# %% [markdown]
# @channel **Hi Everyone,**

# %% [markdown]
# **2023-12-04 `14.1-Interactive-Visualizations-Introduction to JavaScript Visualizations`**

# %% [markdown]
# **Welcome**
#
# We are in the home stretch now. Reflect on what you have learned and realize that the material you have so far are tools that enable you to create virtually any data application.
#
# For the next few weeks we are going to add yet another tool, JavaScript!  While this tool may seem primarily for visualization, it also will give us the ability to create entire interactions with both people and other systems.
#
# At times, combining JavaScript with Python can make fantastic, compelling applications, with UI, feedback and amazing interactive graphics.
#
# Having a firm understanding of it can definitely give you a "leg up" over the competition.
#
# We start the week like we have every other new language, the 4 fundamentals and utilizing Plotly.js.  Super excited for you guys to see and create some amazing interactive visualizations!.

# %% [markdown]
# **Objectives**
#
# * Describe JavaScript `variables`, `arrays`, `data types`, and `statements`.
# * Implement basic JavaScript control flow (`functions`, `loops`, `if/else` statements).
# * Create `functions` in JavaScript.
# * `Create`, `update`, and `iterate` JavaScript objects.
# * Create basic `charts`, including `bar charts` and `line charts`, by using `Plotly`.
# * Use Plotly's `layout` object to customize the appearance of charts.
# * `Annotate` charts with `labels`, `text`, and `hover text`.

# %% [markdown]
# **Presentation**
# * [14.1-Introduction to JavaScript Visualizations](https://git.bootcampcontent.com/University-of-California---Berkeley/UCB-VIRT-DATA-PT-08-2023-U-LOLC/-/blob/main/Slides/Data-14.1-Intr_to_JavaScript_Visualizations.pdf)

# %% [markdown]
# **Resources**
# * [JavaScript Variables](https://www.w3schools.com/js/js_variables.asp)
# * [JavaScript If...else](https://www.w3schools.com/js/js_if_else.asp)
# * [JavaScript Comparison Operators](https://www.w3schools.com/js/js_comparisons.asp)
# * [JavaScript For Loops](https://www.w3schools.com/js/js_loop_for.asp)
# * [Plotly getting started page (from the Unit Review)](https://plotly.com/javascript/getting-started/)
# * [Plotly JavaScript page with LOTS of samples](https://plotly.com/javascript/)

# %% [markdown]
# **Best wishes.**

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.01 Instructor Do: Creating Interactive Charts on the Web (15 min)

# %% [markdown]
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Basic Charts</title>
#     <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
# </head>
# <body>
#     <div id="plot"></div>
#     <script>
#         let xData = [1, 2, 3, 4, 5];
#         let yData = [1, 2, 4, 8, 16];
#     </script>
#     <script src="plots.js"></script>
# </body>
# </html>
#
#
# ```
# ### plots.js
# ```js
# let trace1 = {
#   x: xData,
#   y: yData
# };
#
# let data = [trace1];
#
# let layout = {
#   title: "A Plotly plot"
# };
#
# Plotly.newPlot("plot", data, layout);
# ```

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.02 Instructor Do: JavaScript Variables, Objects, and Arrays (10 min)

# %% [markdown]
# ---
# ## Variables
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta http-equiv="X-UA-Compatible" content="ie=edge">
#   <title>JavaScript Variables, Objects, and Arrays</title>
# </head>
#
# <body>
#
#   <h1>Open the Chrome Inspector Console!</h1>
#   <script src="hello-variable-world.js"></script>
# </body>
#
# </html>
# ```
# ### hello-variable-world.js
# ```js
# // JavaScript Variables work a lot like Python variables, but they should be initialized with the `let` keyword.
#
# // variables in JavaScript can be assigned string values...
# let name = "Homer Simpson";
#
# // ...boolean values...
# let isEmployed = true;
#
# // ...numerical values...
# let age = 39;
# let hourlyWage = 11.99;
#
# // ...or expressions using other variables.
# let dailyWage = hourlyWage * 8;
# let weeklyWage = dailyWage * 5;
#
# console.log('Hello JavaScript World!');
# console.log('We use console.log() to print in JavaScript');
# console.log('Why? Because the print() function will try to send the page to your printer!');
# console.log(`Did you know that ${name} is ${age} years old and makes $${weeklyWage} per week?`);
#
# // we can also define constant variables with the `const` keyword. This tells JavaScript that the variable can't
# // be assigned a new value
#
# const pi = 3.14159265358979;
#
# console.log(`The value of pi is approximately ${pi}, and always will be!`);
#
# pi = 3; // this will give an Uncaught TypeError: Assignment to constant variable.
#
# // JavaScript Objects work a lot like Python dictionaries
# let homer = {
#   name: "Homer Jay Simpson",
#   age: 39
# };
#
# let marge = {
#   name: "Marjorie Jacqueline Simpson",
#   age: 34
# };
#
# let bart = {
#   name: "Bartholomew JoJo Simpson",
#   age: 10
# };
#
# let lisa = {
#   name: "Lisa Marie Simpson",
#   age: 10
# };
#
# let maggie = {
#   name: "Margaret Simpson",
#   age: 1
# };
#
# // JavaScript Arrays are a lot like Python lists
#
# let simpsons = [homer, marge, bart, lisa, maggie];
#
# console.log(simpsons);
#
# ```

# %% [markdown]
# ---
# ## Arrays & Objects
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta http-equiv="X-UA-Compatible" content="ie=edge">
#   <title>Working with Objects, and Arrays</title>
# </head>
#
# <body>
#
#   <h1>Open the Chrome Inspector Console!</h1>
#   <script src="arrays.js"></script>
#   <script src="objects.js"></script>
# </body>
#
# </html>
# ```
# ### arrays.js
# ```js
# // a variable can be initialized as an empty array with two square brackets
# let myArray = [];
#
# // elements can be added to arrays with the push() method
# myArray.push('alpha');
# myArray.push('beta');
# myArray.push('gamma');
# myArray.push('delta');
#
# console.log(myArray); // output: ['alpha', 'beta', 'gamma', 'delta']
#
# // to access a single element from an array, use index notation
# // similar to python, JavaScript uses 0-indexing
# console.log(myArray[1]); // output: 'beta'
#
# // elements from arrays can be overwritten by assigning a new value
# myArray[3] = 'omega';
# console.log(myArray); // output: ['alpha', 'beta', 'gamma', 'omega']
#
# // to access a range of values from the array, use the slice() method.
# // slice(start, end) returns a new array of the objects at indexing beginning at `start` and up to (but not including) `end`.
# console.log(myArray.slice(1,3)); // output: ['beta', 'gamma']
#
# ```
# ### objects.js
# ```js
# // objects are collections of properties. Properties are key-value pairs
# let city = {
#     name: "Chicago",
#     state: "Illinois",
#     area: 234.21,
#     nickname: "Second City"
# };
#
# // to access a property from a JavaScript object, there are two options
# // 1) Bracket notation, similar to python
# console.log(city['name']); // output: "Chicago"
#
# // 2) Dot notation (the preferred convention in JavaScript)
# console.log(city.state); // output: "Illinois"
#
# // properties can be overwritten by assigning a new value
# city.nickname = "The Windy City";
# console.log(city);
#
# // to add a property to an existing object, simply assign a value to a new key
# city.population = 2695598;
# console.log(city);
#
# ```

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.03 Students Do: My Variables, Objects, and Arrays (10 min)

# %% [markdown]
# # Hello Variable World
# In this activity, you will create variables and console logging strings with template literals.
# ## Instructions
# * Open [index.html](Unsolved/index.html) in your browser to run your code in [HelloVariableWorld.js](Unsolved/HelloVariableWorld.js). Check your code by refreshing your browser.
# * Create a variable called `name` that holds your name as a string.
# * Create another variable called `title` using a string template to say `"<your name>'s First Plotly Chart"`.
# * Create an array called `books` of your favorite book titles.
# * Create another array called `timesRead` of how many times you've read each respective book.
# * Create a JavaScript object called `myData` with four key-value pairs:
#   1. `name`
#   2. `favoriteBooks`
#   3. `timesRead`
#   4. `age`
# * Use console.log() to print `myData` to the console. Explore the output in the Chrome console.
# ## Bonus
# In `myData`, consolidate the `favoriteBooks` and `timesRead` into one key called `books` where the value is another javascript object, with keys `titles` and `timesRead`.
# ## Hint
# For more information about template literals, check out [MDN's reference page for template literals](https://developer.mozilla.org/en/docs/Web/JavaScript/Reference/Template_literals).
#
# ---

# %% [markdown]
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta http-equiv="X-UA-Compatible" content="ie=edge">
#   <title>Hello, JavaScript Variables!</title>
# </head>
#
# <body>
#   <script src="HelloVariableWorld.js"></script>
# </body>
#
# </html>
# ```
# ### plots.js
# ```js
# // Create a variable called 'name' that holds your name in a string
# let name = 'Travis Taylor';
#
# // Create another variable called 'title' using a string template to say "<your name>'s First Plotly Chart"
# let title = `${name}'s First Plotly Chart`;
#
# // Create an array called 'books' of your favorite book titles
# let books = ["The Visual Display of Quantitative Information", "Automate the Boring Stuff", "Data Science from Scratch"];
#
# // Create another array called 'timesRead' of how many times you've read each respective book
# let timesRead = [100, 50, 25];
#
# // Create a JavaScript object called 'myData' with four key-value pairs
# // 1. name
# // 2. favoriteBooks
# // 3. timesRead
# // 4. age
#
# let myData = {
#     name: name,
#     favoriteBooks: books,
#     timesRead: timesRead,
#     age: 40
# };
#
# // use console.log() to print 'myData' to the console. Explore the output in the Chrome Console
# console.log(myData);
#
# // BONUS: in 'myData', consolidate the 'favoriteBooks' and 'timesRead' into one key called 'books' where the value is
# // another javascript object, with keys 'titles' and 'timesRead'.
#
# myData = {
#     name: name,
#     books: {
#         titles: books,
#         timesRead: timesRead,
#     },
#     age: 40
# };
#
# // use console.log() to print 'myData' to the console. Explore the output in the Chrome Console
# console.log(myData);
# ```

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.04 Students Do: My First Plotly Chart (5 min)

# %% [markdown]
# In this activity, you will create your first Plotly bar chart by using the variables you created in the previous activity. Your chart will show three books you've read as well as the number of times you've read them.
# ## Instructions
# * In the [plots.js](Unsolved/plots.js) file, copy the following variables you created from the previous activity:
#     * `name`
#     * `title`
#     * `books`
#     * `timesRead`
# * In the Plotly `trace1` object, assign the correct `x` and `y` values for a vertical bar chart.
# * Open the [index.html](Unsolved/index.html) file to see your first Plotly bar chart.
#
# ---

# %% [markdown]
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Basic Charts</title>
#     <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
# </head>
# <body>
#     <div id="plot"></div>
#     <script src="plots.js"></script>
# </body>
# </html>
# ```
# ### plots.js
# ```js
# let name = 'Travis Taylor'
#
# let title = `${name}'s First Plotly Chart`
#
# let books = ["The Visual Display of Quantitative Information", "Automate the Boring Stuff", "Data Science from Scratch"]
#
# let timesRead = [100, 50, 25]
#
# let trace1 = {
#   x: books,
#   y: timesRead,
#   type: 'bar'
# };
#
# let data = [trace1];
#
# let layout = {
#   title: title
# };
#
# Plotly.newPlot("plot", data, layout);
# ```

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.05 Instructor Do: Control Flow (15 min)

# %% [markdown]
# ## Conditionals
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta http-equiv="X-UA-Compatible" content="ie=edge">
#   <title>For Loops</title>
# </head>
#
# <body>
#   <h1>Open the Chrome Inspector Console!</h1>
#   <script src="static/js/conditionals.js"></script>
# </body>
#
# </html>
# ```
# ### conditionals-reference.js
# ```js
# // 1. Simple conditional
# if (condition) {
#   // do if true
# }
#
# // 2. if-else
# if (condition) {
#   // do if true
# } else {
#   // do if false
# }
#
# // 3. else-if
# if (condition1) {
#   // do if condition1 is true
# } else if (condition2) {
#   // do if condition1 is false and condition2 is true
# } else {
#   // do if condition1 and condition2 are false
# }
#
# // 4. logical operators
# if (condition1 && condition2) {
#   // do only if condition1 and condition2 are true
# }
#
# if (condition1 || condition2) {
#   // do if either condition1 or condition2 is true
# }
# ```
#
# ### static/js/conditionals.js
# ```js
# let painAfterInjury = true;
# let significantSwelling = true;
# let ableToWalk = true;
# // let painInBothAnkles = true;
# // let fever = true;
# // let moreThanOneJointSwollenAndRed = true;
# // let suddenPain = true;
# // let clothingAgainstJoinCausesPain = true;
# // let painDuringWeather = true;
# // let painAfterUseOfAnkle = true;
#
# if (painAfterInjury && significantSwelling) {
#   if (!ableToWalk) {
#     console.log("You may have a fracture or sprain.")
#     console.log("Don't walk on the injured foot. Raise the leg and place ice on the swollen area.")
#     console.log("See your doctor promptly")
#   } else {
#     console.log("You may have a sprained ankle, or a fracture of the fibula.")
#     console.log("Use ice, elevation, rest and an elastic bandage to keep the swelling under control.")
#     console.log("See your doctor if the swelling and pain continue.")
#   }
# } else {
#     if (painInBothAnkles) {
#       console.log("You may have rheumatoid arthritis")
#       console.log("See your doctor. He or she can prescribe medicine to help control the symptoms of rheumatoid arthritis.")
#     } else if (fever || moreThanOneJointSwollenAndRed) {
#       console.log("Fever along with a painful, swollen joint could be caused by an infected joint. More than one affected joint could mean rheumatic fever.")
#       console.log("URGENT. SEE YOUR DOCTOR RIGHT AWAY.")
#     } else if (suddenPain || clothingAgainstJoinCausesPain) {
#       console.log("You may have gout.")
#       console.log("See your doctor. During a gout attack, you should rest in bed. You can put a hot pad or an ice pack on your ankle to ease the pain")
#     } else if (painDuringWeather || painAfterUseOfAnkle) {
#       console.log("These symptoms could be caused by osteoarthritis or by previous trauma to the ankle.")
#       console.log("See your doctor. Use heat and anti-inflammatory medicine to relieve discomfort.")
#     } else {
#       console.log("For more information, please talk to your doctor. If you think your problem is serious, call right away.")
#     }
# }
# ```

# %% [markdown]
# ---
# ## Itteration
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta http-equiv="X-UA-Compatible" content="ie=edge">
#   <title>For Loops</title>
# </head>
#
# <body>
#   <h1>Open the Chrome Inspector Console!</h1>
#   <script src="static/js/iteration.js"></script>
# </body>
#
# </html>
# ```
# ### static/js/iteration.js
# ```js
# // Prototypical use case increments loop counter by one on each iteration
# for (let i = 0; i < 10; i++) {
#   console.log("Iteration #", i);
# }
#
# // Looping through an array
# let students = ["Johnny", "Tyler", "Bodhi", "Pappas"];
#
# for (let j = 0; j < students.length; j++) {
#   console.log(students[j]);
# }
#
# ```

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.06 Students Do: Iterations and Conditionals (10 min)

# %% [markdown]
# # Movie Profit Looping
# In this activity, you will create a for loop, append values into arrays based on a movie's decade, calculate the average profit of all movies, and print out how many of the top 10 movies came from each decade.
# ## Instructions
# Given a list of movie objects in [data.js](Unsolved/static/js/data.js), do the following:
# * Open the starter file [movies.js](Unsolved/static/js/movies.js) to edit.
# * Append the movies into arrays based on the movie's decade.
# * Calculate the average profit of all movies.
# * Print how many of the top 10 movies came from each decade.
# * Review your results in the DevTools console after opening [index.html](Unsolved/index.html) in Chrome.
# ## Hint
# * For more information about how to push elements to an empty array, review [02-Ins_JavaScript-Variables_and_Data_Structures](../02-Ins_JavaScript-Variables_and_Data_Structures).
# *  To find the length of the array, review the [JavaScript Array documentation](https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Array/length) from Mozilla.
# ## Reference
# Wikipedia. Highest-grossing films as of 2020 adjusted for inflation (Accessed November 30, 2021). https://en.wikipedia.org/wiki/List_of_highest-grossing_films
#
# ---

# %% [markdown]
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta http-equiv="X-UA-Compatible" content="ie=edge">
#   <title>Movie Scores</title>
# </head>
#
# <body>
#
#   <h1>Open the Chrome Inspector Console!</h1>
#   <script src="static/js/data.js"></script>
#   <script src="static/js/movies.js"></script>
#
# </body>
#
# </html>
# ```
# ### static/js/data.js
# ```js
# let movies = [
#     {
#         title: 'Gone with the Wind',
#         profit: 3739000000,
#         year: 1939
#     },
#     {
#         title: 'Avatar',
#         profit: 3286000000,
#         year: 2009
#     },
#     {
#         title: 'Titanic',
#         profit: 3108000000,
#         year: 1997
#     },
#     {
#         title: 'Star Wars',
#         profit: 3071000000,
#         year: 1977
#     },
#     {
#         title: 'Avengers: Endgame',
#         profit: 2823000000,
#         year: 2019
#     },
#     {
#         title: "The Sound of Music",
#         profit: 2572000000,
#         year: 1965
#     },
#     {
#         title: 'E.T. the Extra-Terrestrial',
#         profit: 2511000000,
#         year: 1982
#     },
#     {
#         title: 'The Ten Commandments',
#         profit: 2377000000,
#         year: 1956
#     },
#     {
#         title: 'Doctor Zhivago',
#         profit: 2253000000,
#         year: 1965
#     },
#     {
#         title: 'Star Wars: The Force Awakens',
#         profit: 2221000000,
#         year: 2015
#     }
# ]
# ```
#
# ### static/js/movies.js
# ```js
# // Open the inspector to see the data
# console.log(movies)
#
# // Starting a profit sum
# let sum = 0;
#
# // Arrays to hold all movies by decade
# movies1930s = [];
# movies1940s = [];
# movies1950s = [];
# movies1960s = [];
# movies1970s = [];
# movies1980s = [];
# movies1990s = [];
# movies2000s = [];
# movies2010s = [];
#
# // For loop to go through all movies
# for (let i = 0; i < movies.length; i++) {
#   // Init variable to hold the current movie in loop
#   let movie = movies[i];
#
#   // Increment the sum variable by the amount of profit
#   sum += movie.profit;
#
#   // Conditional statements to determine array assignment
#   if (movie.year < 1940) {
#     movies1930s.push(movie);
#   } else if (movie.year < 1950) {
#     movies1940s.push(movie);
#   } else if (movie.year < 1960) {
#     movies1950s.push(movie);
#   } else if (movie.year < 1970) {
#     movies1960s.push(movie);
#   } else if (movie.year < 1980) {
#     movies1970s.push(movie);
#   } else if (movie.year < 1990) {
#     movies1980s.push(movie);
#   } else if (movie.year < 2000) {
#     movies1990s.push(movie);
#   } else if (movie.year < 2010) {
#     movies2000s.push(movie);
#   } else {
#     movies2010s.push(movie);
#   }
# }
#
# // Find the average profit
# let avg = sum / movies.length;
#
# // Print results
# console.log("---------");
# console.log(`${movies1930s.length} of the top ten highest grossing (adjusted for inflation) movies are from the 1930s.`);
# console.log(`${movies1940s.length} of the top ten highest grossing (adjusted for inflation) movies are from the 1940s.`);
# console.log(`${movies1950s.length} of the top ten highest grossing (adjusted for inflation) movies are from the 1950s.`);
# console.log(`${movies1960s.length} of the top ten highest grossing (adjusted for inflation) movies are from the 1960s.`);
# console.log(`${movies1970s.length} of the top ten highest grossing (adjusted for inflation) movies are from the 1970s.`);
# console.log(`${movies1980s.length} of the top ten highest grossing (adjusted for inflation) movies are from the 1980s.`);
# console.log(`${movies1990s.length} of the top ten highest grossing (adjusted for inflation) movies are from the 1990s.`);
# console.log(`${movies2000s.length} of the top ten highest grossing (adjusted for inflation) movies are from the 2000s.`);
# console.log(`${movies2010s.length} of the top ten highest grossing (adjusted for inflation) movies are from the 2010s.`);
# console.log(`The average movie profit (adjusted for inflation) is ${avg}.`);
# console.log("---------");
#
#
# ```

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### BREAK (0:10)

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.07 Instructor Do: Multiple Trace Charts (5 min)

# %% [markdown]
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta http-equiv="X-UA-Compatible" content="ie=edge">
#   <title>Multi-Trace</title>
#   <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
# </head>
# <body>
#   <div id="plot"></div>
#   <script src="plots.js"></script>
# </body>
# </html>
# ```
# ### plots.js
# ```js
# // Create our first trace
# let trace1 = {
#   x: [0, 1, 2, 3, 4, 5],
#   y: [0, 5, 10, 15, 20, 25],
#   type: "bar"
# };
#
# // Create our second trace
# let trace2 = {
#   x: [0, 1, 2, 3, 4, 5],
#   y: [0, 1, 4, 9, 16, 25],
#   type: "scatter"
# };
#
# // The data array consists of both traces
# let data = [trace1, trace2];
#
# // Note that we omitted the layout object this time
# // This will use default parameters for the layout
# Plotly.newPlot("plot", data);
#
# ```

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.08 Students Do: Multiple Traces (15 min)

# %% [markdown]
# # Greek vs. Roman Mythology
#
# In this activity, you will compare search results between Greek and Roman mythology to determine whether the Greek or Roman name for the god is more popular.
#
# ![Gods Search Results](08-Stu_Multiple-Trace-Charts/Images/plot.png)
#
# ## Instructions
#
# Ancient Roman gods were often counterparts to or imports of Greek gods. For example, the Greek god Zeus became the Roman god Jupiter through an etymological transformation from Zeus to Zeus Pater ("Father Zeus") to Jupiter. (Classical Latin lacked a "J" consonant.)
#
# In today's world, are these gods better known by their Roman names or Greek names?
#
# Your task is to plot the number of search results for both Roman and Greek names, returned for each god, which will visually answer the previous question. To do so, follow these steps:
#
# * Examine the data in [data.js](08-Stu_Multiple-Trace-Charts/Unsolved/data.js). Note the names of properties in each data object.
#
#   * To accomplish this task, you will need to create two traces, one for Roman gods, and another for Greek gods. You may use the starter file [plots.js](08-Stu_Multiple-Trace-Charts/Unsolved/plots.js) for this.
#
# * To define the data for each plot point in a trace, use a `for` loop on the dataset. For each trace:
#
#   * For the x-axis, provide an array of the paired string of Greek and Roman god names, e.g., Amphitrite-Salacia.
#
#   * For the y-axis, provide an array of search results for Greek and Roman god names in their separate traces.
#
# * Open [index.html](08-Stu_Multiple-Trace-Charts/Unsolved/index.html) in Chrome to view your plot.
#
# ## Reference
#
# Search results figures retrieved on December 1, 2021 from https://www.google.com.
#
# ---

# %% [markdown]
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Greek vs Roman</title>
#     <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
# </head>
# <body>
#     <div id="plot"></div>
#     <script src="data.js"></script>
#     <script src="plots.js"></script>
# </body>
# </html>
# ```
# ### data.js
# ```js
# let searchResults = [{
#   greekName: "Amphitrite",
#   greekSearchResults: 2360000,
#   pair: "Amphitrite-Salacia",
#   romanName: "Salacia",
#   romanSearchResults: 806000
# },
# {
#   greekName: "Ananke",
#   greekSearchResults: 1380000,
#   pair: "Ananke-Necessitas",
#   romanName: "Necessitas",
#   romanSearchResults: 3590000
# },
# {
#   greekName: "Aphrodite",
#   greekSearchResults: 52600000,
#   pair: "Aphrodite-Venus",
#   romanName: "Venus",
#   romanSearchResults: 460000000
# },
# {
#   greekName: "Ares",
#   greekSearchResults: 102000000,
#   pair: "Ares-Mars",
#   romanName: "Mars",
#   romanSearchResults: 998000000
# },
# {
#   greekName: "Artemis",
#   greekSearchResults: 119000000,
#   pair: "Artemis-Diana",
#   romanName: "Diana",
#   romanSearchResults: 574000000
# },
# {
#   greekName: "Asclepius",
#   greekSearchResults: 2900000,
#   pair: "Asclepius-Aesculapius",
#   romanName: "Aesculapius",
#   romanSearchResults: 1930000
# },
# {
#   greekName: "Asclepius",
#   greekSearchResults: 2900000,
#   pair: "Asclepius-Veiovis",
#   romanName: "Veiovis",
#   romanSearchResults: 56400
# },
# {
#   greekName: "Athena",
#   greekSearchResults: 191000000,
#   pair: "Athena-Minerva",
#   romanName: "Minerva",
#   romanSearchResults: 88800000
# },
# {
#   greekName: "Atropos",
#   greekSearchResults: 1550000,
#   pair: "Atropos-Morta",
#   romanName: "Morta",
#   romanSearchResults: 94900000
# },
# {
#   greekName: "Boreas",
#   greekSearchResults: 8610000,
#   pair: "Boreas-Aquilo",
#   romanName: "Aquilo",
#   romanSearchResults: 41100000
# },
# {
#   greekName: "Charites (Graces)",
#   greekSearchResults: 70600,
#   pair: "Charites (Graces)-Gratiae",
#   romanName: "Gratiae",
#   romanSearchResults: 1490000
# },
# {
#   greekName: "Chloris",
#   greekSearchResults: 2510000,
#   pair: "Chloris-Flora",
#   romanName: "Flora",
#   romanSearchResults: 350000000
# },
# {
#   greekName: "Clotho",
#   greekSearchResults: 1090000,
#   pair: "Clotho-Nona",
#   romanName: "Nona",
#   romanSearchResults: 67100000
# },
# {
#   greekName: "Cronus",
#   greekSearchResults: 4640000,
#   pair: "Cronus-Saturn",
#   romanName: "Saturn",
#   romanSearchResults: 151000000
# },
# {
#   greekName: "Demeter",
#   greekSearchResults: 22800000,
#   pair: "Demeter-Ceres",
#   romanName: "Ceres",
#   romanSearchResults: 51300000
# },
# {
#   greekName: "Dionysus",
#   greekSearchResults: 17600000,
#   pair: "Dionysus-Bacchus",
#   romanName: "Bacchus",
#   romanSearchResults: 46200000
# },
# {
#   greekName: "Enyo",
#   greekSearchResults: 2410000,
#   pair: "Enyo-Bellona",
#   romanName: "Bellona",
#   romanSearchResults: 12700000
# },
# {
#   greekName: "Eos",
#   greekSearchResults: 448000000,
#   pair: "Eos-Aurora",
#   romanName: "Aurora",
#   romanSearchResults: 2460000000
# },
# {
#   greekName: "Erinyes",
#   greekSearchResults: 556000,
#   pair: "Erinyes-Dirae",
#   romanName: "Dirae",
#   romanSearchResults: 345000
# },
# {
#   greekName: "Eris",
#   greekSearchResults: 33100000,
#   pair: "Eris-Discordia",
#   romanName: "Discordia",
#   romanSearchResults: 11300000
# },
# {
#   greekName: "Eros",
#   greekSearchResults: 185000000,
#   pair: "Eros-Cupid (Amor)",
#   romanName: "Cupid (Amor)",
#   romanSearchResults: 31100000
# },
# {
#   greekName: "Eurus",
#   greekSearchResults: 4550000,
#   pair: "Eurus-Vulturnus",
#   romanName: "Vulturnus",
#   romanSearchResults: 244000
# },
# {
#   greekName: "Gaia",
#   greekSearchResults: 137000000,
#   pair: "Gaia-Tellus",
#   romanName: "Tellus",
#   romanSearchResults: 49300000
# },
# {
#   greekName: "Galinthias",
#   greekSearchResults: 43400,
#   pair: "Galinthias-Galinthis",
#   romanName: "Galinthis",
#   romanSearchResults: 1870
# },
# {
#   greekName: "Irene",
#   greekSearchResults: 242000000,
#   pair: "Irene-Pax",
#   romanName: "Pax",
#   romanSearchResults: 162000000
# },
# {
#   greekName: "Hades",
#   greekSearchResults: 42100000,
#   pair: "Hades-Pluto, Orcus",
#   romanName: "Pluto",
#   romanSearchResults: 75700000
# },
# {
#   greekName: "Hebe",
#   greekSearchResults: 33900000,
#   pair: "Hebe-Juventas",
#   romanName: "Juventas",
#   romanSearchResults: 2560000
# },
# {
#   greekName: "Hecate",
#   greekSearchResults: 5800000,
#   pair: "Hecate-Trivia",
#   romanName: "Trivia",
#   romanSearchResults: 161000000
# },
# {
#   greekName: "Helios",
#   greekSearchResults: 71700000,
#   pair: "Helios-Sol",
#   romanName: "Sol",
#   romanSearchResults: 1410000000
# },
# {
#   greekName: "Hera",
#   greekSearchResults: 66700000,
#   pair: "Hera-Juno",
#   romanName: "Juno",
#   romanSearchResults: 95500000
# },
# {
#   greekName: "Heracles",
#   greekSearchResults: 15800000,
#   pair: "Heracles-Hercules",
#   romanName: "Hercules",
#   romanSearchResults: 127000000
# },
# {
#   greekName: "Hermes",
#   greekSearchResults: 683000000,
#   pair: "Hermes-Mercury",
#   romanName: "Mercury",
#   romanSearchResults: 419000000
# },
# {
#   greekName: "Hephaestus",
#   greekSearchResults: 4900000,
#   pair: "Hephaestus-Vulcan",
#   romanName: "Vulcan",
#   romanSearchResults: 93100000
# },
# {
#   greekName: "Hesperos",
#   greekSearchResults: 122000,
#   pair: "Hesperos-Vesper",
#   romanName: "Vesper",
#   romanSearchResults: 28000000
# },
# {
#   greekName: "Hestia",
#   greekSearchResults: 16000000,
#   pair: "Hestia-Vesta",
#   romanName: "Vesta",
#   romanSearchResults: 57400000
# },
# {
#   greekName: "Hygieia",
#   greekSearchResults: 926000,
#   pair: "Hygieia-Salus",
#   romanName: "Salus",
#   romanSearchResults: 25900000
# },
# {
#   greekName: "Hypnos",
#   greekSearchResults: 58400000,
#   pair: "Hypnos-Somnus",
#   romanName: "Somnus",
#   romanSearchResults: 2590000
# },
# {
#   greekName: "Lachesis",
#   greekSearchResults: 8880000,
#   pair: "Lachesis-Decima",
#   romanName: "Decima",
#   romanSearchResults: 46500000
# },
# {
#   greekName: "Leto",
#   greekSearchResults: 91500000,
#   pair: "Leto-Latona",
#   romanName: "Latona",
#   romanSearchResults: 2610000
# },
# {
#   greekName: "Moirai (Fates)",
#   greekSearchResults: 75200,
#   pair: "Moirai (Fates)-Parcae",
#   romanName: "Parcae",
#   romanSearchResults: 188000
# },
# {
#   greekName: "Nike",
#   greekSearchResults: 1940000000,
#   pair: "Nike-Victoria",
#   romanName: "Victoria",
#   romanSearchResults: 2050000000
# },
# {
#   greekName: "Notus",
#   greekSearchResults: 3730000,
#   pair: "Notus-Auster",
#   romanName: "Auster",
#   romanSearchResults: 9200000
# },
# {
#   greekName: "Nyx",
#   greekSearchResults: 70800000,
#   pair: "Nyx-Nox",
#   romanName: "Nox",
#   romanSearchResults: 95500000
# },
# {
#   greekName: "Odysseus",
#   greekSearchResults: 12600000,
#   pair: "Odysseus-Ulysses",
#   romanName: "Ulysses",
#   romanSearchResults: 38400000
# },
# {
#   greekName: "Pan",
#   greekSearchResults: 1430000000,
#   pair: "Pan-Faunus",
#   romanName: "Faunus",
#   romanSearchResults: 1340000
# },
# {
#   greekName: "Persephone",
#   greekSearchResults: 15500000,
#   pair: "Persephone-Proserpina",
#   romanName: "Proserpina",
#   romanSearchResults: 2210000
# },
# {
#   greekName: "Pheme",
#   greekSearchResults: 437000,
#   pair: "Pheme-Fama",
#   romanName: "Fama",
#   romanSearchResults: 119000000
# },
# {
#   greekName: "Phosphorus",
#   greekSearchResults: 63000000,
#   pair: "Phosphorus-Lucifer",
#   romanName: "Lucifer",
#   romanSearchResults: 69400000
# },
# {
#   greekName: "Poseidon",
#   greekSearchResults: 54900000,
#   pair: "Poseidon-Neptune",
#   romanName: "Neptune",
#   romanSearchResults: 87700000
# },
# {
#   greekName: "Satyr",
#   greekSearchResults: 14200000,
#   pair: "Satyr-Faun",
#   romanName: "Faun",
#   romanSearchResults: 18600000
# },
# {
#   greekName: "Selene",
#   greekSearchResults: 34800000,
#   pair: "Selene-Luna",
#   romanName: "Luna",
#   romanSearchResults: 1030000000
# },
# {
#   greekName: "Semele",
#   greekSearchResults: 1450000,
#   pair: "Semele-Stimula",
#   romanName: "Stimula",
#   romanSearchResults: 4350000
# },
# {
#   greekName: "Silenus",
#   greekSearchResults: 984000,
#   pair: "Silenus-Silvanus",
#   romanName: "Silvanus",
#   romanSearchResults: 2480000
# },
# {
#   greekName: "Thanatos",
#   greekSearchResults: 6850000,
#   pair: "Thanatos-Mors",
#   romanName: "Mors",
#   romanSearchResults: 43000000
# },
# {
#   greekName: "Themis",
#   greekSearchResults: 12900000,
#   pair: "Themis-Justitia",
#   romanName: "Justitia",
#   romanSearchResults: 7570000
# },
# {
#   greekName: "Tyche",
#   greekSearchResults: 3330000,
#   pair: "Tyche-Fortuna",
#   romanName: "Fortuna",
#   romanSearchResults: 206000000
# },
# {
#   greekName: "Zephyrus",
#   greekSearchResults: 13800000,
#   pair: "Zephyrus-Favonius",
#   romanName: "Favonius",
#   romanSearchResults: 922000
# },
# {
#   greekName: "Zeus",
#   greekSearchResults: 110000000,
#   pair: "Zeus-Jupiter",
#   romanName: "Jupiter",
#   romanSearchResults: 251000000
# }
# ];
# ```
# ### plots.js
# ```js
# // Initialized arrays
# let names = []
# let greekNames = []
# let romanNames = []
# let greekSearchResults = []
# let romanSearchResults = []
#
# // For loop to populate arrays
# for (let i = 0; i < searchResults.length; i++) {
#   row = searchResults[i];
#   names.push(row.pair);
#   greekNames.push(row.greekName);
#   romanNames.push(row.romanName);
#   greekSearchResults.push(row.greekSearchResults);
#   romanSearchResults.push(row.romanSearchResults);
# }
#
# // Trace1 for the Greek Data
# let trace1 = {
#   x: names,
#   y: greekSearchResults,
#   text: greekNames,
#   name: "Greek",
#   type: "bar"
# };
#
# // Trace 2 for the Roman Data
# let trace2 = {
#   x: names,
#   y: romanSearchResults,
#   text: romanNames,
#   name: "Roman",
#   type: "bar"
# };
#
# // Create data array
# let data = [trace1, trace2];
#
# // Apply a title to the layout
# let layout = {
#   title: "Greek vs Roman gods search results",
#   barmode: "group",
#   // Include margins in the layout so the x-tick labels display correctly
#   margin: {
#     l: 50,
#     r: 50,
#     b: 200,
#     t: 50,
#     pad: 4
#   }
# };
#
# // Render the plot to the div tag with id "plot"
# Plotly.newPlot("plot", data, layout);
#
# ```

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.09 Instructor Do: Preprocessing Data with Functions (15 min)

# %% [markdown]
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta http-equiv="X-UA-Compatible" content="ie=edge">
#   <title>Python and JavaScript Functions</title>
# </head>
#
# <body>
#   <h1>Open the Chrome Inspector Console!</h1>
#   <script src="static/js/functions.js"></script>
# </body>
#
# </html>
# ```
# ### functions.py
# ```python
# # Simple print statement
# def print_hello():
#     print("Hello there!")
#
#
# # Takes two numbers and adds them
# def addition(a, b):
#     return a + b
#
#
# # Takes in a list and loops through
# def list_loop(user_list):
#     for i in user_list:
#         print(i)
#
#
# # Uses a previous declared function
# def double_addition(c, d):
#     total = addition(c, d) * 2
#
#     return total
#
#
# # Call the functions below
#
# # Run print function
# print_hello()
#
# # Print result of addition function
# print(addition(44, 50))
#
# # Create a list and pass through the loop function
# friends = ["Sarah", "Greg", "Cindy", "Jeff"]
# list_loop(friends)
#
# # Print result of double_addition function
# print(double_addition(3, 4))
#
# # Python built in function for rounding
# long_decimal = 112.34534454
# rounded_decimal = round(long_decimal)
# print(rounded_decimal)
#
# ```
# ### static/js/functions.js
# ```js
# // Simple log statement
# function printHello() {
#   console.log("Hello there!");
# }
#
# // Takes two numbers and adds them
# function addition(a, b) {
#   return a + b;
# }
#
# // Run the code in the `printHello` function
# printHello();
#
# // Log results of addition function
# console.log(addition(44, 50));
#
# // This function accepts a parameter and iterates through an array
# function listLoop(userList) {
#   for (let i = 0; i < userList.length; i++) {
#     console.log(userList[i]);
#   }
# }
#
# let friends = ["Sarah", "Greg", "Cindy", "Jeff"];
# listLoop(friends);
#
# // Functions can call other functions
# function doubleAddition(c, d) {
#   let total = addition(c, d) * 2;
#
#   return total;
# }
#
# // Log results of doubleAddition function
# console.log(doubleAddition(3, 4));
#
#
# // Javascript built in functions
# let longDecimal = 112.34534454;
# let roundedDecimal = Math.floor(longDecimal);
# console.log(roundedDecimal);
#
#
# ```

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.10 Students Do: Creating Functions (15 min)

# %% [markdown]
# # Statistical Functions
# In this activity, you'll create functions that will calculate the mean, variance, and standard deviation of a dataset.
# ## Instructions
# * Using the movie array provided in the [starter code file](Unsolved/static/js/app.js), create functions that will return statistical values from any given array of data.
#   * `movieScore = [4.4, 3.3, 5.9, 8.8, 1.2, 5.2, 7.4, 7.5, 7.2, 9.7, 4.2, 6.9]`
# * Create functions that will find the following:
#   * Mean
#   * Variance
#   * Standard deviation
# * Each function should `console.log` both the name of the statistic used and its value. For example, "The Mean is: 33.3".
# * The functions should be able to take any array of numbers and return the statistical value.
# * After you have the functions working with the movie dataset, run them on the following additional data points:
#   * `monthlyAvgRainFall = [3.03, 2.48, 3.23, 3.15, 4.13, 3.23]`
#   * `mileRunTimes = [5.06, 4.54, 5.56, 4.40, 7.10]`
# ## Hint
# * Remember to open your [index.html](Unsolved/index.html) in Chrome and check the DevTools console as you proceed.
# * Use the JavaScript Math library to handle calculations needing exponents or square roots.
# * If you want to review how to calculate variance and standard deviation, see the following pages:
#   * [Variance](https://stats.stackexchange.com/questions/212650/variance-explanation)
#   * [Standard Deviation](https://www.mathsisfun.com/data/standard-deviation.html)
#
# ---

# %% [markdown]
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta http-equiv="X-UA-Compatible" content="ie=edge">
#   <title>Statistics in JS</title>
# </head>
#
# <body>
#   <h1>Open the Chrome Inspector Console!</h1>
#   <script src="static/js/app.js"></script>
# </body>
#
# </html>
# ```
# ### static/js/app.js
# ```js
# // Array of movie ratings
# let movieScore = [4.4, 3.3, 5.9, 8.8, 1.2, 5.2, 7.4, 7.5, 7.2, 9.7, 4.2, 6.9];
#
# // Mean is the average of all the values.
# function mean(arr) {
#   let total = 0;
#   for (let i = 0; i < arr.length; i++) {
#     total += arr[i];
#   }
#   let meanValue = total / arr.length;
#
#   return meanValue;
# }
#
# // Variance can be found by subtracting the mean from each number in the data set,
# // squaring the result, and then averaging the square differences.
# function variance(arr) {
#   let meanValue = mean(arr);
#   let total = 0;
#
#   for (let i = 0; i < arr.length; i++) {
#     total += (arr[i] - meanValue) ** 2;
#   }
#   let varianceValue = total / arr.length;
#   return varianceValue;
# }
#
#
# // Standard deviation is the square root of the variance
# function standardDeviation(arr) {
#   let varianceValue = variance(arr);
#   let standardDeviationValue = Math.sqrt(varianceValue);
#
#   return standardDeviationValue;
# }
#
# // Print to the console the Movie Statistical Analysis
# console.log("Movie Statistical Analysis");
# console.log("--------------------------");
# console.log(`The mean is : ${mean(movieScore)}`);
# console.log(`The variance is : ${variance(movieScore)}`);
# console.log(`The standard deviation is : ${standardDeviation(movieScore)}`);
# console.log("");
#
# // Print to the console the Rainfall Statistical Analysis
# let monthlyAvgRainFall = [3.03, 2.48, 3.23, 3.15, 4.13, 3.23];
# console.log("Rainfall Statistical Analysis");
# console.log("--------------------------");
# console.log(`The mean is : ${mean(monthlyAvgRainFall)}`);
# console.log(`The variance is : ${variance(monthlyAvgRainFall)}`);
# console.log(`The standard deviation is : ${standardDeviation(monthlyAvgRainFall)}`);
# console.log("");
#
# // Print to the console the Running Statistical Analysis
# let mileRuns = [5.06, 4.54, 5.56, 4.40, 7.10];
# console.log("Mile Run Statistical Analysis");
# console.log("--------------------------");
# console.log(`The mean is : ${mean(mileRuns)}`);
# console.log(`The variance is : ${variance(mileRuns)}`);
# console.log(`The standard deviation is : ${standardDeviation(mileRuns)}`);
# console.log("");
#
# ```

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.11 Students Do: Preprocessing Data for Plotly (15 min)

# %% [markdown]
# # Preprocessing Data with Functions for Plotly
# In this activity, you will create functions that preprocess films from the Pagila database and create a bar chart of average values by content rating.
# ## Instructions
# * Using the [films.js](Unsolved/films.js) array of movies from the Pagila database, and the starter file [plots.js](Unsolved/plots.js), create a function that will calculate averages by content rating (i.e., G, PG, PG-13, and R) of one of the following metrics:
#   * Rental rate (`rental_rate`)
#   * Length (`length`)
#   * Replacement cost (`replacement_cost`)
# * With the calculated averages, create a function that will generate a Plotly bar chart with the average values.
# * After you have the functions working, try changing the metric to update the bar chart.
# * Remember to use [index.html](Unsolved/index.html) to view your bar chart as you progress with your code.
# ## Hint
# You will need to use conditionals, loops, and functions to complete this activity. You may find it helpful to review the following two activities:
# * [06-Stu_Iteration_and_Conditionals](../06-Stu_Iteration_and_Conditionals)
# * [10-Stu_Creating-Functions](../10-Stu_Creating-Functions)
# ## Reference
# Devrim Gündüz (2021) _Pagila_. Retrieved from: [https://github.com/devrimgunduz/pagila](https://github.com/devrimgunduz/pagila)
#
# ---

# %% [markdown]
# ### index.html
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Films</title>
#     <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
# </head>
# <body>
#     <div id="plot"></div>
#     <script src="films.js"></script>
#     <script src="plots.js"></script>
#     <!-- <script src="refactored.js"></script> -->
# </body>
# </html>
# ```
# ### films.js
# ```js
# films = [
#   {'film_id': 1,
#   'title': 'ACADEMY DINOSAUR',
#   'description': 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 85.358235302,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 2,
#   'title': 'ACE GOLDFINGER',
#   'description': 'A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 76.9264450532,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 3,
#   'title': 'ADAPTATION HOLES',
#   'description': 'A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 64.5574354629,
#   'replacement_cost': 18.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 4,
#   'title': 'AFFAIR PREJUDICE',
#   'description': 'A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 102.5389248768,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 5,
#   'title': 'AFRICAN EGG',
#   'description': 'A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 84.3087899483,
#   'replacement_cost': 22.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 6,
#   'title': 'AGENT TRUMAN',
#   'description': 'A Intrepid Panorama of a Robot And a Boy who must Escape a Sumo Wrestler in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 72.9299775569,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 7,
#   'title': 'AIRPLANE SIERRA',
#   'description': 'A Touching Saga of a Hunter And a Butler who must Discover a Butler in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 111.9218942329,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 8,
#   'title': 'AIRPORT POLLOCK',
#   'description': 'A Epic Tale of a Moose And a Girl who must Confront a Monkey in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 112.8455914363,
#   'replacement_cost': 15.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 9,
#   'title': 'ALABAMA DEVIL',
#   'description': 'A Thoughtful Panorama of a Database Administrator And a Mad Scientist who must Outgun a Mad Scientist in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 93.9056933914,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 10,
#   'title': 'ALADDIN CALENDAR',
#   'description': 'A Action-Packed Tale of a Man And a Lumberjack who must Reach a Feminist in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 144.2428019244,
#   'replacement_cost': 24.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 11,
#   'title': 'ALAMO VIDEOTAPE',
#   'description': 'A Boring Epistle of a Butler And a Cat who must Fight a Pastry Chef in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 106.9021214858,
#   'replacement_cost': 16.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 12,
#   'title': 'ALASKA PHANTOM',
#   'description': 'A Fanciful Saga of a Hunter And a Pastry Chef who must Vanquish a Boy in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 116.5325517156,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 213,
#   'title': 'DATE SPEED',
#   'description': 'A Touching Saga of a Composer And a Moose who must Discover a Dentist in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 125.098113588,
#   'replacement_cost': 19.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 13,
#   'title': 'ALI FOREVER',
#   'description': 'A Action-Packed Drama of a Dentist And a Crocodile who must Battle a Feminist in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 119.4847571885,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 14,
#   'title': 'ALICE FANTASIA',
#   'description': 'A Emotional Drama of a A Shark And a Database Administrator who must Vanquish a Pioneer in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 147.1749786951,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 15,
#   'title': 'ALIEN CENTER',
#   'description': 'A Brilliant Drama of a Cat And a Mad Scientist who must Battle a Feminist in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 102.3506191176,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 16,
#   'title': 'ALLEY EVOLUTION',
#   'description': 'A Fast-Paced Drama of a Robot And a Composer who must Battle a Astronaut in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 110.1953285762,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 17,
#   'title': 'ALONE TRIP',
#   'description': 'A Fast-Paced Character Study of a Composer And a Dog who must Outgun a Boat in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 136.1672332931,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 18,
#   'title': 'ALTER VICTORY',
#   'description': 'A Thoughtful Drama of a Composer And a Feminist who must Meet a Secret Agent in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 91.1528679716,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 19,
#   'title': 'AMADEUS HOLY',
#   'description': 'A Emotional Display of a Pioneer And a Technical Writer who must Battle a Man in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 89.8912434301,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 20,
#   'title': 'AMELIE HELLFIGHTERS',
#   'description': 'A Boring Drama of a Woman And a Squirrel who must Conquer a Student in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 125.8131900392,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 21,
#   'title': 'AMERICAN CIRCUS',
#   'description': 'A Insightful Drama of a Girl And a Astronaut who must Face a Database Administrator in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 134.3087923209,
#   'replacement_cost': 17.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 22,
#   'title': 'AMISTAD MIDSUMMER',
#   'description': 'A Emotional Character Study of a Dentist And a Crocodile who must Meet a Sumo Wrestler in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 74.5995076114,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 23,
#   'title': 'ANACONDA CONFESSIONS',
#   'description': 'A Lacklusture Display of a Dentist And a Dentist who must Fight a Girl in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 124.3634356108,
#   'replacement_cost': 9.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 24,
#   'title': 'ANALYZE HOOSIERS',
#   'description': 'A Thoughtful Display of a Explorer And a Pastry Chef who must Overcome a Feminist in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 105.3817800087,
#   'replacement_cost': 19.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 25,
#   'title': 'ANGELS LIFE',
#   'description': 'A Thoughtful Display of a Woman And a Astronaut who must Battle a Robot in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 46.5562358472,
#   'replacement_cost': 15.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 26,
#   'title': 'ANNIE IDENTITY',
#   'description': 'A Amazing Panorama of a Pastry Chef And a Boat who must Escape a Woman in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 94.2447403252,
#   'replacement_cost': 15.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 27,
#   'title': 'ANONYMOUS HUMAN',
#   'description': 'A Amazing Reflection of a Database Administrator And a Astronaut who must Outrace a Database Administrator in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 111.7934986334,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 28,
#   'title': 'ANTHEM LUKE',
#   'description': 'A Touching Panorama of a Waitress And a Woman who must Outrace a Dog in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 98.7812384206,
#   'replacement_cost': 16.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 29,
#   'title': 'ANTITRUST TOMATOES',
#   'description': 'A Fateful Yarn of a Womanizer And a Feminist who must Succumb a Database Administrator in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 83.2623925701,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 30,
#   'title': 'ANYTHING SAVANNAH',
#   'description': 'A Epic Story of a Pastry Chef And a Woman who must Chase a Feminist in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 151.3315928319,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 31,
#   'title': 'APACHE DIVINE',
#   'description': 'A Awe-Inspiring Reflection of a Pastry Chef And a Teacher who must Overcome a Sumo Wrestler in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 135.4913029208,
#   'replacement_cost': 16.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 32,
#   'title': 'APOCALYPSE FLAMINGOS',
#   'description': 'A Astounding Story of a Dog And a Squirrel who must Defeat a Woman in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 147.344407539,
#   'replacement_cost': 11.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 33,
#   'title': 'APOLLO TEEN',
#   'description': 'A Action-Packed Reflection of a Crocodile And a Explorer who must Find a Sumo Wrestler in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 102.2524678307,
#   'replacement_cost': 15.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 34,
#   'title': 'ARABIA DOGMA',
#   'description': 'A Touching Epistle of a Madman And a Mad Cow who must Defeat a Student in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 92.3239979426,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 35,
#   'title': 'ARACHNOPHOBIA ROLLERCOASTER',
#   'description': 'A Action-Packed Reflection of a Pastry Chef And a Composer who must Discover a Mad Scientist in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 97.2646454942,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 36,
#   'title': 'ARGONAUTS TOWN',
#   'description': 'A Emotional Epistle of a Forensic Psychologist And a Butler who must Challenge a Waitress in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 83.0531517627,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 37,
#   'title': 'ARIZONA BANG',
#   'description': 'A Brilliant Panorama of a Mad Scientist And a Mad Cow who must Meet a Pioneer in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 116.4467972266,
#   'replacement_cost': 28.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 38,
#   'title': 'ARK RIDGEMONT',
#   'description': 'A Beautiful Yarn of a Pioneer And a Monkey who must Pursue a Explorer in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 114.0063277817,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 39,
#   'title': 'ARMAGEDDON LOST',
#   'description': 'A Fast-Paced Tale of a Boat And a Teacher who must Succumb a Composer in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 1.99,
#   'length': 97.88324862,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 40,
#   'title': 'ARMY FLINTSTONES',
#   'description': 'A Boring Saga of a Database Administrator And a Womanizer who must Battle a Waitress in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 102.8268615365,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 41,
#   'title': 'ARSENIC INDEPENDENCE',
#   'description': 'A Fanciful Documentary of a Mad Cow And a Womanizer who must Find a Dentist in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 128.0219020184,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 42,
#   'title': 'ARTIST COLDBLOODED',
#   'description': 'A Stunning Reflection of a Robot And a Moose who must Challenge a Woman in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 145.7026803691,
#   'replacement_cost': 10.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 43,
#   'title': 'ATLANTIS CAUSE',
#   'description': 'A Thrilling Yarn of a Feminist And a Hunter who must Fight a Technical Writer in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 94.6407871304,
#   'replacement_cost': 15.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 44,
#   'title': 'ATTACKS HATE',
#   'description': 'A Fast-Paced Panorama of a Technical Writer And a Mad Scientist who must Find a Feminist in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 80.9176818567,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 45,
#   'title': 'ATTRACTION NEWTON',
#   'description': 'A Astounding Panorama of a Composer And a Frisbee who must Reach a Husband in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 102.9512145195,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 46,
#   'title': 'AUTUMN CROW',
#   'description': 'A Beautiful Tale of a Dentist And a Mad Cow who must Battle a Moose in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 98.799477746,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 47,
#   'title': 'BABY HALL',
#   'description': 'A Boring Character Study of a A Shark And a Girl who must Outrace a Feminist in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 128.4099469667,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 48,
#   'title': 'BACKLASH UNDEFEATED',
#   'description': 'A Stunning Character Study of a Mad Scientist And a Mad Cow who must Kill a Car in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 101.3025538493,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 49,
#   'title': 'BADMAN DAWN',
#   'description': 'A Emotional Panorama of a Pioneer And a Composer who must Escape a Mad Scientist in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 142.3632068177,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 50,
#   'title': 'BAKED CLEOPATRA',
#   'description': 'A Stunning Drama of a Forensic Psychologist And a Husband who must Overcome a Waitress in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 84.4919904064,
#   'replacement_cost': 20.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 51,
#   'title': 'BALLOON HOMEWARD',
#   'description': 'A Insightful Panorama of a Forensic Psychologist And a Mad Cow who must Build a Mad Scientist in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 129.3830717608,
#   'replacement_cost': 10.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 52,
#   'title': 'BALLROOM MOCKINGBIRD',
#   'description': 'A Thrilling Documentary of a Composer And a Monkey who must Find a Feminist in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 91.1627919405,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 53,
#   'title': 'BANG KWAI',
#   'description': 'A Epic Drama of a Madman And a Cat who must Face a A Shark in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 69.7215942566,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 54,
#   'title': 'BANGER PINOCCHIO',
#   'description': 'A Awe-Inspiring Drama of a Car And a Pastry Chef who must Chase a Crocodile in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 98.1886009847,
#   'replacement_cost': 15.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 55,
#   'title': 'BARBARELLA STREETCAR',
#   'description': 'A Awe-Inspiring Story of a Feminist And a Cat who must Conquer a Dog in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 97.787260133,
#   'replacement_cost': 27.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 56,
#   'title': 'BAREFOOT MANCHURIAN',
#   'description': 'A Intrepid Story of a Cat And a Student who must Vanquish a Girl in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 77.9200524555,
#   'replacement_cost': 15.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 57,
#   'title': 'BASIC EASY',
#   'description': 'A Stunning Epistle of a Man And a Husband who must Reach a Mad Scientist in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 142.6090155262,
#   'replacement_cost': 18.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 58,
#   'title': 'BEACH HEARTBREAKERS',
#   'description': 'A Fateful Display of a Womanizer And a Mad Scientist who must Outgun a A Shark in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 83.312522577,
#   'replacement_cost': 16.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 59,
#   'title': 'BEAR GRACELAND',
#   'description': 'A Astounding Saga of a Dog And a Boy who must Kill a Teacher in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 131.5048865591,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 60,
#   'title': 'BEAST HUNCHBACK',
#   'description': 'A Awe-Inspiring Epistle of a Student And a Squirrel who must Defeat a Boy in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 119.9835252715,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 61,
#   'title': 'BEAUTY GREASE',
#   'description': 'A Fast-Paced Display of a Composer And a Moose who must Sink a Robot in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 100.4961515467,
#   'replacement_cost': 28.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 62,
#   'title': 'BED HIGHBALL',
#   'description': 'A Astounding Panorama of a Lumberjack And a Dog who must Redeem a Woman in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 112.3128038561,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 63,
#   'title': 'BEDAZZLED MARRIED',
#   'description': 'A Astounding Character Study of a Madman And a Robot who must Meet a Mad Scientist in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 103.0941580554,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 64,
#   'title': 'BEETHOVEN EXORCIST',
#   'description': 'A Epic Display of a Pioneer And a Student who must Challenge a Butler in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 122.9544744952,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 65,
#   'title': 'BEHAVIOR RUNAWAY',
#   'description': 'A Unbelieveable Drama of a Student And a Husband who must Outrace a Sumo Wrestler in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 92.6081268428,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 66,
#   'title': 'BENEATH RUSH',
#   'description': 'A Astounding Panorama of a Man And a Monkey who must Discover a Man in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 98.2757048911,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 67,
#   'title': 'BERETS AGENT',
#   'description': 'A Taut Saga of a Crocodile And a Boy who must Overcome a Technical Writer in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 102.5082325985,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 68,
#   'title': 'BETRAYED REAR',
#   'description': 'A Emotional Character Study of a Boat And a Pioneer who must Find a Explorer in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 103.7329536275,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 69,
#   'title': 'BEVERLY OUTLAW',
#   'description': 'A Fanciful Documentary of a Womanizer And a Boat who must Defeat a Madman in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 127.1038844598,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 70,
#   'title': 'BIKINI BORROWERS',
#   'description': 'A Astounding Drama of a Astronaut And a Cat who must Discover a Woman in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 130.8252433684,
#   'replacement_cost': 26.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 71,
#   'title': 'BILKO ANONYMOUS',
#   'description': 'A Emotional Reflection of a Teacher And a Man who must Meet a Cat in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 94.8332867341,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 72,
#   'title': 'BILL OTHERS',
#   'description': 'A Stunning Saga of a Mad Scientist And a Forensic Psychologist who must Challenge a Squirrel in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 95.9157418414,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 73,
#   'title': 'BINGO TALENTED',
#   'description': 'A Touching Tale of a Girl And a Crocodile who must Discover a Waitress in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 98.1815574288,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 74,
#   'title': 'BIRCH ANTITRUST',
#   'description': 'A Fanciful Panorama of a Husband And a Pioneer who must Outgun a Dog in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 114.2539883896,
#   'replacement_cost': 18.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 75,
#   'title': 'BIRD INDEPENDENCE',
#   'description': 'A Thrilling Documentary of a Car And a Student who must Sink a Hunter in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 74.8923988652,
#   'replacement_cost': 14.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 76,
#   'title': 'BIRDCAGE CASPER',
#   'description': 'A Fast-Paced Saga of a Frisbee And a Astronaut who must Overcome a Feminist in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 116.42352337,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 77,
#   'title': 'BIRDS PERDITION',
#   'description': 'A Boring Story of a Womanizer And a Pioneer who must Face a Dog in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 120.0576816134,
#   'replacement_cost': 15.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 78,
#   'title': 'BLACKOUT PRIVATE',
#   'description': 'A Intrepid Yarn of a Pastry Chef And a Mad Scientist who must Challenge a Secret Agent in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 113.4834064892,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 79,
#   'title': 'BLADE POLISH',
#   'description': 'A Thoughtful Character Study of a Frisbee And a Pastry Chef who must Fight a Dentist in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 104.7383478086,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 80,
#   'title': 'BLANKET BEVERLY',
#   'description': 'A Emotional Documentary of a Student And a Girl who must Build a Boat in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 81.1254239403,
#   'replacement_cost': 21.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 81,
#   'title': 'BLINDNESS GUN',
#   'description': 'A Touching Drama of a Robot And a Dentist who must Meet a Hunter in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 109.2622237315,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 82,
#   'title': 'BLOOD ARGONAUTS',
#   'description': 'A Boring Drama of a Explorer And a Man who must Kill a Lumberjack in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 102.5252389952,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 83,
#   'title': 'BLUES INSTINCT',
#   'description': 'A Insightful Documentary of a Boat And a Composer who must Meet a Forensic Psychologist in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 104.2695077125,
#   'replacement_cost': 18.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 84,
#   'title': 'BOILED DARES',
#   'description': 'A Awe-Inspiring Story of a Waitress And a Dog who must Discover a Dentist in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 105.279733307,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 85,
#   'title': 'BONNIE HOLOCAUST',
#   'description': 'A Fast-Paced Story of a Crocodile And a Robot who must Find a Moose in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 93.3609683335,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 86,
#   'title': 'BOOGIE AMELIE',
#   'description': 'A Lacklusture Character Study of a Husband And a Sumo Wrestler who must Succumb a Technical Writer in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 128.0405423979,
#   'replacement_cost': 11.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 87,
#   'title': 'BOONDOCK BALLROOM',
#   'description': 'A Fateful Panorama of a Crocodile And a Boy who must Defeat a Monkey in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 92.5825982791,
#   'replacement_cost': 14.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 88,
#   'title': 'BORN SPINAL',
#   'description': 'A Touching Epistle of a Frisbee And a Husband who must Pursue a Student in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 129.9598300458,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 89,
#   'title': 'BORROWERS BEDAZZLED',
#   'description': 'A Brilliant Epistle of a Teacher And a Sumo Wrestler who must Defeat a Man in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 116.9580532219,
#   'replacement_cost': 22.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 90,
#   'title': 'BOULEVARD MOB',
#   'description': 'A Fateful Epistle of a Moose And a Monkey who must Confront a Lumberjack in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 130.1731268202,
#   'replacement_cost': 11.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 91,
#   'title': 'BOUND CHEAPER',
#   'description': 'A Thrilling Panorama of a Database Administrator And a Astronaut who must Challenge a Lumberjack in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 114.7300960333,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 92,
#   'title': 'BOWFINGER GABLES',
#   'description': 'A Fast-Paced Yarn of a Waitress And a Composer who must Outgun a Dentist in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 103.3525677955,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 93,
#   'title': 'BRANNIGAN SUNRISE',
#   'description': 'A Amazing Epistle of a Moose And a Crocodile who must Outrace a Dog in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 105.2451433658,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 94,
#   'title': 'BRAVEHEART HUMAN',
#   'description': 'A Insightful Story of a Dog And a Pastry Chef who must Battle a Girl in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 100.6523187224,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 95,
#   'title': 'BREAKFAST GOLDFINGER',
#   'description': 'A Beautiful Reflection of a Student And a Student who must Fight a Moose in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 96.6817557978,
#   'replacement_cost': 18.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 96,
#   'title': 'BREAKING HOME',
#   'description': 'A Beautiful Display of a Secret Agent And a Monkey who must Battle a Sumo Wrestler in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 122.3321265574,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 97,
#   'title': 'BRIDE INTRIGUE',
#   'description': 'A Epic Tale of a Robot And a Monkey who must Vanquish a Man in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 62.6358407058,
#   'replacement_cost': 24.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 98,
#   'title': 'BRIGHT ENCOUNTERS',
#   'description': 'A Fateful Yarn of a Lumberjack And a Feminist who must Conquer a Student in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 119.6636828821,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 99,
#   'title': 'BRINGING HYSTERICAL',
#   'description': 'A Fateful Saga of a A Shark And a Technical Writer who must Find a Woman in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 102.1330754637,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 100,
#   'title': 'BROOKLYN DESERT',
#   'description': 'A Beautiful Drama of a Dentist And a Composer who must Battle a Sumo Wrestler in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 151.8990815161,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 101,
#   'title': 'BROTHERHOOD BLANKET',
#   'description': 'A Fateful Character Study of a Butler And a Technical Writer who must Sink a Astronaut in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 128.4794731054,
#   'replacement_cost': 26.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 102,
#   'title': 'BUBBLE GROSSE',
#   'description': 'A Awe-Inspiring Panorama of a Crocodile And a Moose who must Confront a Girl in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 165.2677900197,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 103,
#   'title': 'BUCKET BROTHERHOOD',
#   'description': 'A Amazing Display of a Girl And a Womanizer who must Succumb a Lumberjack in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 106.1607402667,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 104,
#   'title': 'BUGSY SONG',
#   'description': 'A Awe-Inspiring Character Study of a Secret Agent And a Boat who must Find a Squirrel in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 78.7935947101,
#   'replacement_cost': 17.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 105,
#   'title': 'BULL SHAWSHANK',
#   'description': 'A Fanciful Drama of a Moose And a Squirrel who must Conquer a Pioneer in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 139.3449589313,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 106,
#   'title': 'BULWORTH COMMANDMENTS',
#   'description': 'A Amazing Display of a Mad Cow And a Pioneer who must Redeem a Sumo Wrestler in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 107.4403081623,
#   'replacement_cost': 14.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 107,
#   'title': 'BUNCH MINDS',
#   'description': 'A Emotional Story of a Feminist And a Feminist who must Escape a Pastry Chef in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 92.9107496167,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 108,
#   'title': 'BUTCH PANTHER',
#   'description': 'A Lacklusture Yarn of a Feminist And a Database Administrator who must Face a Hunter in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 90.3600646535,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 109,
#   'title': 'BUTTERFLY CHOCOLAT',
#   'description': 'A Fateful Story of a Girl And a Composer who must Conquer a Husband in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 75.6743920976,
#   'replacement_cost': 17.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 110,
#   'title': 'CABIN FLASH',
#   'description': 'A Stunning Epistle of a Boat And a Man who must Challenge a A Shark in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 112.2564612006,
#   'replacement_cost': 25.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 111,
#   'title': 'CADDYSHACK JEDI',
#   'description': 'A Awe-Inspiring Epistle of a Woman And a Madman who must Fight a Robot in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 90.7624608748,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 112,
#   'title': 'CALENDAR GUNFIGHT',
#   'description': 'A Thrilling Drama of a Frisbee And a Lumberjack who must Sink a Man in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 5.99,
#   'length': 80.3634134383,
#   'replacement_cost': 22.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 113,
#   'title': 'CALIFORNIA BIRDS',
#   'description': 'A Thrilling Yarn of a Database Administrator And a Robot who must Battle a Database Administrator in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 90.3030871656,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 114,
#   'title': 'CAMELOT VACATION',
#   'description': 'A Touching Character Study of a Woman And a Waitress who must Battle a Pastry Chef in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 85.4074339298,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 115,
#   'title': 'CAMPUS REMEMBER',
#   'description': 'A Astounding Drama of a Crocodile And a Mad Cow who must Build a Robot in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 127.9432335971,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 116,
#   'title': 'CANDIDATE PERDITION',
#   'description': 'A Brilliant Epistle of a Composer And a Database Administrator who must Vanquish a Mad Scientist in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 148.5938779566,
#   'replacement_cost': 10.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 117,
#   'title': 'CANDLES GRAPES',
#   'description': 'A Fanciful Character Study of a Monkey And a Explorer who must Build a Astronaut in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 100.2909840576,
#   'replacement_cost': 15.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 118,
#   'title': 'CANYON STOCK',
#   'description': 'A Thoughtful Reflection of a Waitress And a Feminist who must Escape a Squirrel in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 106.428157589,
#   'replacement_cost': 26.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 119,
#   'title': 'CAPER MOTIONS',
#   'description': 'A Fateful Saga of a Moose And a Car who must Pursue a Woman in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 95.8051984428,
#   'replacement_cost': 22.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 120,
#   'title': 'CARIBBEAN LIBERTY',
#   'description': 'A Fanciful Tale of a Pioneer And a Technical Writer who must Outgun a Pioneer in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 110.2131933543,
#   'replacement_cost': 16.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 121,
#   'title': 'CAROL TEXAS',
#   'description': 'A Astounding Character Study of a Composer And a Student who must Overcome a Composer in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 96.2268357758,
#   'replacement_cost': 15.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 122,
#   'title': 'CARRIE BUNCH',
#   'description': 'A Amazing Epistle of a Student And a Astronaut who must Discover a Frisbee in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 100.9339445343,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 123,
#   'title': 'CASABLANCA SUPER',
#   'description': 'A Amazing Panorama of a Crocodile And a Forensic Psychologist who must Pursue a Secret Agent in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 104.9605834447,
#   'replacement_cost': 22.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 124,
#   'title': 'CASPER DRAGONFLY',
#   'description': 'A Intrepid Documentary of a Boat And a Crocodile who must Chase a Robot in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 120.1442552794,
#   'replacement_cost': 16.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 125,
#   'title': 'CASSIDY WYOMING',
#   'description': 'A Intrepid Drama of a Frisbee And a Hunter who must Kill a Secret Agent in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 123.3084560003,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 126,
#   'title': 'CASUALTIES ENCINO',
#   'description': 'A Insightful Yarn of a A Shark And a Pastry Chef who must Face a Boy in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 77.7446653817,
#   'replacement_cost': 16.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 127,
#   'title': 'CAT CONEHEADS',
#   'description': 'A Fast-Paced Panorama of a Girl And a A Shark who must Confront a Boy in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 104.7903625808,
#   'replacement_cost': 14.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 128,
#   'title': 'CATCH AMISTAD',
#   'description': 'A Boring Reflection of a Lumberjack And a Feminist who must Discover a Woman in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 82.471798635,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 129,
#   'title': 'CAUSE DATE',
#   'description': 'A Taut Tale of a Explorer And a Pastry Chef who must Conquer a Hunter in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 139.2897373529,
#   'replacement_cost': 16.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 130,
#   'title': 'CELEBRITY HORN',
#   'description': 'A Amazing Documentary of a Secret Agent And a Astronaut who must Vanquish a Hunter in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 104.3836193364,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 131,
#   'title': 'CENTER DINOSAUR',
#   'description': 'A Beautiful Character Study of a Sumo Wrestler And a Dentist who must Find a Dog in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 102.1042331583,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 132,
#   'title': 'CHAINSAW UPTOWN',
#   'description': 'A Beautiful Documentary of a Boy And a Robot who must Discover a Squirrel in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 124.7022871714,
#   'replacement_cost': 25.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 133,
#   'title': 'CHAMBER ITALIAN',
#   'description': 'A Fateful Reflection of a Moose And a Husband who must Overcome a Monkey in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 85.516205297,
#   'replacement_cost': 14.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 134,
#   'title': 'CHAMPION FLATLINERS',
#   'description': 'A Amazing Story of a Mad Cow And a Dog who must Kill a Husband in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 104.87387182,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 135,
#   'title': 'CHANCE RESURRECTION',
#   'description': 'A Astounding Story of a Forensic Psychologist And a Forensic Psychologist who must Overcome a Moose in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 135.9263479389,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 136,
#   'title': 'CHAPLIN LICENSE',
#   'description': 'A Boring Drama of a Dog And a Forensic Psychologist who must Outrace a Explorer in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 115.9968260842,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 137,
#   'title': 'CHARADE DUFFEL',
#   'description': 'A Action-Packed Display of a Man And a Waitress who must Build a Dog in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 127.7533978944,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 138,
#   'title': 'CHARIOTS CONSPIRACY',
#   'description': 'A Unbelieveable Epistle of a Robot And a Husband who must Chase a Robot in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 120.9638578299,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 139,
#   'title': 'CHASING FIGHT',
#   'description': 'A Astounding Saga of a Technical Writer And a Butler who must Battle a Butler in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 111.9649722593,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 140,
#   'title': 'CHEAPER CLYDE',
#   'description': 'A Emotional Character Study of a Pioneer And a Girl who must Discover a Dog in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 91.1114972827,
#   'replacement_cost': 23.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 141,
#   'title': 'CHICAGO NORTH',
#   'description': 'A Fateful Yarn of a Mad Cow And a Waitress who must Battle a Student in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 85.9093833713,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 142,
#   'title': 'CHICKEN HELLFIGHTERS',
#   'description': 'A Emotional Drama of a Dog And a Explorer who must Outrace a Technical Writer in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 78.6249548427,
#   'replacement_cost': 24.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 143,
#   'title': 'CHILL LUCK',
#   'description': 'A Lacklusture Epistle of a Boat And a Technical Writer who must Fight a A Shark in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 123.5760492889,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 144,
#   'title': 'CHINATOWN GLADIATOR',
#   'description': 'A Brilliant Panorama of a Technical Writer And a Lumberjack who must Escape a Butler in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 101.8920351813,
#   'replacement_cost': 24.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 145,
#   'title': 'CHISUM BEHAVIOR',
#   'description': 'A Epic Documentary of a Sumo Wrestler And a Butler who must Kill a Car in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 87.9092727529,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 146,
#   'title': 'CHITTY LOCK',
#   'description': 'A Boring Epistle of a Boat And a Database Administrator who must Kill a Sumo Wrestler in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 86.8458415826,
#   'replacement_cost': 24.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 147,
#   'title': 'CHOCOLAT HARRY',
#   'description': 'A Action-Packed Epistle of a Dentist And a Moose who must Meet a Mad Cow in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 1.99,
#   'length': 84.2272905418,
#   'replacement_cost': 16.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 148,
#   'title': 'CHOCOLATE DUCK',
#   'description': 'A Unbelieveable Story of a Mad Scientist And a Technical Writer who must Discover a Composer in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 126.3904678128,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 149,
#   'title': 'CHRISTMAS MOONSHINE',
#   'description': 'A Action-Packed Epistle of a Feminist And a Astronaut who must Conquer a Boat in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 75.5342834998,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 150,
#   'title': 'CIDER DESIRE',
#   'description': 'A Stunning Character Study of a Composer And a Mad Cow who must Succumb a Cat in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 106.703450599,
#   'replacement_cost': 9.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 151,
#   'title': 'CINCINATTI WHISPERER',
#   'description': 'A Brilliant Saga of a Pastry Chef And a Hunter who must Confront a Butler in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 107.3309193446,
#   'replacement_cost': 26.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 152,
#   'title': 'CIRCUS YOUTH',
#   'description': 'A Thoughtful Drama of a Pastry Chef And a Dentist who must Pursue a Girl in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 105.4774792277,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 153,
#   'title': 'CITIZEN SHREK',
#   'description': 'A Fanciful Character Study of a Technical Writer And a Husband who must Redeem a Robot in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 113.3909599328,
#   'replacement_cost': 18.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 154,
#   'title': 'CLASH FREDDY',
#   'description': 'A Amazing Yarn of a Composer And a Squirrel who must Escape a Astronaut in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 110.6486931941,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 155,
#   'title': 'CLEOPATRA DEVIL',
#   'description': 'A Fanciful Documentary of a Crocodile And a Technical Writer who must Fight a A Shark in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 85.3550769053,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 156,
#   'title': 'CLERKS ANGELS',
#   'description': 'A Thrilling Display of a Sumo Wrestler And a Girl who must Confront a Man in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 100.7538984899,
#   'replacement_cost': 15.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 157,
#   'title': 'CLOCKWORK PARADISE',
#   'description': 'A Insightful Documentary of a Technical Writer And a Feminist who must Challenge a Cat in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 109.592198117,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 158,
#   'title': 'CLONES PINOCCHIO',
#   'description': 'A Amazing Drama of a Car And a Robot who must Pursue a Dentist in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 153.2002319651,
#   'replacement_cost': 16.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 159,
#   'title': 'CLOSER BANG',
#   'description': 'A Unbelieveable Panorama of a Frisbee And a Hunter who must Vanquish a Monkey in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 123.2670132941,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 160,
#   'title': 'CLUB GRAFFITI',
#   'description': 'A Epic Tale of a Pioneer And a Hunter who must Escape a Girl in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 151.0588926378,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 161,
#   'title': 'CLUE GRAIL',
#   'description': 'A Taut Tale of a Butler And a Mad Scientist who must Build a Crocodile in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 92.7628271008,
#   'replacement_cost': 27.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 162,
#   'title': 'CLUELESS BUCKET',
#   'description': 'A Taut Tale of a Car And a Pioneer who must Conquer a Sumo Wrestler in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 134.1760118312,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 163,
#   'title': 'CLYDE THEORY',
#   'description': 'A Beautiful Yarn of a Astronaut And a Frisbee who must Overcome a Explorer in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 129.5773603131,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 164,
#   'title': 'COAST RAINBOW',
#   'description': 'A Astounding Documentary of a Mad Cow And a Pioneer who must Challenge a Butler in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 85.6370542302,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 165,
#   'title': 'COLDBLOODED DARLING',
#   'description': 'A Brilliant Panorama of a Dentist And a Moose who must Find a Student in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 105.6382710305,
#   'replacement_cost': 27.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 166,
#   'title': 'COLOR PHILADELPHIA',
#   'description': 'A Thoughtful Panorama of a Car And a Crocodile who must Sink a Monkey in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 88.8343241816,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 167,
#   'title': 'COMA HEAD',
#   'description': 'A Awe-Inspiring Drama of a Boy And a Frisbee who must Escape a Pastry Chef in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 136.4831436308,
#   'replacement_cost': 10.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 168,
#   'title': 'COMANCHEROS ENEMY',
#   'description': 'A Boring Saga of a Lumberjack And a Monkey who must Find a Monkey in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 148.1184864916,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 169,
#   'title': 'COMFORTS RUSH',
#   'description': 'A Unbelieveable Panorama of a Pioneer And a Husband who must Meet a Mad Cow in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 137.3086076977,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 170,
#   'title': 'COMMAND DARLING',
#   'description': 'A Awe-Inspiring Tale of a Forensic Psychologist And a Woman who must Challenge a Database Administrator in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 127.9136561369,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 171,
#   'title': 'COMMANDMENTS EXPRESS',
#   'description': 'A Fanciful Saga of a Student And a Mad Scientist who must Battle a Hunter in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 98.9906914977,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 172,
#   'title': 'CONEHEADS SMOOCHY',
#   'description': 'A Touching Story of a Womanizer And a Composer who must Pursue a Husband in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 86.7761956688,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 173,
#   'title': 'CONFESSIONS MAGUIRE',
#   'description': 'A Insightful Story of a Car And a Boy who must Battle a Technical Writer in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 116.2027979955,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 174,
#   'title': 'CONFIDENTIAL INTERVIEW',
#   'description': 'A Stunning Reflection of a Cat And a Woman who must Find a Astronaut in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 96.7893110882,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 175,
#   'title': 'CONFUSED CANDLES',
#   'description': 'A Stunning Epistle of a Cat And a Forensic Psychologist who must Confront a Pioneer in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 112.1372541364,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 176,
#   'title': 'CONGENIALITY QUEST',
#   'description': 'A Touching Documentary of a Cat And a Pastry Chef who must Find a Lumberjack in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 116.514734988,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 177,
#   'title': 'CONNECTICUT TRAMP',
#   'description': 'A Unbelieveable Drama of a Crocodile And a Mad Cow who must Reach a Dentist in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 107.9155527761,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 178,
#   'title': 'CONNECTION MICROCOSMOS',
#   'description': 'A Fateful Documentary of a Crocodile And a Husband who must Face a Husband in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 96.0280327046,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 179,
#   'title': 'CONQUERER NUTS',
#   'description': 'A Taut Drama of a Mad Scientist And a Man who must Escape a Pioneer in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 5.99,
#   'length': 91.3342378847,
#   'replacement_cost': 14.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 180,
#   'title': 'CONSPIRACY SPIRIT',
#   'description': 'A Awe-Inspiring Story of a Student And a Frisbee who must Conquer a Crocodile in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 94.4260925072,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 181,
#   'title': 'CONTACT ANONYMOUS',
#   'description': 'A Insightful Display of a A Shark And a Monkey who must Face a Database Administrator in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 80.2638524666,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 182,
#   'title': 'CONTROL ANTHEM',
#   'description': 'A Fateful Documentary of a Robot And a Student who must Battle a Cat in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 114.7263243124,
#   'replacement_cost': 9.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 183,
#   'title': 'CONVERSATION DOWNHILL',
#   'description': 'A Taut Character Study of a Husband And a Waitress who must Sink a Squirrel in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 109.8784546712,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 184,
#   'title': 'CORE SUIT',
#   'description': 'A Unbelieveable Tale of a Car And a Explorer who must Confront a Boat in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 141.5650014978,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 185,
#   'title': 'COWBOY DOOM',
#   'description': 'A Astounding Drama of a Boy And a Lumberjack who must Fight a Butler in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 95.8913148103,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 186,
#   'title': 'CRAFT OUTFIELD',
#   'description': 'A Lacklusture Display of a Explorer And a Hunter who must Succumb a Database Administrator in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 125.7961031416,
#   'replacement_cost': 17.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 187,
#   'title': 'CRANES RESERVOIR',
#   'description': 'A Fanciful Documentary of a Teacher And a Dog who must Outgun a Forensic Psychologist in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 139.2024658116,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 188,
#   'title': 'CRAZY HOME',
#   'description': 'A Fanciful Panorama of a Boy And a Woman who must Vanquish a Database Administrator in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 113.2094746944,
#   'replacement_cost': 24.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 189,
#   'title': 'CREATURES SHAKESPEARE',
#   'description': 'A Emotional Drama of a Womanizer And a Squirrel who must Vanquish a Crocodile in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 116.3287423063,
#   'replacement_cost': 23.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 190,
#   'title': 'CREEPERS KANE',
#   'description': 'A Awe-Inspiring Reflection of a Squirrel And a Boat who must Outrace a Car in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 126.1838341559,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 191,
#   'title': 'CROOKED FROGMEN',
#   'description': 'A Unbelieveable Drama of a Hunter And a Database Administrator who must Battle a Crocodile in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 127.8869558748,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 192,
#   'title': 'CROSSING DIVORCE',
#   'description': 'A Beautiful Documentary of a Dog And a Robot who must Redeem a Womanizer in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 142.4763178918,
#   'replacement_cost': 19.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 193,
#   'title': 'CROSSROADS CASUALTIES',
#   'description': 'A Intrepid Documentary of a Sumo Wrestler And a Astronaut who must Battle a Composer in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 109.8547542894,
#   'replacement_cost': 20.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 194,
#   'title': 'CROW GREASE',
#   'description': 'A Awe-Inspiring Documentary of a Woman And a Husband who must Sink a Database Administrator in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 122.111590979,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 195,
#   'title': 'CROWDS TELEMARK',
#   'description': 'A Intrepid Documentary of a Astronaut And a Forensic Psychologist who must Find a Frisbee in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 125.695760908,
#   'replacement_cost': 16.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 196,
#   'title': 'CRUELTY UNFORGIVEN',
#   'description': 'A Brilliant Tale of a Car And a Moose who must Battle a Dentist in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 61.3027881745,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 197,
#   'title': 'CRUSADE HONEY',
#   'description': 'A Fast-Paced Reflection of a Explorer And a Butler who must Battle a Madman in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 152.7254789606,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 198,
#   'title': 'CRYSTAL BREAKING',
#   'description': 'A Fast-Paced Character Study of a Feminist And a Explorer who must Face a Pastry Chef in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 114.6067205607,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 199,
#   'title': 'CUPBOARD SINNERS',
#   'description': 'A Emotional Reflection of a Frisbee And a Boat who must Reach a Pastry Chef in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 128.8853225039,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 200,
#   'title': 'CURTAIN VIDEOTAPE',
#   'description': 'A Boring Reflection of a Dentist And a Mad Cow who must Chase a Secret Agent in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 102.6350737402,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 201,
#   'title': 'CYCLONE FAMILY',
#   'description': 'A Lacklusture Drama of a Student And a Monkey who must Sink a Womanizer in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 123.3406204433,
#   'replacement_cost': 18.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 202,
#   'title': 'DADDY PITTSBURGH',
#   'description': 'A Epic Story of a A Shark And a Student who must Confront a Explorer in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 117.5390480396,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 203,
#   'title': 'DAISY MENAGERIE',
#   'description': 'A Fast-Paced Saga of a Pastry Chef And a Monkey who must Sink a Composer in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 100.535664641,
#   'replacement_cost': 9.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 204,
#   'title': 'DALMATIONS SWEDEN',
#   'description': 'A Emotional Epistle of a Moose And a Hunter who must Overcome a Robot in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 121.8094692401,
#   'replacement_cost': 25.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 205,
#   'title': 'DANCES NONE',
#   'description': 'A Insightful Reflection of a A Shark And a Dog who must Kill a Butler in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 112.7381254254,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 206,
#   'title': 'DANCING FEVER',
#   'description': 'A Stunning Story of a Explorer And a Forensic Psychologist who must Face a Crocodile in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 83.241462999,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 207,
#   'title': 'DANGEROUS UPTOWN',
#   'description': 'A Unbelieveable Story of a Mad Scientist And a Woman who must Overcome a Dog in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 67.7300142963,
#   'replacement_cost': 26.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 208,
#   'title': 'DARES PLUTO',
#   'description': 'A Fateful Story of a Robot And a Dentist who must Defeat a Astronaut in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 91.3948635137,
#   'replacement_cost': 16.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 209,
#   'title': 'DARKNESS WAR',
#   'description': 'A Touching Documentary of a Husband And a Hunter who must Escape a Boy in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 140.360794205,
#   'replacement_cost': 24.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 210,
#   'title': 'DARKO DORADO',
#   'description': 'A Stunning Reflection of a Frisbee And a Husband who must Redeem a Dog in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 94.0991263501,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 211,
#   'title': 'DARLING BREAKING',
#   'description': 'A Brilliant Documentary of a Astronaut And a Squirrel who must Succumb a Student in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 124.396405998,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 212,
#   'title': 'DARN FORRESTER',
#   'description': 'A Fateful Story of a A Shark And a Explorer who must Succumb a Technical Writer in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 89.6340878695,
#   'replacement_cost': 14.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 214,
#   'title': 'DAUGHTER MADIGAN',
#   'description': 'A Beautiful Tale of a Hunter And a Mad Scientist who must Confront a Squirrel in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 112.4746022917,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 215,
#   'title': 'DAWN POND',
#   'description': 'A Thoughtful Documentary of a Dentist And a Forensic Psychologist who must Defeat a Waitress in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 107.808328972,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 216,
#   'title': 'DAY UNFAITHFUL',
#   'description': 'A Stunning Documentary of a Composer And a Mad Scientist who must Find a Technical Writer in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 107.0749234813,
#   'replacement_cost': 16.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 217,
#   'title': 'DAZED PUNK',
#   'description': 'A Action-Packed Story of a Pioneer And a Technical Writer who must Discover a Forensic Psychologist in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 107.6228970529,
#   'replacement_cost': 20.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 218,
#   'title': 'DECEIVER BETRAYED',
#   'description': 'A Taut Story of a Moose And a Squirrel who must Build a Husband in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 118.6006210035,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 219,
#   'title': 'DEEP CRUSADE',
#   'description': 'A Amazing Tale of a Crocodile And a Squirrel who must Discover a Composer in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 107.7430388738,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 220,
#   'title': 'DEER VIRGINIAN',
#   'description': 'A Thoughtful Story of a Mad Cow And a Womanizer who must Overcome a Mad Scientist in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 103.5483999128,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 221,
#   'title': 'DELIVERANCE MULHOLLAND',
#   'description': 'A Astounding Saga of a Monkey And a Moose who must Conquer a Butler in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 142.4986320275,
#   'replacement_cost': 9.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 222,
#   'title': 'DESERT POSEIDON',
#   'description': 'A Brilliant Documentary of a Butler And a Frisbee who must Build a Astronaut in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 119.2089865043,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 223,
#   'title': 'DESIRE ALIEN',
#   'description': 'A Fast-Paced Tale of a Dog And a Forensic Psychologist who must Meet a Astronaut in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 64.6735307258,
#   'replacement_cost': 24.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 224,
#   'title': 'DESPERATE TRAINSPOTTING',
#   'description': 'A Epic Yarn of a Forensic Psychologist And a Teacher who must Face a Lumberjack in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 102.8256452829,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 225,
#   'title': 'DESTINATION JERK',
#   'description': 'A Beautiful Yarn of a Teacher And a Cat who must Build a Car in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 108.9985366029,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 226,
#   'title': 'DESTINY SATURDAY',
#   'description': 'A Touching Drama of a Crocodile And a Crocodile who must Conquer a Explorer in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 5.99,
#   'length': 92.1128831894,
#   'replacement_cost': 20.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 227,
#   'title': 'DETAILS PACKER',
#   'description': 'A Epic Saga of a Waitress And a Composer who must Face a Boat in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 147.3890823468,
#   'replacement_cost': 17.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 228,
#   'title': 'DETECTIVE VISION',
#   'description': 'A Fanciful Documentary of a Pioneer And a Woman who must Redeem a Hunter in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 111.9781111662,
#   'replacement_cost': 16.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 229,
#   'title': 'DEVIL DESIRE',
#   'description': 'A Beautiful Reflection of a Monkey And a Dentist who must Face a Database Administrator in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 142.9377860751,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 230,
#   'title': 'DIARY PANIC',
#   'description': 'A Thoughtful Character Study of a Frisbee And a Mad Cow who must Outgun a Man in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 90.5371251875,
#   'replacement_cost': 20.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 231,
#   'title': 'DINOSAUR SECRETARY',
#   'description': 'A Action-Packed Drama of a Feminist And a Girl who must Reach a Robot in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 158.0427533075,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 232,
#   'title': 'DIRTY ACE',
#   'description': 'A Action-Packed Character Study of a Forensic Psychologist And a Girl who must Build a Dentist in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 103.9628242361,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 233,
#   'title': 'DISCIPLE MOTHER',
#   'description': 'A Touching Reflection of a Mad Scientist And a Boat who must Face a Moose in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 116.5524499621,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 234,
#   'title': 'DISTURBING SCARFACE',
#   'description': 'A Lacklusture Display of a Crocodile And a Butler who must Overcome a Monkey in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 123.6233908553,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 235,
#   'title': 'DIVIDE MONSTER',
#   'description': 'A Intrepid Saga of a Man And a Forensic Psychologist who must Reach a Squirrel in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 124.4320375159,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 236,
#   'title': 'DIVINE RESURRECTION',
#   'description': 'A Boring Character Study of a Man And a Womanizer who must Succumb a Teacher in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 112.5735025499,
#   'replacement_cost': 19.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 237,
#   'title': 'DIVORCE SHINING',
#   'description': 'A Unbelieveable Saga of a Crocodile And a Student who must Discover a Cat in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 102.4808500712,
#   'replacement_cost': 21.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 238,
#   'title': 'DOCTOR GRAIL',
#   'description': 'A Insightful Drama of a Womanizer And a Waitress who must Reach a Forensic Psychologist in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 88.6287388223,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 239,
#   'title': 'DOGMA FAMILY',
#   'description': 'A Brilliant Character Study of a Database Administrator And a Monkey who must Succumb a Astronaut in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 76.5290245082,
#   'replacement_cost': 16.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 240,
#   'title': 'DOLLS RAGE',
#   'description': 'A Thrilling Display of a Pioneer And a Frisbee who must Escape a Teacher in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 113.1492250475,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 241,
#   'title': 'DONNIE ALLEY',
#   'description': 'A Awe-Inspiring Tale of a Butler And a Frisbee who must Vanquish a Teacher in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 142.4445633714,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 242,
#   'title': 'DOOM DANCING',
#   'description': 'A Astounding Panorama of a Car And a Mad Scientist who must Battle a Lumberjack in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 134.7616805183,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 243,
#   'title': 'DOORS PRESIDENT',
#   'description': 'A Awe-Inspiring Display of a Squirrel And a Woman who must Overcome a Boy in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 122.0658178576,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 244,
#   'title': 'DORADO NOTTING',
#   'description': 'A Action-Packed Tale of a Sumo Wrestler And a A Shark who must Meet a Frisbee in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 108.5817604059,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 245,
#   'title': 'DOUBLE WRATH',
#   'description': 'A Thoughtful Yarn of a Womanizer And a Dog who must Challenge a Madman in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 109.9209783578,
#   'replacement_cost': 28.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 246,
#   'title': 'DOUBTFIRE LABYRINTH',
#   'description': 'A Intrepid Panorama of a Butler And a Composer who must Meet a Mad Cow in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 141.9981723314,
#   'replacement_cost': 16.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 247,
#   'title': 'DOWNHILL ENOUGH',
#   'description': 'A Emotional Tale of a Pastry Chef And a Forensic Psychologist who must Succumb a Monkey in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 80.6494765561,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 248,
#   'title': 'DOZEN LION',
#   'description': 'A Taut Drama of a Cat And a Girl who must Defeat a Frisbee in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 97.0746973217,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 249,
#   'title': 'DRACULA CRYSTAL',
#   'description': 'A Thrilling Reflection of a Feminist And a Cat who must Find a Frisbee in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 87.9052785012,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 250,
#   'title': 'DRAGON SQUAD',
#   'description': 'A Taut Reflection of a Boy And a Waitress who must Outgun a Teacher in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 94.987748079,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 251,
#   'title': 'DRAGONFLY STRANGERS',
#   'description': 'A Boring Documentary of a Pioneer And a Man who must Vanquish a Man in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 123.9555073587,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 252,
#   'title': 'DREAM PICKUP',
#   'description': 'A Epic Display of a Car And a Composer who must Overcome a Forensic Psychologist in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 118.3712969389,
#   'replacement_cost': 18.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 253,
#   'title': 'DRIFTER COMMANDMENTS',
#   'description': 'A Epic Reflection of a Womanizer And a Squirrel who must Discover a Husband in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 128.2679272734,
#   'replacement_cost': 18.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 254,
#   'title': 'DRIVER ANNIE',
#   'description': 'A Lacklusture Character Study of a Butler And a Car who must Redeem a Boat in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 129.4545668611,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 255,
#   'title': 'DRIVING POLISH',
#   'description': 'A Action-Packed Yarn of a Feminist And a Technical Writer who must Sink a Boat in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 100.7505283117,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 256,
#   'title': 'DROP WATERFRONT',
#   'description': 'A Fanciful Documentary of a Husband And a Explorer who must Reach a Madman in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 123.0122869544,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 257,
#   'title': 'DRUMLINE CYCLONE',
#   'description': 'A Insightful Panorama of a Monkey And a Sumo Wrestler who must Outrace a Mad Scientist in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 69.4529221843,
#   'replacement_cost': 14.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 258,
#   'title': 'DRUMS DYNAMITE',
#   'description': 'A Epic Display of a Crocodile And a Crocodile who must Confront a Dog in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 93.3701210955,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 259,
#   'title': 'DUCK RACER',
#   'description': 'A Lacklusture Yarn of a Teacher And a Squirrel who must Overcome a Dog in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 99.2954858098,
#   'replacement_cost': 15.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 260,
#   'title': 'DUDE BLINDNESS',
#   'description': 'A Stunning Reflection of a Husband And a Lumberjack who must Face a Frisbee in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 97.1581417687,
#   'replacement_cost': 9.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 261,
#   'title': 'DUFFEL APOCALYPSE',
#   'description': 'A Emotional Display of a Boat And a Explorer who must Challenge a Madman in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 1.99,
#   'length': 88.6250236588,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 262,
#   'title': 'DUMBO LUST',
#   'description': 'A Touching Display of a Feminist And a Dentist who must Conquer a Husband in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 1.99,
#   'length': 94.5136810273,
#   'replacement_cost': 17.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 263,
#   'title': 'DURHAM PANKY',
#   'description': 'A Brilliant Panorama of a Girl And a Boy who must Face a Mad Scientist in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 146.0462080589,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 264,
#   'title': 'DWARFS ALTER',
#   'description': 'A Emotional Yarn of a Girl And a Dog who must Challenge a Composer in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 110.3088612524,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 265,
#   'title': 'DYING MAKER',
#   'description': 'A Intrepid Tale of a Boat And a Monkey who must Kill a Cat in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 90.9100802214,
#   'replacement_cost': 28.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 266,
#   'title': 'DYNAMITE TARZAN',
#   'description': 'A Intrepid Documentary of a Forensic Psychologist And a Mad Scientist who must Face a Explorer in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 120.3349863828,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 267,
#   'title': 'EAGLES PANKY',
#   'description': 'A Thoughtful Story of a Car And a Boy who must Find a A Shark in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 82.3445478881,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 268,
#   'title': 'EARLY HOME',
#   'description': 'A Amazing Panorama of a Mad Scientist And a Husband who must Meet a Woman in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 104.7732417388,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 269,
#   'title': 'EARRING INSTINCT',
#   'description': 'A Stunning Character Study of a Dentist And a Mad Cow who must Find a Teacher in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 126.2172943165,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 270,
#   'title': 'EARTH VISION',
#   'description': 'A Stunning Drama of a Butler And a Madman who must Outrace a Womanizer in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 124.8852817878,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 271,
#   'title': 'EASY GLADIATOR',
#   'description': 'A Fateful Story of a Monkey And a Girl who must Overcome a Pastry Chef in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 108.6208724822,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 272,
#   'title': 'EDGE KISSING',
#   'description': 'A Beautiful Yarn of a Composer And a Mad Cow who must Redeem a Mad Scientist in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 104.7315026092,
#   'replacement_cost': 9.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 273,
#   'title': 'EFFECT GLADIATOR',
#   'description': 'A Beautiful Display of a Pastry Chef And a Pastry Chef who must Outgun a Forensic Psychologist in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 104.393116287,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 274,
#   'title': 'EGG IGBY',
#   'description': 'A Beautiful Documentary of a Boat And a Sumo Wrestler who must Succumb a Database Administrator in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 104.8905656603,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 275,
#   'title': 'EGYPT TENENBAUMS',
#   'description': 'A Intrepid Story of a Madman And a Secret Agent who must Outrace a Astronaut in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 89.6740349151,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 276,
#   'title': 'ELEMENT FREDDY',
#   'description': 'A Awe-Inspiring Reflection of a Waitress And a Squirrel who must Kill a Mad Cow in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 110.8116405441,
#   'replacement_cost': 28.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 277,
#   'title': 'ELEPHANT TROJAN',
#   'description': 'A Beautiful Panorama of a Lumberjack And a Forensic Psychologist who must Overcome a Frisbee in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 110.5544921459,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 278,
#   'title': 'ELF MURDER',
#   'description': 'A Action-Packed Story of a Frisbee And a Woman who must Reach a Girl in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 129.1378251444,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 279,
#   'title': 'ELIZABETH SHANE',
#   'description': 'A Lacklusture Display of a Womanizer And a Dog who must Face a Sumo Wrestler in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 136.8764568783,
#   'replacement_cost': 11.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 280,
#   'title': 'EMPIRE MALKOVICH',
#   'description': 'A Amazing Story of a Feminist And a Cat who must Face a Car in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 87.6420362975,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 281,
#   'title': 'ENCINO ELF',
#   'description': 'A Astounding Drama of a Feminist And a Teacher who must Confront a Husband in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 81.6356500989,
#   'replacement_cost': 9.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 282,
#   'title': 'ENCOUNTERS CURTAIN',
#   'description': 'A Insightful Epistle of a Pastry Chef And a Womanizer who must Build a Boat in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 103.4204455801,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 283,
#   'title': 'ENDING CROWDS',
#   'description': 'A Unbelieveable Display of a Dentist And a Madman who must Vanquish a Squirrel in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 99.8872093359,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 284,
#   'title': 'ENEMY ODDS',
#   'description': 'A Fanciful Panorama of a Mad Scientist And a Woman who must Pursue a Astronaut in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 119.2577412592,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 285,
#   'title': 'ENGLISH BULWORTH',
#   'description': 'A Intrepid Epistle of a Pastry Chef And a Pastry Chef who must Pursue a Crocodile in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 121.9490992629,
#   'replacement_cost': 18.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 286,
#   'title': 'ENOUGH RAGING',
#   'description': 'A Astounding Character Study of a Boat And a Secret Agent who must Find a Mad Cow in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 69.5565048891,
#   'replacement_cost': 16.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 287,
#   'title': 'ENTRAPMENT SATISFACTION',
#   'description': 'A Thoughtful Panorama of a Hunter And a Teacher who must Reach a Mad Cow in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 137.3544001117,
#   'replacement_cost': 19.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 288,
#   'title': 'ESCAPE METROPOLIS',
#   'description': 'A Taut Yarn of a Astronaut And a Technical Writer who must Outgun a Boat in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 138.9032711437,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 289,
#   'title': 'EVE RESURRECTION',
#   'description': 'A Awe-Inspiring Yarn of a Pastry Chef And a Database Administrator who must Challenge a Teacher in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 88.9310069938,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 290,
#   'title': 'EVERYONE CRAFT',
#   'description': 'A Fateful Display of a Waitress And a Dentist who must Reach a Butler in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 109.6956234153,
#   'replacement_cost': 29.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 291,
#   'title': 'EVOLUTION ALTER',
#   'description': 'A Fanciful Character Study of a Feminist And a Madman who must Find a Explorer in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 117.8697600689,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 292,
#   'title': 'EXCITEMENT EVE',
#   'description': 'A Brilliant Documentary of a Monkey And a Car who must Conquer a Crocodile in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 108.7046886239,
#   'replacement_cost': 20.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 293,
#   'title': 'EXORCIST STING',
#   'description': 'A Touching Drama of a Dog And a Sumo Wrestler who must Conquer a Mad Scientist in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 86.0238463745,
#   'replacement_cost': 17.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 294,
#   'title': 'EXPECATIONS NATURAL',
#   'description': 'A Amazing Drama of a Butler And a Husband who must Reach a A Shark in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 73.3024446881,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 295,
#   'title': 'EXPENDABLE STALLION',
#   'description': 'A Amazing Character Study of a Mad Cow And a Squirrel who must Discover a Hunter in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 82.739683449,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 296,
#   'title': 'EXPRESS LONELY',
#   'description': 'A Boring Drama of a Astronaut And a Boat who must Face a Boat in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 145.8799489222,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 297,
#   'title': 'EXTRAORDINARY CONQUERER',
#   'description': 'A Stunning Story of a Dog And a Feminist who must Face a Forensic Psychologist in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 100.558459836,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 298,
#   'title': 'EYES DRIVING',
#   'description': 'A Thrilling Story of a Cat And a Waitress who must Fight a Explorer in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 103.9088101793,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 299,
#   'title': 'FACTORY DRAGON',
#   'description': 'A Action-Packed Saga of a Teacher And a Frisbee who must Escape a Lumberjack in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 106.4419486244,
#   'replacement_cost': 9.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 300,
#   'title': 'FALCON VOLUME',
#   'description': 'A Fateful Saga of a Sumo Wrestler And a Hunter who must Redeem a A Shark in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 100.5949571946,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 301,
#   'title': 'FAMILY SWEET',
#   'description': 'A Epic Documentary of a Teacher And a Boy who must Escape a Woman in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 139.8039638227,
#   'replacement_cost': 24.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 302,
#   'title': 'FANTASIA PARK',
#   'description': 'A Thoughtful Documentary of a Mad Scientist And a A Shark who must Outrace a Feminist in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 100.6213543549,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 303,
#   'title': 'FANTASY TROOPERS',
#   'description': 'A Touching Saga of a Teacher And a Monkey who must Overcome a Secret Agent in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 96.6045760017,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 304,
#   'title': 'FARGO GANDHI',
#   'description': 'A Thrilling Reflection of a Pastry Chef And a Crocodile who must Reach a Teacher in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 95.9586603245,
#   'replacement_cost': 28.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 305,
#   'title': 'FATAL HAUNTED',
#   'description': 'A Beautiful Drama of a Student And a Secret Agent who must Confront a Dentist in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 83.3589800193,
#   'replacement_cost': 24.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 306,
#   'title': 'FEATHERS METAL',
#   'description': 'A Thoughtful Yarn of a Monkey And a Teacher who must Find a Dog in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 133.845615843,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 307,
#   'title': 'FELLOWSHIP AUTUMN',
#   'description': 'A Lacklusture Reflection of a Dentist And a Hunter who must Meet a Teacher in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 106.2606265433,
#   'replacement_cost': 9.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 308,
#   'title': 'FERRIS MOTHER',
#   'description': 'A Touching Display of a Frisbee And a Frisbee who must Kill a Girl in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 106.047939794,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 309,
#   'title': 'FEUD FROGMEN',
#   'description': 'A Brilliant Reflection of a Database Administrator And a Mad Cow who must Chase a Woman in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 124.3732140009,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 310,
#   'title': 'FEVER EMPIRE',
#   'description': 'A Insightful Panorama of a Cat And a Boat who must Defeat a Boat in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 111.5356024711,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 311,
#   'title': 'FICTION CHRISTMAS',
#   'description': 'A Emotional Yarn of a A Shark And a Student who must Battle a Robot in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 97.7226340594,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 312,
#   'title': 'FIDDLER LOST',
#   'description': 'A Boring Tale of a Squirrel And a Dog who must Challenge a Madman in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 125.7187225685,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 313,
#   'title': 'FIDELITY DEVIL',
#   'description': 'A Awe-Inspiring Drama of a Technical Writer And a Composer who must Reach a Pastry Chef in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 88.2954205868,
#   'replacement_cost': 11.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 314,
#   'title': 'FIGHT JAWBREAKER',
#   'description': 'A Intrepid Panorama of a Womanizer And a Girl who must Escape a Girl in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 120.1461982142,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 315,
#   'title': 'FINDING ANACONDA',
#   'description': 'A Fateful Tale of a Database Administrator And a Girl who must Battle a Squirrel in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 136.0711518623,
#   'replacement_cost': 10.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 316,
#   'title': 'FIRE WOLVES',
#   'description': 'A Intrepid Documentary of a Frisbee And a Dog who must Outrace a Lumberjack in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 148.449846279,
#   'replacement_cost': 18.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 317,
#   'title': 'FIREBALL PHILADELPHIA',
#   'description': 'A Amazing Yarn of a Dentist And a A Shark who must Vanquish a Madman in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 112.0470986884,
#   'replacement_cost': 25.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 318,
#   'title': 'FIREHOUSE VIETNAM',
#   'description': 'A Awe-Inspiring Character Study of a Boat And a Boy who must Kill a Pastry Chef in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 77.5585715593,
#   'replacement_cost': 14.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 319,
#   'title': 'FISH OPUS',
#   'description': 'A Touching Display of a Feminist And a Girl who must Confront a Astronaut in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 141.7394782668,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 320,
#   'title': 'FLAMINGOS CONNECTICUT',
#   'description': 'A Fast-Paced Reflection of a Composer And a Composer who must Meet a Cat in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 108.2032724783,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 321,
#   'title': 'FLASH WARS',
#   'description': 'A Astounding Saga of a Moose And a Pastry Chef who must Chase a Student in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 121.8427580412,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 322,
#   'title': 'FLATLINERS KILLER',
#   'description': 'A Taut Display of a Secret Agent And a Waitress who must Sink a Robot in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 72.4128594686,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 323,
#   'title': 'FLIGHT LIES',
#   'description': 'A Stunning Character Study of a Crocodile And a Pioneer who must Pursue a Teacher in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 119.5562317504,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 324,
#   'title': 'FLINTSTONES HAPPINESS',
#   'description': 'A Fateful Story of a Husband And a Moose who must Vanquish a Boy in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 89.9134278128,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 325,
#   'title': 'FLOATS GARDEN',
#   'description': 'A Action-Packed Epistle of a Robot And a Car who must Chase a Boat in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 78.8274813701,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 326,
#   'title': 'FLYING HOOK',
#   'description': 'A Thrilling Display of a Mad Cow And a Dog who must Challenge a Frisbee in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 133.0180221333,
#   'replacement_cost': 18.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 327,
#   'title': 'FOOL MOCKINGBIRD',
#   'description': 'A Lacklusture Tale of a Crocodile And a Composer who must Defeat a Madman in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 117.0936264102,
#   'replacement_cost': 24.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 328,
#   'title': 'FOREVER CANDIDATE',
#   'description': 'A Unbelieveable Panorama of a Technical Writer And a Man who must Pursue a Frisbee in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 102.9047073346,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 329,
#   'title': 'FORREST SONS',
#   'description': 'A Thrilling Documentary of a Forensic Psychologist And a Butler who must Defeat a Explorer in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 130.0803575877,
#   'replacement_cost': 15.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 330,
#   'title': 'FORRESTER COMANCHEROS',
#   'description': 'A Fateful Tale of a Squirrel And a Forensic Psychologist who must Redeem a Man in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 105.2945558866,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 331,
#   'title': 'FORWARD TEMPLE',
#   'description': 'A Astounding Display of a Forensic Psychologist And a Mad Scientist who must Challenge a Girl in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 103.9030867669,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 332,
#   'title': 'FRANKENSTEIN STRANGER',
#   'description': 'A Insightful Character Study of a Feminist And a Pioneer who must Pursue a Pastry Chef in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 116.1075685158,
#   'replacement_cost': 16.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 333,
#   'title': 'FREAKY POCUS',
#   'description': 'A Fast-Paced Documentary of a Pastry Chef And a Crocodile who must Chase a Squirrel in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 122.9387171079,
#   'replacement_cost': 16.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 334,
#   'title': 'FREDDY STORM',
#   'description': 'A Intrepid Saga of a Man And a Lumberjack who must Vanquish a Husband in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 149.4963146566,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 335,
#   'title': 'FREEDOM CLEOPATRA',
#   'description': 'A Emotional Reflection of a Dentist And a Mad Cow who must Face a Squirrel in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 99.1529090171,
#   'replacement_cost': 23.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 336,
#   'title': 'FRENCH HOLIDAY',
#   'description': 'A Thrilling Epistle of a Dog And a Feminist who must Kill a Madman in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 79.719888045,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 337,
#   'title': 'FRIDA SLIPPER',
#   'description': 'A Fateful Story of a Lumberjack And a Car who must Escape a Boat in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 139.221847502,
#   'replacement_cost': 11.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 338,
#   'title': 'FRISCO FORREST',
#   'description': 'A Beautiful Documentary of a Woman And a Pioneer who must Pursue a Mad Scientist in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 87.074762435,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 339,
#   'title': 'FROGMEN BREAKING',
#   'description': 'A Unbelieveable Yarn of a Mad Scientist And a Cat who must Chase a Lumberjack in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 135.4198537211,
#   'replacement_cost': 17.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 340,
#   'title': 'FRONTIER CABIN',
#   'description': 'A Emotional Story of a Madman And a Waitress who must Battle a Teacher in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 117.9567381877,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 341,
#   'title': 'FROST HEAD',
#   'description': 'A Amazing Reflection of a Lumberjack And a Cat who must Discover a Husband in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 113.5860570652,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 342,
#   'title': 'FUGITIVE MAGUIRE',
#   'description': 'A Taut Epistle of a Feminist And a Sumo Wrestler who must Battle a Crocodile in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 111.6622821199,
#   'replacement_cost': 28.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 343,
#   'title': 'FULL FLATLINERS',
#   'description': 'A Beautiful Documentary of a Astronaut And a Moose who must Pursue a Monkey in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 89.2465952151,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 344,
#   'title': 'FURY MURDER',
#   'description': 'A Lacklusture Reflection of a Boat And a Forensic Psychologist who must Fight a Waitress in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 122.0356835823,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 345,
#   'title': 'GABLES METROPOLIS',
#   'description': 'A Fateful Display of a Cat And a Pioneer who must Challenge a Pastry Chef in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 121.6359149599,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 346,
#   'title': 'GALAXY SWEETHEARTS',
#   'description': 'A Emotional Reflection of a Womanizer And a Pioneer who must Face a Squirrel in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 90.5873905757,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 347,
#   'title': 'GAMES BOWFINGER',
#   'description': 'A Astounding Documentary of a Butler And a Explorer who must Challenge a Butler in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 103.2694521223,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 348,
#   'title': 'GANDHI KWAI',
#   'description': 'A Thoughtful Display of a Mad Scientist And a Secret Agent who must Chase a Boat in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 109.1033924037,
#   'replacement_cost': 9.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 349,
#   'title': 'GANGS PRIDE',
#   'description': 'A Taut Character Study of a Woman And a A Shark who must Confront a Frisbee in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 98.9332050019,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 350,
#   'title': 'GARDEN ISLAND',
#   'description': 'A Unbelieveable Character Study of a Womanizer And a Madman who must Reach a Man in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 84.569466762,
#   'replacement_cost': 21.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 351,
#   'title': 'GASLIGHT CRUSADE',
#   'description': 'A Amazing Epistle of a Boy And a Astronaut who must Redeem a Man in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 103.6400342669,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 352,
#   'title': 'GATHERING CALENDAR',
#   'description': 'A Intrepid Tale of a Pioneer And a Moose who must Conquer a Frisbee in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 126.2011087314,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 353,
#   'title': 'GENTLEMEN STAGE',
#   'description': 'A Awe-Inspiring Reflection of a Monkey And a Student who must Overcome a Dentist in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 118.9871224138,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 354,
#   'title': 'GHOST GROUNDHOG',
#   'description': 'A Brilliant Panorama of a Madman And a Composer who must Succumb a Car in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 85.3354407376,
#   'replacement_cost': 18.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 355,
#   'title': 'GHOSTBUSTERS ELF',
#   'description': 'A Thoughtful Epistle of a Dog And a Feminist who must Chase a Composer in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 147.0976765092,
#   'replacement_cost': 18.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 356,
#   'title': 'GIANT TROOPERS',
#   'description': 'A Fateful Display of a Feminist And a Monkey who must Vanquish a Monkey in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 126.7769873183,
#   'replacement_cost': 10.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 357,
#   'title': 'GILBERT PELICAN',
#   'description': 'A Fateful Tale of a Man And a Feminist who must Conquer a Crocodile in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 102.5143043937,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 358,
#   'title': 'GILMORE BOILED',
#   'description': 'A Unbelieveable Documentary of a Boat And a Husband who must Succumb a Student in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 129.6251042043,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 359,
#   'title': 'GLADIATOR WESTWARD',
#   'description': 'A Astounding Reflection of a Squirrel And a Sumo Wrestler who must Sink a Dentist in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 112.7968969095,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 360,
#   'title': 'GLASS DYING',
#   'description': 'A Astounding Drama of a Frisbee And a Astronaut who must Fight a Dog in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 78.1638687191,
#   'replacement_cost': 24.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 361,
#   'title': 'GLEAMING JAWBREAKER',
#   'description': 'A Amazing Display of a Composer And a Forensic Psychologist who must Discover a Car in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 136.5274030838,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 362,
#   'title': 'GLORY TRACY',
#   'description': 'A Amazing Saga of a Woman And a Womanizer who must Discover a Cat in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 117.4499541139,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 363,
#   'title': 'GO PURPLE',
#   'description': 'A Fast-Paced Display of a Car And a Database Administrator who must Battle a Woman in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 126.0472009155,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 364,
#   'title': 'GODFATHER DIARY',
#   'description': 'A Stunning Saga of a Lumberjack And a Squirrel who must Chase a Car in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 137.2078684732,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 365,
#   'title': 'GOLD RIVER',
#   'description': 'A Taut Documentary of a Database Administrator And a Waitress who must Reach a Mad Scientist in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 129.8672345708,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 366,
#   'title': 'GOLDFINGER SENSIBILITY',
#   'description': 'A Insightful Drama of a Mad Scientist And a Hunter who must Defeat a Pastry Chef in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 116.5536316153,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 367,
#   'title': 'GOLDMINE TYCOON',
#   'description': 'A Brilliant Epistle of a Composer And a Frisbee who must Conquer a Husband in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 155.715741371,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 368,
#   'title': 'GONE TROUBLE',
#   'description': 'A Insightful Character Study of a Mad Cow And a Forensic Psychologist who must Conquer a A Shark in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 128.1811644587,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 369,
#   'title': 'GOODFELLAS SALUTE',
#   'description': 'A Unbelieveable Tale of a Dog And a Explorer who must Sink a Mad Cow in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 91.7389790296,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 370,
#   'title': 'GORGEOUS BINGO',
#   'description': 'A Action-Packed Display of a Sumo Wrestler And a Car who must Overcome a Waitress in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 126.05773054,
#   'replacement_cost': 26.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 371,
#   'title': 'GOSFORD DONNIE',
#   'description': 'A Epic Panorama of a Mad Scientist And a Monkey who must Redeem a Secret Agent in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 99.9927254681,
#   'replacement_cost': 17.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 372,
#   'title': 'GRACELAND DYNAMITE',
#   'description': 'A Taut Display of a Cat And a Girl who must Overcome a Database Administrator in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 151.3079067243,
#   'replacement_cost': 26.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 373,
#   'title': 'GRADUATE LORD',
#   'description': 'A Lacklusture Epistle of a Girl And a A Shark who must Meet a Mad Scientist in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 82.0969123822,
#   'replacement_cost': 14.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 374,
#   'title': 'GRAFFITI LOVE',
#   'description': 'A Unbelieveable Epistle of a Sumo Wrestler And a Hunter who must Build a Composer in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 103.5009017541,
#   'replacement_cost': 29.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 375,
#   'title': 'GRAIL FRANKENSTEIN',
#   'description': 'A Unbelieveable Saga of a Teacher And a Monkey who must Fight a Girl in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 80.4958561711,
#   'replacement_cost': 17.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 376,
#   'title': 'GRAPES FURY',
#   'description': 'A Boring Yarn of a Mad Cow And a Sumo Wrestler who must Meet a Robot in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 106.2253463614,
#   'replacement_cost': 20.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 377,
#   'title': 'GREASE YOUTH',
#   'description': 'A Emotional Panorama of a Secret Agent And a Waitress who must Escape a Composer in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 72.2419055534,
#   'replacement_cost': 20.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 378,
#   'title': 'GREATEST NORTH',
#   'description': 'A Astounding Character Study of a Secret Agent And a Robot who must Build a A Shark in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 102.424616581,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 379,
#   'title': 'GREEDY ROOTS',
#   'description': 'A Amazing Reflection of a A Shark And a Butler who must Chase a Hunter in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 141.2605589242,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 380,
#   'title': 'GREEK EVERYONE',
#   'description': 'A Stunning Display of a Butler And a Teacher who must Confront a A Shark in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 60.5817859422,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 381,
#   'title': 'GRINCH MASSAGE',
#   'description': 'A Intrepid Display of a Madman And a Feminist who must Pursue a Pioneer in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 140.4397895886,
#   'replacement_cost': 25.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 382,
#   'title': 'GRIT CLOCKWORK',
#   'description': 'A Thoughtful Display of a Dentist And a Squirrel who must Confront a Lumberjack in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 101.8768518581,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 383,
#   'title': 'GROOVE FICTION',
#   'description': 'A Unbelieveable Reflection of a Moose And a A Shark who must Defeat a Lumberjack in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 137.9114568947,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 384,
#   'title': 'GROSSE WONDERFUL',
#   'description': 'A Epic Drama of a Cat And a Explorer who must Redeem a Moose in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 129.4190915502,
#   'replacement_cost': 19.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 385,
#   'title': 'GROUNDHOG UNCUT',
#   'description': 'A Brilliant Panorama of a Astronaut And a Technical Writer who must Discover a Butler in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 99.4179827852,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 386,
#   'title': 'GUMP DATE',
#   'description': 'A Intrepid Yarn of a Explorer And a Student who must Kill a Husband in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 105.818021317,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 387,
#   'title': 'GUN BONNIE',
#   'description': 'A Boring Display of a Sumo Wrestler And a Husband who must Build a Waitress in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 80.384307681,
#   'replacement_cost': 27.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 388,
#   'title': 'GUNFIGHT MOON',
#   'description': 'A Epic Reflection of a Pastry Chef And a Explorer who must Reach a Dentist in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 113.6176500202,
#   'replacement_cost': 16.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 389,
#   'title': 'GUNFIGHTER MUSSOLINI',
#   'description': 'A Touching Saga of a Robot And a Boy who must Kill a Man in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 123.3483405551,
#   'replacement_cost': 9.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 390,
#   'title': 'GUYS FALCON',
#   'description': 'A Boring Story of a Woman And a Feminist who must Redeem a Squirrel in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 134.7575143226,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 391,
#   'title': 'HALF OUTFIELD',
#   'description': 'A Epic Epistle of a Database Administrator And a Crocodile who must Face a Madman in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 98.6448476651,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 392,
#   'title': 'HALL CASSIDY',
#   'description': 'A Beautiful Panorama of a Pastry Chef And a A Shark who must Battle a Pioneer in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 91.5477916185,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 393,
#   'title': 'HALLOWEEN NUTS',
#   'description': 'A Amazing Panorama of a Forensic Psychologist And a Technical Writer who must Fight a Dentist in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 132.1861600327,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 394,
#   'title': 'HAMLET WISDOM',
#   'description': 'A Touching Reflection of a Man And a Man who must Sink a Robot in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 138.0507470521,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 395,
#   'title': 'HANDICAP BOONDOCK',
#   'description': 'A Beautiful Display of a Pioneer And a Squirrel who must Vanquish a Sumo Wrestler in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 131.5971853422,
#   'replacement_cost': 28.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 396,
#   'title': 'HANGING DEEP',
#   'description': 'A Action-Packed Yarn of a Boat And a Crocodile who must Build a Monkey in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 90.093725975,
#   'replacement_cost': 18.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 397,
#   'title': 'HANKY OCTOBER',
#   'description': 'A Boring Epistle of a Database Administrator And a Explorer who must Pursue a Madman in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 91.6682331831,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 398,
#   'title': 'HANOVER GALAXY',
#   'description': 'A Stunning Reflection of a Girl And a Secret Agent who must Succumb a Boy in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 101.8160917456,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 399,
#   'title': 'HAPPINESS UNITED',
#   'description': 'A Action-Packed Panorama of a Husband And a Feminist who must Meet a Forensic Psychologist in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 93.0420740086,
#   'replacement_cost': 23.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 400,
#   'title': 'HARDLY ROBBERS',
#   'description': 'A Emotional Character Study of a Hunter And a Car who must Kill a Woman in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 150.659395716,
#   'replacement_cost': 15.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 401,
#   'title': 'HAROLD FRENCH',
#   'description': 'A Stunning Saga of a Sumo Wrestler And a Student who must Outrace a Moose in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 90.2278559182,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 402,
#   'title': 'HARPER DYING',
#   'description': 'A Awe-Inspiring Reflection of a Woman And a Cat who must Confront a Feminist in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 95.8079713494,
#   'replacement_cost': 15.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 403,
#   'title': 'HARRY IDAHO',
#   'description': 'A Taut Yarn of a Technical Writer And a Feminist who must Outrace a Dog in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 109.8782673719,
#   'replacement_cost': 18.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 404,
#   'title': 'HATE HANDICAP',
#   'description': 'A Intrepid Reflection of a Mad Scientist And a Pioneer who must Overcome a Hunter in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 92.3621727758,
#   'replacement_cost': 26.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 405,
#   'title': 'HAUNTED ANTITRUST',
#   'description': 'A Amazing Saga of a Man And a Dentist who must Reach a Technical Writer in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 122.7940930068,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 406,
#   'title': 'HAUNTING PIANIST',
#   'description': 'A Fast-Paced Story of a Database Administrator And a Composer who must Defeat a Squirrel in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 121.4680910707,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 407,
#   'title': 'HAWK CHILL',
#   'description': 'A Action-Packed Drama of a Mad Scientist And a Composer who must Outgun a Car in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 129.7593610984,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 408,
#   'title': 'HEAD STRANGER',
#   'description': 'A Thoughtful Saga of a Hunter And a Crocodile who must Confront a Dog in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 124.8687925345,
#   'replacement_cost': 28.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 409,
#   'title': 'HEARTBREAKERS BRIGHT',
#   'description': 'A Awe-Inspiring Documentary of a A Shark And a Dentist who must Outrace a Pastry Chef in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 84.541903317,
#   'replacement_cost': 9.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 410,
#   'title': 'HEAVEN FREEDOM',
#   'description': 'A Intrepid Story of a Butler And a Car who must Vanquish a Man in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 104.2006657943,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 411,
#   'title': 'HEAVENLY GUN',
#   'description': 'A Beautiful Yarn of a Forensic Psychologist And a Frisbee who must Battle a Moose in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 119.1586082816,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 412,
#   'title': 'HEAVYWEIGHTS BEAST',
#   'description': 'A Unbelieveable Story of a Composer And a Dog who must Overcome a Womanizer in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 88.1807653757,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 413,
#   'title': 'HEDWIG ALTER',
#   'description': 'A Action-Packed Yarn of a Womanizer And a Lumberjack who must Chase a Sumo Wrestler in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 116.8408908445,
#   'replacement_cost': 16.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 414,
#   'title': 'HELLFIGHTERS SIERRA',
#   'description': 'A Taut Reflection of a A Shark And a Dentist who must Battle a Boat in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 105.9734048316,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 415,
#   'title': 'HIGH ENCINO',
#   'description': 'A Fateful Saga of a Waitress And a Hunter who must Outrace a Sumo Wrestler in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 128.7362398528,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 416,
#   'title': 'HIGHBALL POTTER',
#   'description': 'A Action-Packed Saga of a Husband And a Dog who must Redeem a Database Administrator in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 143.2609427925,
#   'replacement_cost': 10.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 417,
#   'title': 'HILLS NEIGHBORS',
#   'description': 'A Epic Display of a Hunter And a Feminist who must Sink a Car in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 1.99,
#   'length': 108.9771811296,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 418,
#   'title': 'HOBBIT ALIEN',
#   'description': 'A Emotional Drama of a Husband And a Girl who must Outgun a Composer in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 136.7543229393,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 419,
#   'title': 'HOCUS FRIDA',
#   'description': 'A Awe-Inspiring Tale of a Girl And a Madman who must Outgun a Student in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 99.6888587461,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 420,
#   'title': 'HOLES BRANNIGAN',
#   'description': 'A Fast-Paced Reflection of a Technical Writer And a Student who must Fight a Boy in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 92.8774853226,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 421,
#   'title': 'HOLIDAY GAMES',
#   'description': 'A Insightful Reflection of a Waitress And a Madman who must Pursue a Boy in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 103.8902928812,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 422,
#   'title': 'HOLLOW JEOPARDY',
#   'description': 'A Beautiful Character Study of a Robot And a Astronaut who must Overcome a Boat in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 121.8850130147,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 423,
#   'title': 'HOLLYWOOD ANONYMOUS',
#   'description': 'A Fast-Paced Epistle of a Boy And a Explorer who must Escape a Dog in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 115.1365164872,
#   'replacement_cost': 29.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 424,
#   'title': 'HOLOCAUST HIGHBALL',
#   'description': 'A Awe-Inspiring Yarn of a Composer And a Man who must Find a Robot in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 125.5684901923,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 425,
#   'title': 'HOLY TADPOLE',
#   'description': 'A Action-Packed Display of a Feminist And a Pioneer who must Pursue a Dog in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 137.0921142491,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 426,
#   'title': 'HOME PITY',
#   'description': 'A Touching Panorama of a Man And a Secret Agent who must Challenge a Teacher in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 109.7283780361,
#   'replacement_cost': 15.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 427,
#   'title': 'HOMEWARD CIDER',
#   'description': 'A Taut Reflection of a Astronaut And a Squirrel who must Fight a Squirrel in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 141.3310709468,
#   'replacement_cost': 19.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 428,
#   'title': 'HOMICIDE PEACH',
#   'description': 'A Astounding Documentary of a Hunter And a Boy who must Confront a Boy in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 147.9511311185,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 429,
#   'title': 'HONEY TIES',
#   'description': 'A Taut Story of a Waitress And a Crocodile who must Outrace a Lumberjack in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 112.9435642416,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 430,
#   'title': 'HOOK CHARIOTS',
#   'description': 'A Insightful Story of a Boy And a Dog who must Redeem a Boy in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 83.2546257416,
#   'replacement_cost': 23.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 431,
#   'title': 'HOOSIERS BIRDCAGE',
#   'description': 'A Astounding Display of a Explorer And a Boat who must Vanquish a Car in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 115.7195948645,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 432,
#   'title': 'HOPE TOOTSIE',
#   'description': 'A Amazing Documentary of a Student And a Sumo Wrestler who must Outgun a A Shark in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 140.4931267853,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 433,
#   'title': 'HORN WORKING',
#   'description': 'A Stunning Display of a Mad Scientist And a Technical Writer who must Succumb a Monkey in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 80.3163411898,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 434,
#   'title': 'HORROR REIGN',
#   'description': 'A Touching Documentary of a A Shark And a Car who must Build a Husband in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 118.8799813446,
#   'replacement_cost': 25.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 435,
#   'title': 'HOTEL HAPPINESS',
#   'description': 'A Thrilling Yarn of a Pastry Chef And a A Shark who must Challenge a Mad Scientist in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 127.5235158811,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 436,
#   'title': 'HOURS RAGE',
#   'description': 'A Fateful Story of a Explorer And a Feminist who must Meet a Technical Writer in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 77.1296253153,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 437,
#   'title': 'HOUSE DYNAMITE',
#   'description': 'A Taut Story of a Pioneer And a Squirrel who must Battle a Student in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 120.9895166104,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 438,
#   'title': 'HUMAN GRAFFITI',
#   'description': 'A Beautiful Reflection of a Womanizer And a Sumo Wrestler who must Chase a Database Administrator in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 114.2159101454,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 439,
#   'title': 'HUNCHBACK IMPOSSIBLE',
#   'description': 'A Touching Yarn of a Frisbee And a Dentist who must Fight a Composer in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 145.6437096613,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 440,
#   'title': 'HUNGER ROOF',
#   'description': 'A Unbelieveable Yarn of a Student And a Database Administrator who must Outgun a Husband in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 60.1378792394,
#   'replacement_cost': 21.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 441,
#   'title': 'HUNTER ALTER',
#   'description': 'A Emotional Drama of a Mad Cow And a Boat who must Redeem a Secret Agent in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 92.5708738821,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 442,
#   'title': 'HUNTING MUSKETEERS',
#   'description': 'A Thrilling Reflection of a Pioneer And a Dentist who must Outrace a Womanizer in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 121.7179083838,
#   'replacement_cost': 24.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 443,
#   'title': 'HURRICANE AFFAIR',
#   'description': 'A Lacklusture Epistle of a Database Administrator And a Woman who must Meet a Hunter in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 83.9486144607,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 444,
#   'title': 'HUSTLER PARTY',
#   'description': 'A Emotional Reflection of a Sumo Wrestler And a Monkey who must Conquer a Robot in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 91.2651816025,
#   'replacement_cost': 22.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 445,
#   'title': 'HYDE DOCTOR',
#   'description': 'A Fanciful Documentary of a Boy And a Woman who must Redeem a Womanizer in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 100.0228406097,
#   'replacement_cost': 11.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 446,
#   'title': 'HYSTERICAL GRAIL',
#   'description': 'A Amazing Saga of a Madman And a Dentist who must Build a Car in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 92.6521442709,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 447,
#   'title': 'ICE CROSSING',
#   'description': 'A Fast-Paced Tale of a Butler And a Moose who must Overcome a Pioneer in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 111.1591091635,
#   'replacement_cost': 28.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 448,
#   'title': 'IDAHO LOVE',
#   'description': 'A Fast-Paced Drama of a Student And a Crocodile who must Meet a Database Administrator in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 123.698527083,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 449,
#   'title': 'IDENTITY LOVER',
#   'description': 'A Boring Tale of a Composer And a Mad Cow who must Defeat a Car in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 78.6848627594,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 450,
#   'title': 'IDOLS SNATCHERS',
#   'description': 'A Insightful Drama of a Car And a Composer who must Fight a Man in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 110.9536629208,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 451,
#   'title': 'IGBY MAKER',
#   'description': 'A Epic Documentary of a Hunter And a Dog who must Outgun a Dog in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 133.8176796976,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 452,
#   'title': 'ILLUSION AMELIE',
#   'description': 'A Emotional Epistle of a Boat And a Mad Scientist who must Outrace a Robot in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 126.6470543169,
#   'replacement_cost': 15.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 453,
#   'title': 'IMAGE PRINCESS',
#   'description': 'A Lacklusture Panorama of a Secret Agent And a Crocodile who must Discover a Madman in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 97.3487929306,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 454,
#   'title': 'IMPACT ALADDIN',
#   'description': 'A Epic Character Study of a Frisbee And a Moose who must Outgun a Technical Writer in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 122.1179414007,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 455,
#   'title': 'IMPOSSIBLE PREJUDICE',
#   'description': 'A Awe-Inspiring Yarn of a Monkey And a Hunter who must Chase a Teacher in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 104.5858619071,
#   'replacement_cost': 11.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 456,
#   'title': 'INCH JET',
#   'description': 'A Fateful Saga of a Womanizer And a Student who must Defeat a Butler in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 123.6724134076,
#   'replacement_cost': 18.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 457,
#   'title': 'INDEPENDENCE HOTEL',
#   'description': 'A Thrilling Tale of a Technical Writer And a Boy who must Face a Pioneer in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 124.9765668055,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 458,
#   'title': 'INDIAN LOVE',
#   'description': 'A Insightful Saga of a Mad Scientist And a Mad Scientist who must Kill a Astronaut in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 90.0813246645,
#   'replacement_cost': 26.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 459,
#   'title': 'INFORMER DOUBLE',
#   'description': 'A Action-Packed Display of a Woman And a Dentist who must Redeem a Forensic Psychologist in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 80.2011224619,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 460,
#   'title': 'INNOCENT USUAL',
#   'description': 'A Beautiful Drama of a Pioneer And a Crocodile who must Challenge a Student in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 68.2737053446,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 461,
#   'title': 'INSECTS STONE',
#   'description': 'A Epic Display of a Butler And a Dog who must Vanquish a Crocodile in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 88.539535088,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 462,
#   'title': 'INSIDER ARIZONA',
#   'description': 'A Astounding Saga of a Mad Scientist And a Hunter who must Pursue a Robot in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 114.9473432254,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 463,
#   'title': 'INSTINCT AIRPORT',
#   'description': 'A Touching Documentary of a Mad Cow And a Explorer who must Confront a Butler in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 106.1379343248,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 464,
#   'title': 'INTENTIONS EMPIRE',
#   'description': 'A Astounding Epistle of a Cat And a Cat who must Conquer a Mad Cow in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 87.1590875504,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 465,
#   'title': 'INTERVIEW LIAISONS',
#   'description': 'A Action-Packed Reflection of a Student And a Butler who must Discover a Database Administrator in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 115.3698162766,
#   'replacement_cost': 17.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 466,
#   'title': 'INTOLERABLE INTENTIONS',
#   'description': 'A Awe-Inspiring Story of a Monkey And a Pastry Chef who must Succumb a Womanizer in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 109.700822771,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 467,
#   'title': 'INTRIGUE WORST',
#   'description': 'A Fanciful Character Study of a Explorer And a Mad Scientist who must Vanquish a Squirrel in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 91.6758777034,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 468,
#   'title': 'INVASION CYCLONE',
#   'description': 'A Lacklusture Character Study of a Mad Scientist And a Womanizer who must Outrace a Explorer in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 91.2064451116,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 469,
#   'title': 'IRON MOON',
#   'description': 'A Fast-Paced Documentary of a Mad Cow And a Boy who must Pursue a Dentist in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 88.2504426626,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 470,
#   'title': 'ISHTAR ROCKETEER',
#   'description': 'A Astounding Saga of a Dog And a Squirrel who must Conquer a Dog in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 126.6561428998,
#   'replacement_cost': 24.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 471,
#   'title': 'ISLAND EXORCIST',
#   'description': 'A Fanciful Panorama of a Technical Writer And a Boy who must Find a Dentist in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 95.7925926283,
#   'replacement_cost': 23.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 472,
#   'title': 'ITALIAN AFRICAN',
#   'description': 'A Astounding Character Study of a Monkey And a Moose who must Outgun a Cat in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 84.2293573051,
#   'replacement_cost': 24.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 473,
#   'title': 'JACKET FRISCO',
#   'description': 'A Insightful Reflection of a Womanizer And a Husband who must Conquer a Pastry Chef in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 130.1441988725,
#   'replacement_cost': 16.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 474,
#   'title': 'JADE BUNCH',
#   'description': 'A Insightful Panorama of a Squirrel And a Mad Cow who must Confront a Student in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 94.4799270687,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 475,
#   'title': 'JAPANESE RUN',
#   'description': 'A Awe-Inspiring Epistle of a Feminist And a Girl who must Sink a Girl in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 98.7857165113,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 476,
#   'title': 'JASON TRAP',
#   'description': 'A Thoughtful Tale of a Woman And a A Shark who must Conquer a Dog in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 87.0981545193,
#   'replacement_cost': 9.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 477,
#   'title': 'JAWBREAKER BROOKLYN',
#   'description': 'A Stunning Reflection of a Boat And a Pastry Chef who must Succumb a A Shark in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 93.842953631,
#   'replacement_cost': 15.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 478,
#   'title': 'JAWS HARRY',
#   'description': 'A Thrilling Display of a Database Administrator And a Monkey who must Overcome a Dog in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 97.1207058656,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 479,
#   'title': 'JEDI BENEATH',
#   'description': 'A Astounding Reflection of a Explorer And a Dentist who must Pursue a Student in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 90.3750105902,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 480,
#   'title': 'JEEPERS WEDDING',
#   'description': 'A Astounding Display of a Composer And a Dog who must Kill a Pastry Chef in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 147.0433197796,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 481,
#   'title': 'JEKYLL FROGMEN',
#   'description': 'A Fanciful Epistle of a Student And a Astronaut who must Kill a Waitress in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 89.5699708228,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 482,
#   'title': 'JEOPARDY ENCINO',
#   'description': 'A Boring Panorama of a Man And a Mad Cow who must Face a Explorer in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 117.3401964482,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 483,
#   'title': 'JERICHO MULAN',
#   'description': 'A Amazing Yarn of a Hunter And a Butler who must Defeat a Boy in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 47.1508487804,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 484,
#   'title': 'JERK PAYCHECK',
#   'description': 'A Touching Character Study of a Pastry Chef And a Database Administrator who must Reach a A Shark in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 95.7225900101,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 485,
#   'title': 'JERSEY SASSY',
#   'description': 'A Lacklusture Documentary of a Madman And a Mad Cow who must Find a Feminist in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 129.1816114192,
#   'replacement_cost': 16.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 486,
#   'title': 'JET NEIGHBORS',
#   'description': 'A Amazing Display of a Lumberjack And a Teacher who must Outrace a Woman in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 125.2408774707,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 487,
#   'title': 'JINGLE SAGEBRUSH',
#   'description': 'A Epic Character Study of a Feminist And a Student who must Meet a Woman in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 102.3611622397,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 488,
#   'title': 'JOON NORTHWEST',
#   'description': 'A Thrilling Panorama of a Technical Writer And a Car who must Discover a Forensic Psychologist in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 96.2781187071,
#   'replacement_cost': 23.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 489,
#   'title': 'JUGGLER HARDLY',
#   'description': 'A Epic Story of a Mad Cow And a Astronaut who must Challenge a Car in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 119.6342930143,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 490,
#   'title': 'JUMANJI BLADE',
#   'description': 'A Intrepid Yarn of a Husband And a Womanizer who must Pursue a Mad Scientist in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 78.1401027277,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 491,
#   'title': 'JUMPING WRATH',
#   'description': 'A Touching Epistle of a Monkey And a Feminist who must Discover a Boat in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 128.482606489,
#   'replacement_cost': 18.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 492,
#   'title': 'JUNGLE CLOSER',
#   'description': 'A Boring Character Study of a Boy And a Woman who must Battle a Astronaut in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 120.7049021363,
#   'replacement_cost': 11.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 493,
#   'title': 'KANE EXORCIST',
#   'description': 'A Epic Documentary of a Composer And a Robot who must Overcome a Car in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 129.5014568296,
#   'replacement_cost': 18.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 494,
#   'title': 'KARATE MOON',
#   'description': 'A Astounding Yarn of a Womanizer And a Dog who must Reach a Waitress in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 128.3385322249,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 495,
#   'title': 'KENTUCKIAN GIANT',
#   'description': 'A Stunning Yarn of a Woman And a Frisbee who must Escape a Waitress in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 94.9155753159,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 496,
#   'title': 'KICK SAVANNAH',
#   'description': 'A Emotional Drama of a Monkey And a Robot who must Defeat a Monkey in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 107.6546100062,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 497,
#   'title': 'KILL BROTHERHOOD',
#   'description': 'A Touching Display of a Hunter And a Secret Agent who must Redeem a Husband in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 104.1139761638,
#   'replacement_cost': 15.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 498,
#   'title': 'KILLER INNOCENT',
#   'description': 'A Fanciful Character Study of a Student And a Explorer who must Succumb a Composer in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 133.4921642089,
#   'replacement_cost': 11.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 499,
#   'title': 'KING EVOLUTION',
#   'description': 'A Action-Packed Tale of a Boy And a Lumberjack who must Chase a Madman in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 145.6337576765,
#   'replacement_cost': 24.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 500,
#   'title': 'KISS GLORY',
#   'description': 'A Lacklusture Reflection of a Girl And a Husband who must Find a Robot in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 114.1979797249,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 501,
#   'title': 'KISSING DOLLS',
#   'description': 'A Insightful Reflection of a Pioneer And a Teacher who must Build a Composer in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 119.0827272034,
#   'replacement_cost': 9.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 502,
#   'title': 'KNOCK WARLOCK',
#   'description': 'A Unbelieveable Story of a Teacher And a Boat who must Confront a Moose in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 117.3919172528,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 503,
#   'title': 'KRAMER CHOCOLATE',
#   'description': 'A Amazing Yarn of a Robot And a Pastry Chef who must Redeem a Mad Scientist in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 126.7569404903,
#   'replacement_cost': 24.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 504,
#   'title': 'KWAI HOMEWARD',
#   'description': 'A Amazing Drama of a Car And a Squirrel who must Pursue a Car in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 102.5873388184,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 505,
#   'title': 'LABYRINTH LEAGUE',
#   'description': 'A Awe-Inspiring Saga of a Composer And a Frisbee who must Succumb a Pioneer in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 92.1859239744,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 506,
#   'title': 'LADY STAGE',
#   'description': 'A Beautiful Character Study of a Woman And a Man who must Pursue a Explorer in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 119.5701063148,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 507,
#   'title': 'LADYBUGS ARMAGEDDON',
#   'description': 'A Fateful Reflection of a Dog And a Mad Scientist who must Meet a Mad Scientist in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 127.5819642847,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 508,
#   'title': 'LAMBS CINCINATTI',
#   'description': 'A Insightful Story of a Man And a Feminist who must Fight a Composer in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 117.9865639039,
#   'replacement_cost': 18.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 509,
#   'title': 'LANGUAGE COWBOY',
#   'description': 'A Epic Yarn of a Cat And a Madman who must Vanquish a Dentist in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 83.9239265972,
#   'replacement_cost': 26.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 510,
#   'title': 'LAWLESS VISION',
#   'description': 'A Insightful Yarn of a Boy And a Sumo Wrestler who must Outgun a Car in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 101.2171078222,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 511,
#   'title': 'LAWRENCE LOVE',
#   'description': 'A Fanciful Yarn of a Database Administrator And a Mad Cow who must Pursue a Womanizer in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 148.2771278045,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 512,
#   'title': 'LEAGUE HELLFIGHTERS',
#   'description': 'A Thoughtful Saga of a A Shark And a Monkey who must Outgun a Student in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 104.7038309363,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 513,
#   'title': 'LEATHERNECKS DWARFS',
#   'description': 'A Fateful Reflection of a Dog And a Mad Cow who must Outrace a Teacher in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 89.4743878153,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 514,
#   'title': 'LEBOWSKI SOLDIERS',
#   'description': 'A Beautiful Epistle of a Secret Agent And a Pioneer who must Chase a Astronaut in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 122.82623796,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 515,
#   'title': 'LEGALLY SECRETARY',
#   'description': 'A Astounding Tale of a A Shark And a Moose who must Meet a Womanizer in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 113.1631651246,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 516,
#   'title': 'LEGEND JEDI',
#   'description': 'A Awe-Inspiring Epistle of a Pioneer And a Student who must Outgun a Crocodile in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 86.2415058211,
#   'replacement_cost': 18.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 517,
#   'title': 'LESSON CLEOPATRA',
#   'description': 'A Emotional Display of a Man And a Explorer who must Build a Boy in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 116.5203520838,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 518,
#   'title': 'LIAISONS SWEET',
#   'description': 'A Boring Drama of a A Shark And a Explorer who must Redeem a Waitress in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 98.1206720469,
#   'replacement_cost': 15.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 519,
#   'title': 'LIBERTY MAGNIFICENT',
#   'description': 'A Boring Drama of a Student And a Cat who must Sink a Technical Writer in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 100.9324810715,
#   'replacement_cost': 27.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 520,
#   'title': 'LICENSE WEEKEND',
#   'description': 'A Insightful Story of a Man And a Husband who must Overcome a Madman in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 83.932166715,
#   'replacement_cost': 28.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 521,
#   'title': 'LIES TREATMENT',
#   'description': 'A Fast-Paced Character Study of a Dentist And a Moose who must Defeat a Composer in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 96.5118146995,
#   'replacement_cost': 28.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 522,
#   'title': 'LIFE TWISTED',
#   'description': 'A Thrilling Reflection of a Teacher And a Composer who must Find a Man in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 84.8670828531,
#   'replacement_cost': 9.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 523,
#   'title': 'LIGHTS DEER',
#   'description': 'A Unbelieveable Epistle of a Dog And a Woman who must Confront a Moose in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 114.9722165203,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 524,
#   'title': 'LION UNCUT',
#   'description': 'A Intrepid Display of a Pastry Chef And a Cat who must Kill a A Shark in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 114.5377105297,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 525,
#   'title': 'LOATHING LEGALLY',
#   'description': 'A Boring Epistle of a Pioneer And a Mad Scientist who must Escape a Frisbee in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 132.5514008265,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 526,
#   'title': 'LOCK REAR',
#   'description': 'A Thoughtful Character Study of a Squirrel And a Technical Writer who must Outrace a Student in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 141.5307979504,
#   'replacement_cost': 10.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 527,
#   'title': 'LOLA AGENT',
#   'description': 'A Astounding Tale of a Mad Scientist And a Husband who must Redeem a Database Administrator in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 97.0407501071,
#   'replacement_cost': 24.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 528,
#   'title': 'LOLITA WORLD',
#   'description': 'A Thrilling Drama of a Girl And a Robot who must Redeem a Waitress in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 138.8004303769,
#   'replacement_cost': 25.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 529,
#   'title': 'LONELY ELEPHANT',
#   'description': 'A Intrepid Story of a Student And a Dog who must Challenge a Explorer in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 93.2239139363,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 530,
#   'title': 'LORD ARIZONA',
#   'description': 'A Action-Packed Display of a Frisbee And a Pastry Chef who must Pursue a Crocodile in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 112.1233492186,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 531,
#   'title': 'LOSE INCH',
#   'description': 'A Stunning Reflection of a Student And a Technical Writer who must Battle a Butler in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 119.3744903963,
#   'replacement_cost': 18.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 532,
#   'title': 'LOSER HUSTLER',
#   'description': 'A Stunning Drama of a Robot And a Feminist who must Outgun a Butler in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 75.5278685802,
#   'replacement_cost': 28.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 533,
#   'title': 'LOST BIRD',
#   'description': 'A Emotional Character Study of a Robot And a A Shark who must Defeat a Technical Writer in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 98.6932567793,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 534,
#   'title': 'LOUISIANA HARRY',
#   'description': 'A Lacklusture Drama of a Girl And a Technical Writer who must Redeem a Monkey in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 106.6604806636,
#   'replacement_cost': 18.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 535,
#   'title': 'LOVE SUICIDES',
#   'description': 'A Brilliant Panorama of a Hunter And a Explorer who must Pursue a Dentist in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 114.4866824134,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 536,
#   'title': 'LOVELY JINGLE',
#   'description': 'A Fanciful Yarn of a Crocodile And a Forensic Psychologist who must Discover a Crocodile in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 96.7150900685,
#   'replacement_cost': 18.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 537,
#   'title': 'LOVER TRUMAN',
#   'description': 'A Emotional Yarn of a Robot And a Boy who must Outgun a Technical Writer in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 87.9677023754,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 538,
#   'title': 'LOVERBOY ATTACKS',
#   'description': 'A Boring Story of a Car And a Butler who must Build a Girl in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 119.1448065735,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 539,
#   'title': 'LUCK OPUS',
#   'description': 'A Boring Display of a Moose And a Squirrel who must Outrace a Teacher in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 76.9298026201,
#   'replacement_cost': 21.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 540,
#   'title': 'LUCKY FLYING',
#   'description': 'A Lacklusture Character Study of a A Shark And a Man who must Find a Forensic Psychologist in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 117.2734651665,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 541,
#   'title': 'LUKE MUMMY',
#   'description': 'A Taut Character Study of a Boy And a Robot who must Redeem a Mad Scientist in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 119.6555159419,
#   'replacement_cost': 21.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 542,
#   'title': 'LUST LOCK',
#   'description': 'A Fanciful Panorama of a Hunter And a Dentist who must Meet a Secret Agent in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 100.8567440936,
#   'replacement_cost': 28.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 543,
#   'title': 'MADIGAN DORADO',
#   'description': 'A Astounding Character Study of a A Shark And a A Shark who must Discover a Crocodile in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 102.2296950021,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 544,
#   'title': 'MADISON TRAP',
#   'description': 'A Awe-Inspiring Reflection of a Monkey And a Dentist who must Overcome a Pioneer in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 121.9787494367,
#   'replacement_cost': 11.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 545,
#   'title': 'MADNESS ATTACKS',
#   'description': 'A Fanciful Tale of a Squirrel And a Boat who must Defeat a Crocodile in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 97.6273215299,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 546,
#   'title': 'MADRE GABLES',
#   'description': 'A Intrepid Panorama of a Sumo Wrestler And a Forensic Psychologist who must Discover a Moose in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 96.4640524124,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 547,
#   'title': 'MAGIC MALLRATS',
#   'description': 'A Touching Documentary of a Pastry Chef And a Pastry Chef who must Build a Mad Scientist in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 102.6354731793,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 548,
#   'title': 'MAGNIFICENT CHITTY',
#   'description': 'A Insightful Story of a Teacher And a Hunter who must Face a Mad Cow in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 126.1758097036,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 549,
#   'title': 'MAGNOLIA FORRESTER',
#   'description': 'A Thoughtful Documentary of a Composer And a Explorer who must Conquer a Dentist in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 115.1374596054,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 550,
#   'title': 'MAGUIRE APACHE',
#   'description': 'A Fast-Paced Reflection of a Waitress And a Hunter who must Defeat a Forensic Psychologist in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 112.7614774781,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 551,
#   'title': 'MAIDEN HOME',
#   'description': 'A Lacklusture Saga of a Moose And a Teacher who must Kill a Forensic Psychologist in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 113.6007948559,
#   'replacement_cost': 9.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 552,
#   'title': 'MAJESTIC FLOATS',
#   'description': 'A Thrilling Character Study of a Moose And a Student who must Escape a Butler in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 90.0252871927,
#   'replacement_cost': 15.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 553,
#   'title': 'MAKER GABLES',
#   'description': 'A Stunning Display of a Moose And a Database Administrator who must Pursue a Composer in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 122.7272307907,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 554,
#   'title': 'MALKOVICH PET',
#   'description': 'A Intrepid Reflection of a Waitress And a A Shark who must Kill a Squirrel in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 59.1504317544,
#   'replacement_cost': 22.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 555,
#   'title': 'MALLRATS UNITED',
#   'description': 'A Thrilling Yarn of a Waitress And a Dentist who must Find a Hunter in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 100.525377677,
#   'replacement_cost': 25.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 556,
#   'title': 'MALTESE HOPE',
#   'description': 'A Fast-Paced Documentary of a Crocodile And a Sumo Wrestler who must Conquer a Explorer in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 92.6268114124,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 557,
#   'title': 'MANCHURIAN CURTAIN',
#   'description': 'A Stunning Tale of a Mad Cow And a Boy who must Battle a Boy in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 105.9383069742,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 558,
#   'title': 'MANNEQUIN WORST',
#   'description': 'A Astounding Saga of a Mad Cow And a Pastry Chef who must Discover a Husband in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 123.8211290217,
#   'replacement_cost': 18.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 559,
#   'title': 'MARRIED GO',
#   'description': 'A Fanciful Story of a Womanizer And a Dog who must Face a Forensic Psychologist in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 103.4043949561,
#   'replacement_cost': 22.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 560,
#   'title': 'MARS ROMAN',
#   'description': 'A Boring Drama of a Car And a Dog who must Succumb a Madman in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 80.2630700421,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 561,
#   'title': 'MASK PEACH',
#   'description': 'A Boring Character Study of a Student And a Robot who must Meet a Woman in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 69.0873405949,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 562,
#   'title': 'MASKED BUBBLE',
#   'description': 'A Fanciful Documentary of a Pioneer And a Boat who must Pursue a Pioneer in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 136.4511124546,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 563,
#   'title': 'MASSACRE USUAL',
#   'description': 'A Fateful Reflection of a Waitress And a Crocodile who must Challenge a Forensic Psychologist in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 107.536221583,
#   'replacement_cost': 16.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 564,
#   'title': 'MASSAGE IMAGE',
#   'description': 'A Fateful Drama of a Frisbee And a Crocodile who must Vanquish a Dog in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 103.3998436335,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 565,
#   'title': 'MATRIX SNOWMAN',
#   'description': 'A Action-Packed Saga of a Womanizer And a Woman who must Overcome a Student in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 124.2371199829,
#   'replacement_cost': 9.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 566,
#   'title': 'MAUDE MOD',
#   'description': 'A Beautiful Documentary of a Forensic Psychologist And a Cat who must Reach a Astronaut in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 142.6403983279,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 567,
#   'title': 'MEET CHOCOLATE',
#   'description': 'A Boring Documentary of a Dentist And a Butler who must Confront a Monkey in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 86.5187603857,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 568,
#   'title': 'MEMENTO ZOOLANDER',
#   'description': 'A Touching Epistle of a Squirrel And a Explorer who must Redeem a Pastry Chef in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 5.99,
#   'length': 81.2723166324,
#   'replacement_cost': 11.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 569,
#   'title': 'MENAGERIE RUSHMORE',
#   'description': 'A Unbelieveable Panorama of a Composer And a Butler who must Overcome a Database Administrator in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 81.9820179719,
#   'replacement_cost': 18.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 570,
#   'title': 'MERMAID INSECTS',
#   'description': 'A Lacklusture Drama of a Waitress And a Husband who must Fight a Husband in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 111.9668969944,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 571,
#   'title': 'METAL ARMAGEDDON',
#   'description': 'A Thrilling Display of a Lumberjack And a Crocodile who must Meet a Monkey in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 123.5921469479,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 572,
#   'title': 'METROPOLIS COMA',
#   'description': 'A Emotional Saga of a Database Administrator And a Pastry Chef who must Confront a Teacher in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 90.6938033561,
#   'replacement_cost': 9.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 573,
#   'title': 'MICROCOSMOS PARADISE',
#   'description': 'A Touching Character Study of a Boat And a Student who must Sink a A Shark in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 103.3486688364,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 574,
#   'title': 'MIDNIGHT WESTWARD',
#   'description': 'A Taut Reflection of a Husband And a A Shark who must Redeem a Pastry Chef in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 93.6118913513,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 575,
#   'title': 'MIDSUMMER GROUNDHOG',
#   'description': 'A Fateful Panorama of a Moose And a Dog who must Chase a Crocodile in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 85.1183427958,
#   'replacement_cost': 27.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 576,
#   'title': 'MIGHTY LUCK',
#   'description': 'A Astounding Epistle of a Mad Scientist And a Pioneer who must Escape a Database Administrator in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 92.5775304192,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 577,
#   'title': 'MILE MULAN',
#   'description': 'A Lacklusture Epistle of a Cat And a Husband who must Confront a Boy in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 111.5675875829,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 578,
#   'title': 'MILLION ACE',
#   'description': 'A Brilliant Documentary of a Womanizer And a Squirrel who must Find a Technical Writer in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 140.8918558645,
#   'replacement_cost': 16.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 579,
#   'title': 'MINDS TRUMAN',
#   'description': 'A Taut Yarn of a Mad Scientist And a Crocodile who must Outgun a Database Administrator in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 85.4807582071,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 580,
#   'title': 'MINE TITANS',
#   'description': 'A Amazing Yarn of a Robot And a Womanizer who must Discover a Forensic Psychologist in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 92.6342170857,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 581,
#   'title': 'MINORITY KISS',
#   'description': 'A Insightful Display of a Lumberjack And a Sumo Wrestler who must Meet a Man in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 68.2733168355,
#   'replacement_cost': 16.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 582,
#   'title': 'MIRACLE VIRTUAL',
#   'description': 'A Touching Epistle of a Butler And a Boy who must Find a Mad Scientist in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 122.3423349803,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 583,
#   'title': 'MISSION ZOOLANDER',
#   'description': 'A Intrepid Story of a Sumo Wrestler And a Teacher who must Meet a A Shark in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 100.1492235087,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 584,
#   'title': 'MIXED DOORS',
#   'description': 'A Taut Drama of a Womanizer And a Lumberjack who must Succumb a Pioneer in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 101.523450782,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 585,
#   'title': 'MOB DUFFEL',
#   'description': 'A Unbelieveable Documentary of a Frisbee And a Boat who must Meet a Boy in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 89.9110504448,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 586,
#   'title': 'MOCKINGBIRD HOLLYWOOD',
#   'description': 'A Thoughtful Panorama of a Man And a Car who must Sink a Composer in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 103.345138919,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 587,
#   'title': 'MOD SECRETARY',
#   'description': 'A Boring Documentary of a Mad Cow And a Cat who must Build a Lumberjack in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 95.4730407082,
#   'replacement_cost': 20.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 588,
#   'title': 'MODEL FISH',
#   'description': 'A Beautiful Panorama of a Boat And a Crocodile who must Outrace a Dog in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 102.5032184563,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 589,
#   'title': 'MODERN DORADO',
#   'description': 'A Awe-Inspiring Story of a Butler And a Sumo Wrestler who must Redeem a Boy in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 68.7805833146,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 590,
#   'title': 'MONEY HAROLD',
#   'description': 'A Touching Tale of a Explorer And a Boat who must Defeat a Robot in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 103.3686547418,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 591,
#   'title': 'MONSOON CAUSE',
#   'description': 'A Astounding Tale of a Crocodile And a Car who must Outrace a Squirrel in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 99.4409488482,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 592,
#   'title': 'MONSTER SPARTACUS',
#   'description': 'A Fast-Paced Story of a Waitress And a Cat who must Fight a Girl in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 90.8432491337,
#   'replacement_cost': 28.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 593,
#   'title': 'MONTEREY LABYRINTH',
#   'description': 'A Awe-Inspiring Drama of a Monkey And a Composer who must Escape a Feminist in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 116.5436335396,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 594,
#   'title': 'MONTEZUMA COMMAND',
#   'description': 'A Thrilling Reflection of a Waitress And a Butler who must Battle a Butler in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 93.2075458104,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 595,
#   'title': 'MOON BUNCH',
#   'description': 'A Beautiful Tale of a Astronaut And a Mad Cow who must Challenge a Cat in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 97.3435978495,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 596,
#   'title': 'MOONSHINE CABIN',
#   'description': 'A Thoughtful Display of a Astronaut And a Feminist who must Chase a Frisbee in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 135.2335613437,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 597,
#   'title': 'MOONWALKER FOOL',
#   'description': 'A Epic Drama of a Feminist And a Pioneer who must Sink a Composer in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 83.7834925987,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 598,
#   'title': 'MOSQUITO ARMAGEDDON',
#   'description': 'A Thoughtful Character Study of a Waitress And a Feminist who must Build a Teacher in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 72.1609902553,
#   'replacement_cost': 22.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 599,
#   'title': 'MOTHER OLEANDER',
#   'description': 'A Boring Tale of a Husband And a Boy who must Fight a Squirrel in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 132.445351294,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 600,
#   'title': 'MOTIONS DETAILS',
#   'description': 'A Awe-Inspiring Reflection of a Dog And a Student who must Kill a Car in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 86.0431052084,
#   'replacement_cost': 16.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 601,
#   'title': 'MOULIN WAKE',
#   'description': 'A Astounding Story of a Forensic Psychologist And a Cat who must Battle a Teacher in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 100.8679122511,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 602,
#   'title': 'MOURNING PURPLE',
#   'description': 'A Lacklusture Display of a Waitress And a Lumberjack who must Chase a Pioneer in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 107.6146599003,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 603,
#   'title': 'MOVIE SHAKESPEARE',
#   'description': 'A Insightful Display of a Database Administrator And a Student who must Build a Hunter in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 114.8962170632,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 604,
#   'title': 'MULAN MOON',
#   'description': 'A Emotional Saga of a Womanizer And a Pioneer who must Overcome a Dentist in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 84.2940897495,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 605,
#   'title': 'MULHOLLAND BEAST',
#   'description': 'A Awe-Inspiring Display of a Husband And a Squirrel who must Battle a Sumo Wrestler in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 113.9589522312,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 606,
#   'title': 'MUMMY CREATURES',
#   'description': 'A Fateful Character Study of a Crocodile And a Monkey who must Meet a Dentist in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 97.2036161554,
#   'replacement_cost': 15.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 607,
#   'title': 'MUPPET MILE',
#   'description': 'A Lacklusture Story of a Madman And a Teacher who must Kill a Frisbee in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 130.197801137,
#   'replacement_cost': 18.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 608,
#   'title': 'MURDER ANTITRUST',
#   'description': 'A Brilliant Yarn of a Car And a Database Administrator who must Escape a Boy in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 117.8159511141,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 609,
#   'title': 'MUSCLE BRIGHT',
#   'description': 'A Stunning Panorama of a Sumo Wrestler And a Husband who must Redeem a Madman in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 99.7974152466,
#   'replacement_cost': 23.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 610,
#   'title': 'MUSIC BOONDOCK',
#   'description': 'A Thrilling Tale of a Butler And a Astronaut who must Battle a Explorer in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 126.4033984622,
#   'replacement_cost': 17.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 611,
#   'title': 'MUSKETEERS WAIT',
#   'description': 'A Touching Yarn of a Student And a Moose who must Fight a Mad Cow in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 90.7775207248,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 612,
#   'title': 'MUSSOLINI SPOILERS',
#   'description': 'A Thrilling Display of a Boat And a Monkey who must Meet a Composer in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 76.7427980595,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 613,
#   'title': 'MYSTIC TRUMAN',
#   'description': 'A Epic Yarn of a Teacher And a Hunter who must Outgun a Explorer in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 102.9121840835,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 614,
#   'title': 'NAME DETECTIVE',
#   'description': 'A Touching Saga of a Sumo Wrestler And a Cat who must Pursue a Mad Scientist in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 105.8357795685,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 615,
#   'title': 'NASH CHOCOLAT',
#   'description': 'A Epic Reflection of a Monkey And a Mad Cow who must Kill a Forensic Psychologist in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 82.8036496365,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 616,
#   'title': 'NATIONAL STORY',
#   'description': 'A Taut Epistle of a Mad Scientist And a Girl who must Escape a Monkey in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 80.5580049553,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 617,
#   'title': 'NATURAL STOCK',
#   'description': 'A Fast-Paced Story of a Sumo Wrestler And a Girl who must Defeat a Car in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 121.5495944972,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 618,
#   'title': 'NECKLACE OUTBREAK',
#   'description': 'A Astounding Epistle of a Database Administrator And a Mad Scientist who must Pursue a Cat in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 103.2279025517,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 619,
#   'title': 'NEIGHBORS CHARADE',
#   'description': 'A Fanciful Reflection of a Crocodile And a Astronaut who must Outrace a Feminist in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 122.046096782,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 620,
#   'title': 'NEMO CAMPUS',
#   'description': 'A Lacklusture Reflection of a Monkey And a Squirrel who must Outrace a Womanizer in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 79.1843234161,
#   'replacement_cost': 23.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 621,
#   'title': 'NETWORK PEAK',
#   'description': 'A Unbelieveable Reflection of a Butler And a Boat who must Outgun a Mad Scientist in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 109.8664650216,
#   'replacement_cost': 23.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 622,
#   'title': 'NEWSIES STORY',
#   'description': 'A Action-Packed Character Study of a Dog And a Lumberjack who must Outrace a Moose in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 98.3124366009,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 623,
#   'title': 'NEWTON LABYRINTH',
#   'description': 'A Intrepid Character Study of a Moose And a Waitress who must Find a A Shark in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 115.6882088144,
#   'replacement_cost': 9.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 624,
#   'title': 'NIGHTMARE CHILL',
#   'description': 'A Brilliant Display of a Robot And a Butler who must Fight a Waitress in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 124.0300502001,
#   'replacement_cost': 25.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 625,
#   'title': 'NONE SPIKING',
#   'description': 'A Boring Reflection of a Secret Agent And a Astronaut who must Face a Composer in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 98.7250184098,
#   'replacement_cost': 18.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 626,
#   'title': 'NOON PAPI',
#   'description': 'A Unbelieveable Character Study of a Mad Scientist And a Astronaut who must Find a Pioneer in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 89.8330979972,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 627,
#   'title': 'NORTH TEQUILA',
#   'description': 'A Beautiful Character Study of a Mad Cow And a Robot who must Reach a Womanizer in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 78.1678786247,
#   'replacement_cost': 9.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 628,
#   'title': 'NORTHWEST POLISH',
#   'description': 'A Boring Character Study of a Boy And a A Shark who must Outrace a Womanizer in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 102.4519468498,
#   'replacement_cost': 24.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 629,
#   'title': 'NOTORIOUS REUNION',
#   'description': 'A Amazing Epistle of a Woman And a Squirrel who must Fight a Hunter in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 93.330501673,
#   'replacement_cost': 9.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 630,
#   'title': 'NOTTING SPEAKEASY',
#   'description': 'A Thoughtful Display of a Butler And a Womanizer who must Find a Waitress in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 117.4796650378,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 631,
#   'title': 'NOVOCAINE FLIGHT',
#   'description': 'A Fanciful Display of a Student And a Teacher who must Outgun a Crocodile in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 80.5659878128,
#   'replacement_cost': 11.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 632,
#   'title': 'NUTS TIES',
#   'description': 'A Thoughtful Drama of a Explorer And a Womanizer who must Meet a Teacher in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 77.6080219413,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 633,
#   'title': 'OCTOBER SUBMARINE',
#   'description': 'A Taut Epistle of a Monkey And a Boy who must Confront a Husband in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 133.7093458805,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 634,
#   'title': 'ODDS BOOGIE',
#   'description': 'A Thrilling Yarn of a Feminist And a Madman who must Battle a Hunter in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 137.1027538235,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 635,
#   'title': 'OKLAHOMA JUMANJI',
#   'description': 'A Thoughtful Drama of a Dentist And a Womanizer who must Meet a Husband in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 125.4168173231,
#   'replacement_cost': 15.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 636,
#   'title': 'OLEANDER CLUE',
#   'description': 'A Boring Story of a Teacher And a Monkey who must Succumb a Forensic Psychologist in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 107.1586489035,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 637,
#   'title': 'OPEN AFRICAN',
#   'description': 'A Lacklusture Drama of a Secret Agent And a Explorer who must Discover a Car in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 124.1272363373,
#   'replacement_cost': 16.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 638,
#   'title': 'OPERATION OPERATION',
#   'description': 'A Intrepid Character Study of a Man And a Frisbee who must Overcome a Madman in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 85.1397189252,
#   'replacement_cost': 23.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 639,
#   'title': 'OPPOSITE NECKLACE',
#   'description': 'A Fateful Epistle of a Crocodile And a Moose who must Kill a Explorer in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 117.4162644844,
#   'replacement_cost': 9.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 640,
#   'title': 'OPUS ICE',
#   'description': 'A Fast-Paced Drama of a Hunter And a Boy who must Discover a Feminist in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 125.7069367209,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 641,
#   'title': 'ORANGE GRAPES',
#   'description': 'A Astounding Documentary of a Butler And a Womanizer who must Face a Dog in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 112.2966936831,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 642,
#   'title': 'ORDER BETRAYED',
#   'description': 'A Amazing Saga of a Dog And a A Shark who must Challenge a Cat in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 92.1202895626,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 643,
#   'title': 'ORIENT CLOSER',
#   'description': 'A Astounding Epistle of a Technical Writer And a Teacher who must Fight a Squirrel in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 137.5939711166,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 644,
#   'title': 'OSCAR GOLD',
#   'description': 'A Insightful Tale of a Database Administrator And a Dog who must Face a Madman in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 128.4014997722,
#   'replacement_cost': 29.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 645,
#   'title': 'OTHERS SOUP',
#   'description': 'A Lacklusture Documentary of a Mad Cow And a Madman who must Sink a Moose in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 113.9799265077,
#   'replacement_cost': 18.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 646,
#   'title': 'OUTBREAK DIVINE',
#   'description': 'A Unbelieveable Yarn of a Database Administrator And a Woman who must Succumb a A Shark in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 94.7961651708,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 647,
#   'title': 'OUTFIELD MASSACRE',
#   'description': 'A Thoughtful Drama of a Husband And a Secret Agent who must Pursue a Database Administrator in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 87.6903694418,
#   'replacement_cost': 18.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 648,
#   'title': 'OUTLAW HANKY',
#   'description': 'A Thoughtful Story of a Astronaut And a Composer who must Conquer a Dog in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 111.2373492805,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 649,
#   'title': 'OZ LIAISONS',
#   'description': 'A Epic Yarn of a Mad Scientist And a Cat who must Confront a Womanizer in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 122.7894884549,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 650,
#   'title': 'PACIFIC AMISTAD',
#   'description': 'A Thrilling Yarn of a Dog And a Moose who must Kill a Pastry Chef in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 84.9864356773,
#   'replacement_cost': 27.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 651,
#   'title': 'PACKER MADIGAN',
#   'description': 'A Epic Display of a Sumo Wrestler And a Forensic Psychologist who must Build a Woman in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 129.81133916,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 652,
#   'title': 'PAJAMA JAWBREAKER',
#   'description': 'A Emotional Drama of a Boy And a Technical Writer who must Redeem a Sumo Wrestler in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 145.8522869168,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 653,
#   'title': 'PANIC CLUB',
#   'description': 'A Fanciful Display of a Teacher And a Crocodile who must Succumb a Girl in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 96.4681929721,
#   'replacement_cost': 15.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 654,
#   'title': 'PANKY SUBMARINE',
#   'description': 'A Touching Documentary of a Dentist And a Sumo Wrestler who must Overcome a Boy in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 5.99,
#   'length': 98.207904805,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 655,
#   'title': 'PANTHER REDS',
#   'description': 'A Brilliant Panorama of a Moose And a Man who must Reach a Teacher in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 92.0178281424,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 656,
#   'title': 'PAPI NECKLACE',
#   'description': 'A Fanciful Display of a Car And a Monkey who must Escape a Squirrel in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 95.0332307763,
#   'replacement_cost': 9.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 657,
#   'title': 'PARADISE SABRINA',
#   'description': 'A Intrepid Yarn of a Car And a Moose who must Outrace a Crocodile in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 106.2997354127,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 658,
#   'title': 'PARIS WEEKEND',
#   'description': 'A Intrepid Story of a Squirrel And a Crocodile who must Defeat a Monkey in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 107.8242785627,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 659,
#   'title': 'PARK CITIZEN',
#   'description': 'A Taut Epistle of a Sumo Wrestler And a Girl who must Face a Husband in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 119.8611223713,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 660,
#   'title': 'PARTY KNOCK',
#   'description': 'A Fateful Display of a Technical Writer And a Butler who must Battle a Sumo Wrestler in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 111.6872221229,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 661,
#   'title': 'PAST SUICIDES',
#   'description': 'A Intrepid Tale of a Madman And a Astronaut who must Challenge a Hunter in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 96.6300610385,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 662,
#   'title': 'PATHS CONTROL',
#   'description': 'A Astounding Documentary of a Butler And a Cat who must Find a Frisbee in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 143.0598261754,
#   'replacement_cost': 9.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 663,
#   'title': 'PATIENT SISTER',
#   'description': 'A Emotional Epistle of a Squirrel And a Robot who must Confront a Lumberjack in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 105.5637741224,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 664,
#   'title': 'PATRIOT ROMAN',
#   'description': 'A Taut Saga of a Robot And a Database Administrator who must Challenge a Astronaut in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 97.2312050749,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 665,
#   'title': 'PATTON INTERVIEW',
#   'description': 'A Thrilling Documentary of a Composer And a Secret Agent who must Succumb a Cat in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 77.1593338821,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 666,
#   'title': 'PAYCHECK WAIT',
#   'description': 'A Awe-Inspiring Reflection of a Boy And a Man who must Discover a Moose in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 114.675435825,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 667,
#   'title': 'PEACH INNOCENT',
#   'description': 'A Action-Packed Drama of a Monkey And a Dentist who must Chase a Butler in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 121.7570875313,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 668,
#   'title': 'PEAK FOREVER',
#   'description': 'A Insightful Reflection of a Boat And a Secret Agent who must Vanquish a Astronaut in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 136.5573619265,
#   'replacement_cost': 25.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 669,
#   'title': 'PEARL DESTINY',
#   'description': 'A Lacklusture Yarn of a Astronaut And a Pastry Chef who must Sink a Dog in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 98.2212227014,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 670,
#   'title': 'PELICAN COMFORTS',
#   'description': 'A Epic Documentary of a Boy And a Monkey who must Pursue a Astronaut in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 111.1297920663,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 671,
#   'title': 'PERDITION FARGO',
#   'description': 'A Fast-Paced Story of a Car And a Cat who must Outgun a Hunter in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 97.1890702462,
#   'replacement_cost': 27.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 672,
#   'title': 'PERFECT GROOVE',
#   'description': 'A Thrilling Yarn of a Dog And a Dog who must Build a Husband in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 109.4319985663,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 673,
#   'title': 'PERSONAL LADYBUGS',
#   'description': 'A Epic Saga of a Hunter And a Technical Writer who must Conquer a Cat in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 108.5294869757,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 674,
#   'title': 'PET HAUNTING',
#   'description': 'A Unbelieveable Reflection of a Explorer And a Boat who must Conquer a Woman in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 95.5994812179,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 675,
#   'title': 'PHANTOM GLORY',
#   'description': 'A Beautiful Documentary of a Astronaut And a Crocodile who must Discover a Madman in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 76.7131715793,
#   'replacement_cost': 17.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 676,
#   'title': 'PHILADELPHIA WIFE',
#   'description': 'A Taut Yarn of a Hunter And a Astronaut who must Conquer a Database Administrator in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 119.2819037458,
#   'replacement_cost': 16.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 677,
#   'title': 'PIANIST OUTFIELD',
#   'description': 'A Intrepid Story of a Boy And a Technical Writer who must Pursue a Lumberjack in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 118.7211890655,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 678,
#   'title': 'PICKUP DRIVING',
#   'description': 'A Touching Documentary of a Husband And a Boat who must Meet a Pastry Chef in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 73.2090726117,
#   'replacement_cost': 23.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 679,
#   'title': 'PILOT HOOSIERS',
#   'description': 'A Awe-Inspiring Reflection of a Crocodile And a Sumo Wrestler who must Meet a Forensic Psychologist in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 95.895752543,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 680,
#   'title': 'PINOCCHIO SIMON',
#   'description': 'A Action-Packed Reflection of a Mad Scientist And a A Shark who must Find a Feminist in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 81.8981316541,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 681,
#   'title': 'PIRATES ROXANNE',
#   'description': 'A Stunning Drama of a Woman And a Lumberjack who must Overcome a A Shark in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 115.5594913928,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 682,
#   'title': 'PITTSBURGH HUNCHBACK',
#   'description': 'A Thrilling Epistle of a Boy And a Boat who must Find a Student in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 128.8753519342,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 683,
#   'title': 'PITY BOUND',
#   'description': 'A Boring Panorama of a Feminist And a Moose who must Defeat a Database Administrator in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 102.0257450986,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 684,
#   'title': 'PIZZA JUMANJI',
#   'description': 'A Epic Saga of a Cat And a Squirrel who must Outgun a Robot in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 93.8155156652,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 685,
#   'title': 'PLATOON INSTINCT',
#   'description': 'A Thrilling Panorama of a Man And a Woman who must Reach a Woman in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 128.4573597296,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 686,
#   'title': 'PLUTO OLEANDER',
#   'description': 'A Action-Packed Reflection of a Car And a Moose who must Outgun a Car in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 113.924290796,
#   'replacement_cost': 9.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 687,
#   'title': 'POCUS PULP',
#   'description': 'A Intrepid Yarn of a Frisbee And a Dog who must Build a Astronaut in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 106.5741392962,
#   'replacement_cost': 15.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 688,
#   'title': 'POLISH BROOKLYN',
#   'description': 'A Boring Character Study of a Database Administrator And a Lumberjack who must Reach a Madman in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 107.1481990774,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 689,
#   'title': 'POLLOCK DELIVERANCE',
#   'description': 'A Intrepid Story of a Madman And a Frisbee who must Outgun a Boat in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 95.5050205396,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 690,
#   'title': 'POND SEATTLE',
#   'description': 'A Stunning Drama of a Teacher And a Boat who must Battle a Feminist in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 92.9165705318,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 691,
#   'title': 'POSEIDON FOREVER',
#   'description': 'A Thoughtful Epistle of a Womanizer And a Monkey who must Vanquish a Dentist in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 101.7015773641,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 692,
#   'title': 'POTLUCK MIXED',
#   'description': 'A Beautiful Story of a Dog And a Technical Writer who must Outgun a Student in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 90.1898438345,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 693,
#   'title': 'POTTER CONNECTICUT',
#   'description': 'A Thrilling Epistle of a Frisbee And a Cat who must Fight a Technical Writer in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 98.6526676084,
#   'replacement_cost': 16.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 694,
#   'title': 'PREJUDICE OLEANDER',
#   'description': 'A Epic Saga of a Boy And a Dentist who must Outrace a Madman in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 91.4958079945,
#   'replacement_cost': 15.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 695,
#   'title': 'PRESIDENT BANG',
#   'description': 'A Fateful Panorama of a Technical Writer And a Moose who must Battle a Robot in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 98.5815605368,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 696,
#   'title': 'PRIDE ALAMO',
#   'description': 'A Thoughtful Drama of a A Shark And a Forensic Psychologist who must Vanquish a Student in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 106.9944243258,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 697,
#   'title': 'PRIMARY GLASS',
#   'description': 'A Fateful Documentary of a Pastry Chef And a Butler who must Build a Dog in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 91.827930407,
#   'replacement_cost': 16.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 698,
#   'title': 'PRINCESS GIANT',
#   'description': 'A Thrilling Yarn of a Pastry Chef And a Monkey who must Battle a Monkey in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 72.6027035062,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 699,
#   'title': 'PRIVATE DROP',
#   'description': 'A Stunning Story of a Technical Writer And a Hunter who must Succumb a Secret Agent in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 121.0096667916,
#   'replacement_cost': 26.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 700,
#   'title': 'PRIX UNDEFEATED',
#   'description': 'A Stunning Saga of a Mad Scientist And a Boat who must Overcome a Dentist in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 157.0022839712,
#   'replacement_cost': 13.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 701,
#   'title': 'PSYCHO SHRUNK',
#   'description': 'A Amazing Panorama of a Crocodile And a Explorer who must Fight a Husband in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 125.5108434665,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 702,
#   'title': 'PULP BEVERLY',
#   'description': 'A Unbelieveable Display of a Dog And a Crocodile who must Outrace a Man in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 86.8281404793,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 703,
#   'title': 'PUNK DIVORCE',
#   'description': 'A Fast-Paced Tale of a Pastry Chef And a Boat who must Face a Frisbee in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 102.2628248924,
#   'replacement_cost': 18.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 704,
#   'title': 'PURE RUNNER',
#   'description': 'A Thoughtful Documentary of a Student And a Madman who must Challenge a Squirrel in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 145.6673796668,
#   'replacement_cost': 25.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 705,
#   'title': 'PURPLE MOVIE',
#   'description': 'A Boring Display of a Pastry Chef And a Sumo Wrestler who must Discover a Frisbee in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 154.6084060444,
#   'replacement_cost': 9.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 706,
#   'title': 'QUEEN LUKE',
#   'description': 'A Astounding Story of a Girl And a Boy who must Challenge a Composer in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 125.6964277076,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 707,
#   'title': 'QUEST MUSSOLINI',
#   'description': 'A Fateful Drama of a Husband And a Sumo Wrestler who must Battle a Pastry Chef in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 118.1103586852,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 708,
#   'title': 'QUILLS BULL',
#   'description': 'A Thoughtful Story of a Pioneer And a Woman who must Reach a Moose in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 140.9237302204,
#   'replacement_cost': 19.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 709,
#   'title': 'RACER EGG',
#   'description': 'A Emotional Display of a Monkey And a Waitress who must Reach a Secret Agent in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 145.0085322236,
#   'replacement_cost': 19.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 710,
#   'title': 'RAGE GAMES',
#   'description': 'A Fast-Paced Saga of a Astronaut And a Secret Agent who must Escape a Hunter in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 143.7188605983,
#   'replacement_cost': 18.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 711,
#   'title': 'RAGING AIRPLANE',
#   'description': 'A Astounding Display of a Secret Agent And a Technical Writer who must Escape a Mad Scientist in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 127.246318837,
#   'replacement_cost': 18.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 712,
#   'title': 'RAIDERS ANTITRUST',
#   'description': 'A Amazing Drama of a Teacher And a Feminist who must Meet a Woman in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 76.2526808456,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 713,
#   'title': 'RAINBOW SHOCK',
#   'description': 'A Action-Packed Story of a Hunter And a Boy who must Discover a Lumberjack in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 92.4323013201,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 714,
#   'title': 'RANDOM GO',
#   'description': 'A Fateful Drama of a Frisbee And a Student who must Confront a Cat in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 92.2635082868,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 715,
#   'title': 'RANGE MOONWALKER',
#   'description': 'A Insightful Documentary of a Hunter And a Dentist who must Confront a Crocodile in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 95.8184391648,
#   'replacement_cost': 25.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 716,
#   'title': 'REAP UNFAITHFUL',
#   'description': 'A Thrilling Epistle of a Composer And a Sumo Wrestler who must Challenge a Mad Cow in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 121.5233725179,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 717,
#   'title': 'REAR TRADING',
#   'description': 'A Awe-Inspiring Reflection of a Forensic Psychologist And a Secret Agent who must Succumb a Pastry Chef in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 80.4353461585,
#   'replacement_cost': 23.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 718,
#   'title': 'REBEL AIRPORT',
#   'description': 'A Intrepid Yarn of a Database Administrator And a Boat who must Outrace a Husband in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 77.0352284371,
#   'replacement_cost': 24.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 719,
#   'title': 'RECORDS ZORRO',
#   'description': 'A Amazing Drama of a Mad Scientist And a Composer who must Build a Husband in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 97.7609145452,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 720,
#   'title': 'REDEMPTION COMFORTS',
#   'description': 'A Emotional Documentary of a Dentist And a Woman who must Battle a Mad Scientist in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 105.4853175675,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 721,
#   'title': 'REDS POCUS',
#   'description': 'A Lacklusture Yarn of a Sumo Wrestler And a Squirrel who must Redeem a Monkey in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 121.8891190495,
#   'replacement_cost': 23.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 722,
#   'title': 'REEF SALUTE',
#   'description': 'A Action-Packed Saga of a Teacher And a Lumberjack who must Battle a Dentist in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 96.9196889467,
#   'replacement_cost': 26.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 723,
#   'title': 'REIGN GENTLEMEN',
#   'description': 'A Emotional Yarn of a Composer And a Man who must Escape a Butler in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 90.0872947345,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 724,
#   'title': 'REMEMBER DIARY',
#   'description': 'A Insightful Tale of a Technical Writer And a Waitress who must Conquer a Monkey in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 152.0698871422,
#   'replacement_cost': 15.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 725,
#   'title': 'REQUIEM TYCOON',
#   'description': 'A Unbelieveable Character Study of a Cat And a Database Administrator who must Pursue a Teacher in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 136.2317918734,
#   'replacement_cost': 25.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 726,
#   'title': 'RESERVOIR ADAPTATION',
#   'description': 'A Intrepid Drama of a Teacher And a Moose who must Kill a Car in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 109.2091879456,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 727,
#   'title': 'RESURRECTION SILVERADO',
#   'description': 'A Epic Yarn of a Robot And a Explorer who must Challenge a Girl in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 103.6371997943,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 728,
#   'title': 'REUNION WITCHES',
#   'description': 'A Unbelieveable Documentary of a Database Administrator And a Frisbee who must Redeem a Mad Scientist in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 110.5665410038,
#   'replacement_cost': 26.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 729,
#   'title': 'RIDER CADDYSHACK',
#   'description': 'A Taut Reflection of a Monkey And a Womanizer who must Chase a Moose in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 120.3835275672,
#   'replacement_cost': 28.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 730,
#   'title': 'RIDGEMONT SUBMARINE',
#   'description': 'A Unbelieveable Drama of a Waitress And a Composer who must Sink a Mad Cow in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 70.909301707,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 731,
#   'title': 'RIGHT CRANES',
#   'description': 'A Fateful Character Study of a Boat And a Cat who must Find a Database Administrator in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 97.3001646242,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 732,
#   'title': 'RINGS HEARTBREAKERS',
#   'description': 'A Amazing Yarn of a Sumo Wrestler And a Boat who must Conquer a Waitress in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 1.99,
#   'length': 80.5530886802,
#   'replacement_cost': 17.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 733,
#   'title': 'RIVER OUTLAW',
#   'description': 'A Thrilling Character Study of a Squirrel And a Lumberjack who must Face a Hunter in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 121.0985983996,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 734,
#   'title': 'ROAD ROXANNE',
#   'description': 'A Boring Character Study of a Waitress And a Astronaut who must Fight a Crocodile in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 166.9592249182,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 735,
#   'title': 'ROBBERS JOON',
#   'description': 'A Thoughtful Story of a Mad Scientist And a Waitress who must Confront a Forensic Psychologist in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 128.2322211732,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 736,
#   'title': 'ROBBERY BRIGHT',
#   'description': 'A Taut Reflection of a Robot And a Squirrel who must Fight a Boat in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 131.9023674053,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 737,
#   'title': 'ROCK INSTINCT',
#   'description': 'A Astounding Character Study of a Robot And a Moose who must Overcome a Astronaut in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 67.5872349245,
#   'replacement_cost': 28.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 738,
#   'title': 'ROCKETEER MOTHER',
#   'description': 'A Awe-Inspiring Character Study of a Robot And a Sumo Wrestler who must Discover a Womanizer in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 134.4711213786,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 739,
#   'title': 'ROCKY WAR',
#   'description': 'A Fast-Paced Display of a Squirrel And a Explorer who must Outgun a Mad Scientist in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 109.1587754274,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 740,
#   'title': 'ROLLERCOASTER BRINGING',
#   'description': 'A Beautiful Drama of a Robot And a Lumberjack who must Discover a Technical Writer in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 96.8366529938,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 741,
#   'title': 'ROMAN PUNK',
#   'description': 'A Thoughtful Panorama of a Mad Cow And a Student who must Battle a Forensic Psychologist in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 104.2142768878,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 742,
#   'title': 'ROOF CHAMPION',
#   'description': 'A Lacklusture Reflection of a Car And a Explorer who must Find a Monkey in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 148.8437562371,
#   'replacement_cost': 25.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 743,
#   'title': 'ROOM ROMAN',
#   'description': 'A Awe-Inspiring Panorama of a Composer And a Secret Agent who must Sink a Composer in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 123.1494414617,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 744,
#   'title': 'ROOTS REMEMBER',
#   'description': 'A Brilliant Drama of a Mad Cow And a Hunter who must Escape a Hunter in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 81.2280409566,
#   'replacement_cost': 23.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 745,
#   'title': 'ROSES TREASURE',
#   'description': 'A Astounding Panorama of a Monkey And a Secret Agent who must Defeat a Woman in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 130.3189558344,
#   'replacement_cost': 23.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 746,
#   'title': 'ROUGE SQUAD',
#   'description': 'A Awe-Inspiring Drama of a Astronaut And a Frisbee who must Conquer a Mad Scientist in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 88.9159629358,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 747,
#   'title': 'ROXANNE REBEL',
#   'description': 'A Astounding Story of a Pastry Chef And a Database Administrator who must Fight a Man in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 119.5913447188,
#   'replacement_cost': 9.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 748,
#   'title': 'RUGRATS SHAKESPEARE',
#   'description': 'A Touching Saga of a Crocodile And a Crocodile who must Discover a Technical Writer in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 127.6694927357,
#   'replacement_cost': 16.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 749,
#   'title': 'RULES HUMAN',
#   'description': 'A Beautiful Epistle of a Astronaut And a Student who must Confront a Monkey in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 115.9924396022,
#   'replacement_cost': 19.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 750,
#   'title': 'RUN PACIFIC',
#   'description': 'A Touching Tale of a Cat And a Pastry Chef who must Conquer a Pastry Chef in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 143.2359748127,
#   'replacement_cost': 25.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 751,
#   'title': 'RUNAWAY TENENBAUMS',
#   'description': 'A Thoughtful Documentary of a Boat And a Man who must Meet a Boat in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 96.352802489,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 752,
#   'title': 'RUNNER MADIGAN',
#   'description': 'A Thoughtful Documentary of a Crocodile And a Robot who must Outrace a Womanizer in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 91.279744764,
#   'replacement_cost': 27.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 753,
#   'title': 'RUSH GOODFELLAS',
#   'description': 'A Emotional Display of a Man And a Dentist who must Challenge a Squirrel in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 124.173430034,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 754,
#   'title': 'RUSHMORE MERMAID',
#   'description': 'A Boring Story of a Woman And a Moose who must Reach a Husband in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 137.4736422712,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 755,
#   'title': 'SABRINA MIDNIGHT',
#   'description': 'A Emotional Story of a Squirrel And a Crocodile who must Succumb a Husband in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 106.4250522221,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 756,
#   'title': 'SADDLE ANTITRUST',
#   'description': 'A Stunning Epistle of a Feminist And a A Shark who must Battle a Woman in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 89.7070905049,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 757,
#   'title': 'SAGEBRUSH CLUELESS',
#   'description': 'A Insightful Story of a Lumberjack And a Hunter who must Kill a Boy in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 107.4890028915,
#   'replacement_cost': 28.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 758,
#   'title': 'SAINTS BRIDE',
#   'description': 'A Fateful Tale of a Technical Writer And a Composer who must Pursue a Explorer in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 79.3830858542,
#   'replacement_cost': 11.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 759,
#   'title': 'SALUTE APOLLO',
#   'description': 'A Awe-Inspiring Character Study of a Boy And a Feminist who must Sink a Crocodile in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 142.3294336332,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 760,
#   'title': 'SAMURAI LION',
#   'description': 'A Fast-Paced Story of a Pioneer And a Astronaut who must Reach a Boat in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 91.420808634,
#   'replacement_cost': 21.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 761,
#   'title': 'SANTA PARIS',
#   'description': 'A Emotional Documentary of a Moose And a Car who must Redeem a Mad Cow in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 128.8296736303,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 762,
#   'title': 'SASSY PACKER',
#   'description': 'A Fast-Paced Documentary of a Dog And a Teacher who must Find a Moose in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 73.6183326639,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 763,
#   'title': 'SATISFACTION CONFIDENTIAL',
#   'description': 'A Lacklusture Yarn of a Dentist And a Butler who must Meet a Secret Agent in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 100.0746767259,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 764,
#   'title': 'SATURDAY LAMBS',
#   'description': 'A Thoughtful Reflection of a Mad Scientist And a Moose who must Kill a Husband in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 117.9546177265,
#   'replacement_cost': 28.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 765,
#   'title': 'SATURN NAME',
#   'description': 'A Fateful Epistle of a Butler And a Boy who must Redeem a Teacher in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 118.8251918607,
#   'replacement_cost': 18.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 766,
#   'title': 'SAVANNAH TOWN',
#   'description': 'A Awe-Inspiring Tale of a Astronaut And a Database Administrator who must Chase a Secret Agent in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 118.394190378,
#   'replacement_cost': 25.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 767,
#   'title': 'SCALAWAG DUCK',
#   'description': 'A Fateful Reflection of a Car And a Teacher who must Confront a Waitress in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 102.4796884024,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 768,
#   'title': 'SCARFACE BANG',
#   'description': 'A Emotional Yarn of a Teacher And a Girl who must Find a Teacher in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 97.8698710127,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 769,
#   'title': 'SCHOOL JACKET',
#   'description': 'A Intrepid Yarn of a Monkey And a Boy who must Fight a Composer in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 83.9255787212,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 770,
#   'title': 'SCISSORHANDS SLUMS',
#   'description': 'A Awe-Inspiring Drama of a Girl And a Technical Writer who must Meet a Feminist in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 71.4959943416,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 788,
#   'title': 'SHIP WONDERLAND',
#   'description': 'A Thrilling Saga of a Monkey And a Frisbee who must Escape a Explorer in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 133.6996505715,
#   'replacement_cost': 15.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 771,
#   'title': 'SCORPION APOLLO',
#   'description': 'A Awe-Inspiring Documentary of a Technical Writer And a Husband who must Meet a Monkey in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 110.0745115155,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 772,
#   'title': 'SEA VIRGIN',
#   'description': 'A Fast-Paced Documentary of a Technical Writer And a Pastry Chef who must Escape a Moose in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 92.4421831854,
#   'replacement_cost': 24.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 773,
#   'title': 'SEABISCUIT PUNK',
#   'description': 'A Insightful Saga of a Man And a Forensic Psychologist who must Discover a Mad Cow in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 99.1549961453,
#   'replacement_cost': 28.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 774,
#   'title': 'SEARCHERS WAIT',
#   'description': 'A Fast-Paced Tale of a Car And a Mad Scientist who must Kill a Womanizer in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 116.8405253993,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 775,
#   'title': 'SEATTLE EXPECATIONS',
#   'description': 'A Insightful Reflection of a Crocodile And a Sumo Wrestler who must Meet a Technical Writer in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 115.9377135783,
#   'replacement_cost': 18.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 776,
#   'title': 'SECRET GROUNDHOG',
#   'description': 'A Astounding Story of a Cat And a Database Administrator who must Build a Technical Writer in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 114.3506661474,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 777,
#   'title': 'SECRETARY ROUGE',
#   'description': 'A Action-Packed Panorama of a Mad Cow And a Composer who must Discover a Robot in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 98.1232098977,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 778,
#   'title': 'SECRETS PARADISE',
#   'description': 'A Fateful Saga of a Cat And a Frisbee who must Kill a Girl in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 86.5861572276,
#   'replacement_cost': 24.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 779,
#   'title': 'SENSE GREEK',
#   'description': 'A Taut Saga of a Lumberjack And a Pastry Chef who must Escape a Sumo Wrestler in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 146.3864112682,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 780,
#   'title': 'SENSIBILITY REAR',
#   'description': 'A Emotional Tale of a Robot And a Sumo Wrestler who must Redeem a Pastry Chef in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 105.3302990595,
#   'replacement_cost': 15.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 781,
#   'title': 'SEVEN SWARM',
#   'description': 'A Unbelieveable Character Study of a Dog And a Mad Cow who must Kill a Monkey in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 112.8284742636,
#   'replacement_cost': 15.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 782,
#   'title': 'SHAKESPEARE SADDLE',
#   'description': 'A Fast-Paced Panorama of a Lumberjack And a Database Administrator who must Defeat a Madman in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 92.6194058099,
#   'replacement_cost': 26.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 783,
#   'title': 'SHANE DARKNESS',
#   'description': 'A Action-Packed Saga of a Moose And a Lumberjack who must Find a Woman in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 106.9586848726,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 784,
#   'title': 'SHANGHAI TYCOON',
#   'description': 'A Fast-Paced Character Study of a Crocodile And a Lumberjack who must Build a Husband in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 109.6672904218,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 785,
#   'title': 'SHAWSHANK BUBBLE',
#   'description': 'A Lacklusture Story of a Moose And a Monkey who must Confront a Butler in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 79.2759774338,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 786,
#   'title': 'SHEPHERD MIDSUMMER',
#   'description': 'A Thoughtful Drama of a Robot And a Womanizer who must Kill a Lumberjack in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 141.1363579962,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 787,
#   'title': 'SHINING ROSES',
#   'description': 'A Awe-Inspiring Character Study of a Astronaut And a Forensic Psychologist who must Challenge a Madman in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 111.3583711348,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 789,
#   'title': 'SHOCK CABIN',
#   'description': 'A Fateful Tale of a Mad Cow And a Crocodile who must Meet a Husband in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 127.9054103108,
#   'replacement_cost': 15.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 790,
#   'title': 'SHOOTIST SUPERFLY',
#   'description': 'A Fast-Paced Story of a Crocodile And a A Shark who must Sink a Pioneer in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 96.5046240395,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 791,
#   'title': 'SHOW LORD',
#   'description': 'A Fanciful Saga of a Student And a Girl who must Find a Butler in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 111.5826351796,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 792,
#   'title': 'SHREK LICENSE',
#   'description': 'A Fateful Yarn of a Secret Agent And a Feminist who must Find a Feminist in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 102.8154476261,
#   'replacement_cost': 15.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 793,
#   'title': 'SHRUNK DIVINE',
#   'description': 'A Fateful Character Study of a Waitress And a Technical Writer who must Battle a Hunter in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 145.9825261561,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 794,
#   'title': 'SIDE ARK',
#   'description': 'A Stunning Panorama of a Crocodile And a Womanizer who must Meet a Feminist in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 1.99,
#   'length': 95.5169600457,
#   'replacement_cost': 28.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 795,
#   'title': 'SIEGE MADRE',
#   'description': 'A Boring Tale of a Frisbee And a Crocodile who must Vanquish a Moose in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 135.5590570432,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 796,
#   'title': 'SIERRA DIVIDE',
#   'description': 'A Emotional Character Study of a Frisbee And a Mad Scientist who must Build a Madman in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 152.7661642756,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 797,
#   'title': 'SILENCE KANE',
#   'description': 'A Emotional Drama of a Sumo Wrestler And a Dentist who must Confront a Sumo Wrestler in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 135.4526988971,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 798,
#   'title': 'SILVERADO GOLDFINGER',
#   'description': 'A Stunning Epistle of a Sumo Wrestler And a Man who must Challenge a Waitress in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 86.9175768925,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 799,
#   'title': 'SIMON NORTH',
#   'description': 'A Thrilling Documentary of a Technical Writer And a A Shark who must Face a Pioneer in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 105.8316756471,
#   'replacement_cost': 26.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 800,
#   'title': 'SINNERS ATLANTIS',
#   'description': 'A Epic Display of a Dog And a Boat who must Succumb a Mad Scientist in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 112.0312109183,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 801,
#   'title': 'SISTER FREDDY',
#   'description': 'A Stunning Saga of a Butler And a Woman who must Pursue a Explorer in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 100.5158194717,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 802,
#   'title': 'SKY MIRACLE',
#   'description': 'A Epic Drama of a Mad Scientist And a Explorer who must Succumb a Waitress in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 108.8996069618,
#   'replacement_cost': 15.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 803,
#   'title': 'SLACKER LIAISONS',
#   'description': 'A Fast-Paced Tale of a A Shark And a Student who must Meet a Crocodile in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 134.3976026683,
#   'replacement_cost': 29.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 804,
#   'title': 'SLEEPING SUSPECTS',
#   'description': 'A Stunning Reflection of a Sumo Wrestler And a Explorer who must Sink a Frisbee in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 122.3070894538,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 805,
#   'title': 'SLEEPLESS MONSOON',
#   'description': 'A Amazing Saga of a Moose And a Pastry Chef who must Escape a Butler in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 91.7237349477,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 806,
#   'title': 'SLEEPY JAPANESE',
#   'description': 'A Emotional Epistle of a Moose And a Composer who must Fight a Technical Writer in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 97.1344742806,
#   'replacement_cost': 25.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 807,
#   'title': 'SLEUTH ORIENT',
#   'description': 'A Fateful Character Study of a Husband And a Dog who must Find a Feminist in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 130.0163089971,
#   'replacement_cost': 25.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 808,
#   'title': 'SLING LUKE',
#   'description': 'A Intrepid Character Study of a Robot And a Monkey who must Reach a Secret Agent in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 136.3001076428,
#   'replacement_cost': 10.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 809,
#   'title': 'SLIPPER FIDELITY',
#   'description': 'A Taut Reflection of a Secret Agent And a Man who must Redeem a Explorer in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 119.1581771156,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 810,
#   'title': 'SLUMS DUCK',
#   'description': 'A Amazing Character Study of a Teacher And a Database Administrator who must Defeat a Waitress in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 78.5945885795,
#   'replacement_cost': 21.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 811,
#   'title': 'SMILE EARRING',
#   'description': 'A Intrepid Drama of a Teacher And a Butler who must Build a Pastry Chef in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 59.3491777971,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 812,
#   'title': 'SMOKING BARBARELLA',
#   'description': 'A Lacklusture Saga of a Mad Cow And a Mad Scientist who must Sink a Cat in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 111.0497394663,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 813,
#   'title': 'SMOOCHY CONTROL',
#   'description': 'A Thrilling Documentary of a Husband And a Feminist who must Face a Mad Scientist in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 135.2873964569,
#   'replacement_cost': 18.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 814,
#   'title': 'SNATCH SLIPPER',
#   'description': 'A Insightful Panorama of a Woman And a Feminist who must Defeat a Forensic Psychologist in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 125.1507309594,
#   'replacement_cost': 15.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 815,
#   'title': 'SNATCHERS MONTEZUMA',
#   'description': 'A Boring Epistle of a Sumo Wrestler And a Woman who must Escape a Man in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 108.0961491453,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 816,
#   'title': 'SNOWMAN ROLLERCOASTER',
#   'description': 'A Fateful Display of a Lumberjack And a Girl who must Succumb a Mad Cow in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 87.7442954416,
#   'replacement_cost': 27.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 817,
#   'title': 'SOLDIERS EVOLUTION',
#   'description': 'A Lacklusture Panorama of a A Shark And a Pioneer who must Confront a Student in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 115.9388211811,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 818,
#   'title': 'SOMETHING DUCK',
#   'description': 'A Boring Character Study of a Car And a Husband who must Outgun a Frisbee in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 139.5698441773,
#   'replacement_cost': 17.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 819,
#   'title': 'SONG HEDWIG',
#   'description': 'A Amazing Documentary of a Man And a Husband who must Confront a Squirrel in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 99.5621224557,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 820,
#   'title': 'SONS INTERVIEW',
#   'description': 'A Taut Character Study of a Explorer And a Mad Cow who must Battle a Hunter in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 100.3788591302,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 821,
#   'title': 'SORORITY QUEEN',
#   'description': 'A Fast-Paced Display of a Squirrel And a Composer who must Fight a Forensic Psychologist in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 89.2993228366,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 822,
#   'title': 'SOUP WISDOM',
#   'description': 'A Fast-Paced Display of a Robot And a Butler who must Defeat a Butler in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 129.285671054,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 823,
#   'title': 'SOUTH WAIT',
#   'description': 'A Amazing Documentary of a Car And a Robot who must Escape a Lumberjack in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 124.3665570543,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 824,
#   'title': 'SPARTACUS CHEAPER',
#   'description': 'A Thrilling Panorama of a Pastry Chef And a Secret Agent who must Overcome a Student in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 5.99,
#   'length': 103.7713636831,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 825,
#   'title': 'SPEAKEASY DATE',
#   'description': 'A Lacklusture Drama of a Forensic Psychologist And a Car who must Redeem a Man in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 103.4147578859,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 826,
#   'title': 'SPEED SUIT',
#   'description': 'A Brilliant Display of a Frisbee And a Mad Scientist who must Succumb a Robot in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 121.5847822718,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 827,
#   'title': 'SPICE SORORITY',
#   'description': 'A Fateful Display of a Pioneer And a Hunter who must Defeat a Husband in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 172.64534887,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 828,
#   'title': 'SPIKING ELEMENT',
#   'description': 'A Lacklusture Epistle of a Dentist And a Technical Writer who must Find a Dog in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 111.5406242653,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 829,
#   'title': 'SPINAL ROCKY',
#   'description': 'A Lacklusture Epistle of a Sumo Wrestler And a Squirrel who must Defeat a Explorer in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 109.8345165223,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 830,
#   'title': 'SPIRIT FLINTSTONES',
#   'description': 'A Brilliant Yarn of a Cat And a Car who must Confront a Explorer in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 148.3994957094,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 831,
#   'title': 'SPIRITED CASUALTIES',
#   'description': 'A Taut Story of a Waitress And a Man who must Face a Car in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 85.4883577132,
#   'replacement_cost': 20.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 832,
#   'title': 'SPLASH GUMP',
#   'description': 'A Taut Saga of a Crocodile And a Boat who must Conquer a Hunter in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 128.9206074189,
#   'replacement_cost': 16.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 833,
#   'title': 'SPLENDOR PATTON',
#   'description': 'A Taut Story of a Dog And a Explorer who must Find a Astronaut in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 118.1604930796,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 834,
#   'title': 'SPOILERS HELLFIGHTERS',
#   'description': 'A Fanciful Story of a Technical Writer And a Squirrel who must Defeat a Dog in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 1.99,
#   'length': 99.6190414932,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 835,
#   'title': 'SPY MILE',
#   'description': 'A Thrilling Documentary of a Feminist And a Feminist who must Confront a Feminist in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 107.8711129404,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 836,
#   'title': 'SQUAD FISH',
#   'description': 'A Fast-Paced Display of a Pastry Chef And a Dog who must Kill a Teacher in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 121.986299025,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 837,
#   'title': 'STAGE WORLD',
#   'description': 'A Lacklusture Panorama of a Woman And a Frisbee who must Chase a Crocodile in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 120.5673431805,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 838,
#   'title': 'STAGECOACH ARMAGEDDON',
#   'description': 'A Touching Display of a Pioneer And a Butler who must Chase a Car in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 138.9255730891,
#   'replacement_cost': 25.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 839,
#   'title': 'STALLION SUNDANCE',
#   'description': 'A Fast-Paced Tale of a Car And a Dog who must Outgun a A Shark in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 104.2367130013,
#   'replacement_cost': 23.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 840,
#   'title': 'STAMPEDE DISTURBING',
#   'description': 'A Unbelieveable Tale of a Woman And a Lumberjack who must Fight a Frisbee in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 103.7080821125,
#   'replacement_cost': 26.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 841,
#   'title': 'STAR OPERATION',
#   'description': 'A Insightful Character Study of a Girl And a Car who must Pursue a Mad Cow in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 117.5214067398,
#   'replacement_cost': 9.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 842,
#   'title': 'STATE WASTELAND',
#   'description': 'A Beautiful Display of a Cat And a Pastry Chef who must Outrace a Mad Cow in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 3.99,
#   'length': 81.3034792671,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 843,
#   'title': 'STEEL SANTA',
#   'description': 'A Fast-Paced Yarn of a Composer And a Frisbee who must Face a Moose in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 130.8266651826,
#   'replacement_cost': 15.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 844,
#   'title': 'STEERS ARMAGEDDON',
#   'description': 'A Stunning Character Study of a Car And a Girl who must Succumb a Car in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 113.5361155283,
#   'replacement_cost': 16.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 845,
#   'title': 'STEPMOM DREAM',
#   'description': 'A Touching Epistle of a Crocodile And a Teacher who must Build a Forensic Psychologist in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 157.2507713135,
#   'replacement_cost': 9.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 846,
#   'title': 'STING PERSONAL',
#   'description': 'A Fanciful Drama of a Frisbee And a Dog who must Fight a Madman in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 95.0831690902,
#   'replacement_cost': 9.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 847,
#   'title': 'STOCK GLASS',
#   'description': 'A Boring Epistle of a Crocodile And a Lumberjack who must Outgun a Moose in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 90.3924150666,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 848,
#   'title': 'STONE FIRE',
#   'description': 'A Intrepid Drama of a Astronaut And a Crocodile who must Find a Boat in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 79.700125185,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 849,
#   'title': 'STORM HAPPINESS',
#   'description': 'A Insightful Drama of a Feminist And a A Shark who must Vanquish a Boat in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 62.7126389627,
#   'replacement_cost': 28.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 850,
#   'title': 'STORY SIDE',
#   'description': 'A Lacklusture Saga of a Boy And a Cat who must Sink a Dentist in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.49,
#   'length': 131.2336066812,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 851,
#   'title': 'STRAIGHT HOURS',
#   'description': 'A Boring Panorama of a Secret Agent And a Girl who must Sink a Waitress in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 149.2441175292,
#   'replacement_cost': 19.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 852,
#   'title': 'STRANGELOVE DESIRE',
#   'description': 'A Awe-Inspiring Panorama of a Lumberjack And a Waitress who must Defeat a Crocodile in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 124.4777936813,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 853,
#   'title': 'STRANGER STRANGERS',
#   'description': 'A Awe-Inspiring Yarn of a Womanizer And a Explorer who must Fight a Woman in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 73.8663371368,
#   'replacement_cost': 12.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 854,
#   'title': 'STRANGERS GRAFFITI',
#   'description': 'A Brilliant Character Study of a Secret Agent And a Man who must Find a Cat in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 136.8736124122,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 855,
#   'title': 'STREAK RIDGEMONT',
#   'description': 'A Astounding Character Study of a Hunter And a Waitress who must Sink a Man in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 112.9206649484,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 856,
#   'title': 'STREETCAR INTENTIONS',
#   'description': 'A Insightful Character Study of a Waitress And a Crocodile who must Sink a Waitress in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 135.6111779459,
#   'replacement_cost': 11.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 857,
#   'title': 'STRICTLY SCARFACE',
#   'description': 'A Touching Reflection of a Crocodile And a Dog who must Chase a Hunter in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 92.9477596411,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 858,
#   'title': 'SUBMARINE BED',
#   'description': 'A Amazing Display of a Car And a Monkey who must Fight a Teacher in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 97.0611006082,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 859,
#   'title': 'SUGAR WONKA',
#   'description': 'A Touching Story of a Dentist And a Database Administrator who must Conquer a Astronaut in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 105.4569596812,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 860,
#   'title': 'SUICIDES SILENCE',
#   'description': 'A Emotional Character Study of a Car And a Girl who must Face a Composer in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 5.99,
#   'length': 106.8351062886,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 861,
#   'title': 'SUIT WALLS',
#   'description': 'A Touching Panorama of a Lumberjack And a Frisbee who must Build a Dog in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 117.9704043937,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 862,
#   'title': 'SUMMER SCARFACE',
#   'description': 'A Emotional Panorama of a Lumberjack And a Hunter who must Meet a Girl in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 1.99,
#   'length': 88.2820086528,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 863,
#   'title': 'SUN CONFESSIONS',
#   'description': 'A Beautiful Display of a Mad Cow And a Dog who must Redeem a Waitress in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 158.434447591,
#   'replacement_cost': 9.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 864,
#   'title': 'SUNDANCE INVASION',
#   'description': 'A Epic Drama of a Lumberjack And a Explorer who must Confront a Hunter in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 117.513705933,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 865,
#   'title': 'SUNRISE LEAGUE',
#   'description': 'A Beautiful Epistle of a Madman And a Butler who must Face a Crocodile in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.99,
#   'length': 106.2449144866,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 866,
#   'title': 'SUNSET RACER',
#   'description': 'A Awe-Inspiring Reflection of a Astronaut And a A Shark who must Defeat a Forensic Psychologist in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 92.9670725057,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 867,
#   'title': 'SUPER WYOMING',
#   'description': 'A Action-Packed Saga of a Pastry Chef And a Explorer who must Discover a A Shark in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 110.3307843456,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 868,
#   'title': 'SUPERFLY TRIP',
#   'description': 'A Beautiful Saga of a Lumberjack And a Teacher who must Build a Technical Writer in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 114.4974537227,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 869,
#   'title': 'SUSPECTS QUILLS',
#   'description': 'A Emotional Epistle of a Pioneer And a Crocodile who must Battle a Man in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 112.1317154344,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 870,
#   'title': 'SWARM GOLD',
#   'description': 'A Insightful Panorama of a Crocodile And a Boat who must Conquer a Sumo Wrestler in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 133.4254196876,
#   'replacement_cost': 12.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 871,
#   'title': 'SWEDEN SHINING',
#   'description': 'A Taut Documentary of a Car And a Robot who must Conquer a Boy in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 89.8813347991,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 872,
#   'title': 'SWEET BROTHERHOOD',
#   'description': 'A Unbelieveable Epistle of a Sumo Wrestler And a Hunter who must Chase a Forensic Psychologist in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 148.0646847019,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 873,
#   'title': 'SWEETHEARTS SUSPECTS',
#   'description': 'A Brilliant Character Study of a Frisbee And a Sumo Wrestler who must Confront a Woman in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 69.9171630569,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 874,
#   'title': 'TADPOLE PARK',
#   'description': 'A Beautiful Tale of a Frisbee And a Moose who must Vanquish a Dog in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 95.9264201642,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 875,
#   'title': 'TALENTED HOMICIDE',
#   'description': 'A Lacklusture Panorama of a Dentist And a Forensic Psychologist who must Outrace a Pioneer in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 100.0167492413,
#   'replacement_cost': 9.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 876,
#   'title': 'TARZAN VIDEOTAPE',
#   'description': 'A Fast-Paced Display of a Lumberjack And a Mad Scientist who must Succumb a Sumo Wrestler in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 105.7589638236,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 877,
#   'title': 'TAXI KICK',
#   'description': 'A Amazing Epistle of a Girl And a Woman who must Outrace a Waitress in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 116.6324576116,
#   'replacement_cost': 23.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 878,
#   'title': 'TEEN APOLLO',
#   'description': 'A Awe-Inspiring Drama of a Dog And a Man who must Escape a Robot in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 109.7875678581,
#   'replacement_cost': 25.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 879,
#   'title': 'TELEGRAPH VOYAGE',
#   'description': 'A Fateful Yarn of a Husband And a Dog who must Battle a Waitress in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 102.0655681641,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 880,
#   'title': 'TELEMARK HEARTBREAKERS',
#   'description': 'A Action-Packed Panorama of a Technical Writer And a Man who must Build a Forensic Psychologist in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 114.2900404654,
#   'replacement_cost': 9.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 881,
#   'title': 'TEMPLE ATTRACTION',
#   'description': 'A Action-Packed Saga of a Forensic Psychologist And a Woman who must Battle a Womanizer in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.99,
#   'length': 91.8972225156,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 882,
#   'title': 'TENENBAUMS COMMAND',
#   'description': 'A Taut Display of a Pioneer And a Man who must Reach a Girl in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 120.5855181533,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 883,
#   'title': 'TEQUILA PAST',
#   'description': 'A Action-Packed Panorama of a Mad Scientist And a Robot who must Challenge a Student in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 77.647170531,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 884,
#   'title': 'TERMINATOR CLUB',
#   'description': 'A Touching Story of a Crocodile And a Girl who must Sink a Man in The Gulf of Mexico',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 155.7867869584,
#   'replacement_cost': 11.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 885,
#   'title': 'TEXAS WATCH',
#   'description': 'A Awe-Inspiring Yarn of a Student And a Teacher who must Fight a Teacher in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 107.7394191886,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 886,
#   'title': 'THEORY MERMAID',
#   'description': 'A Fateful Yarn of a Composer And a Monkey who must Vanquish a Womanizer in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 121.3085672381,
#   'replacement_cost': 9.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 887,
#   'title': 'THIEF PELICAN',
#   'description': 'A Touching Documentary of a Madman And a Mad Scientist who must Outrace a Feminist in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 111.8739417014,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 888,
#   'title': 'THIN SAGEBRUSH',
#   'description': 'A Emotional Drama of a Husband And a Lumberjack who must Build a Cat in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 73.310965135,
#   'replacement_cost': 9.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 889,
#   'title': 'TIES HUNGER',
#   'description': 'A Insightful Saga of a Astronaut And a Explorer who must Pursue a Mad Scientist in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 129.3176575545,
#   'replacement_cost': 28.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 890,
#   'title': 'TIGHTS DAWN',
#   'description': 'A Thrilling Epistle of a Boat And a Secret Agent who must Face a Boy in A Baloon',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 145.0552022526,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 891,
#   'title': 'TIMBERLAND SKY',
#   'description': 'A Boring Display of a Man And a Dog who must Redeem a Girl in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 64.9083913527,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 892,
#   'title': 'TITANIC BOONDOCK',
#   'description': 'A Brilliant Reflection of a Feminist And a Dog who must Fight a Boy in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 135.4916097732,
#   'replacement_cost': 18.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 893,
#   'title': 'TITANS JERK',
#   'description': 'A Unbelieveable Panorama of a Feminist And a Sumo Wrestler who must Challenge a Technical Writer in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 86.7560739224,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 894,
#   'title': 'TOMATOES HELLFIGHTERS',
#   'description': 'A Thoughtful Epistle of a Madman And a Astronaut who must Overcome a Monkey in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 109.6116837312,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 895,
#   'title': 'TOMORROW HUSTLER',
#   'description': 'A Thoughtful Story of a Moose And a Husband who must Face a Secret Agent in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 121.0785531839,
#   'replacement_cost': 21.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 896,
#   'title': 'TOOTSIE PILOT',
#   'description': 'A Awe-Inspiring Documentary of a Womanizer And a Pastry Chef who must Kill a Lumberjack in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 104.8374758259,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 897,
#   'title': 'TORQUE BOUND',
#   'description': 'A Emotional Display of a Crocodile And a Husband who must Reach a Man in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 108.9103363231,
#   'replacement_cost': 27.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 898,
#   'title': 'TOURIST PELICAN',
#   'description': 'A Boring Story of a Butler And a Astronaut who must Outrace a Pioneer in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 114.6847832072,
#   'replacement_cost': 18.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 899,
#   'title': 'TOWERS HURRICANE',
#   'description': 'A Fateful Display of a Monkey And a Car who must Sink a Husband in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 113.697890215,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 900,
#   'title': 'TOWN ARK',
#   'description': 'A Awe-Inspiring Documentary of a Moose And a Madman who must Meet a Dog in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 138.7765217618,
#   'replacement_cost': 17.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 901,
#   'title': 'TRACY CIDER',
#   'description': 'A Touching Reflection of a Database Administrator And a Madman who must Build a Lumberjack in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 85.1546317749,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 902,
#   'title': 'TRADING PINOCCHIO',
#   'description': 'A Emotional Character Study of a Student And a Explorer who must Discover a Frisbee in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 76.6908122648,
#   'replacement_cost': 22.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 903,
#   'title': 'TRAFFIC HOBBIT',
#   'description': 'A Amazing Epistle of a Squirrel And a Lumberjack who must Succumb a Database Administrator in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 5.99,
#   'length': 95.0910411476,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 904,
#   'title': 'TRAIN BUNCH',
#   'description': 'A Thrilling Character Study of a Robot And a Squirrel who must Face a Dog in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 136.5309683006,
#   'replacement_cost': 26.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 905,
#   'title': 'TRAINSPOTTING STRANGERS',
#   'description': 'A Fast-Paced Drama of a Pioneer And a Mad Cow who must Challenge a Madman in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 90.6190122837,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 906,
#   'title': 'TRAMP OTHERS',
#   'description': 'A Brilliant Display of a Composer And a Cat who must Succumb a A Shark in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 0.99,
#   'length': 98.757703352,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 907,
#   'title': 'TRANSLATION SUMMER',
#   'description': 'A Touching Reflection of a Man And a Monkey who must Pursue a Womanizer in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 124.2436447365,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 908,
#   'title': 'TRAP GUYS',
#   'description': 'A Unbelieveable Story of a Boy And a Mad Cow who must Challenge a Database Administrator in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 100.1929200842,
#   'replacement_cost': 11.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 909,
#   'title': 'TREASURE COMMAND',
#   'description': 'A Emotional Saga of a Car And a Madman who must Discover a Pioneer in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 113.2775947477,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 910,
#   'title': 'TREATMENT JEKYLL',
#   'description': 'A Boring Story of a Teacher And a Student who must Outgun a Cat in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 118.3581521587,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 911,
#   'title': 'TRIP NEWTON',
#   'description': 'A Fanciful Character Study of a Lumberjack And a Car who must Discover a Cat in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 104.4068808152,
#   'replacement_cost': 14.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 912,
#   'title': 'TROJAN TOMORROW',
#   'description': 'A Astounding Panorama of a Husband And a Sumo Wrestler who must Pursue a Boat in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 75.5670792442,
#   'replacement_cost': 9.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 913,
#   'title': 'TROOPERS METAL',
#   'description': 'A Fanciful Drama of a Monkey And a Feminist who must Sink a Man in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 115.1984688472,
#   'replacement_cost': 20.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 914,
#   'title': 'TROUBLE DATE',
#   'description': 'A Lacklusture Panorama of a Forensic Psychologist And a Woman who must Kill a Explorer in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 88.7579496295,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 915,
#   'title': 'TRUMAN CRAZY',
#   'description': 'A Thrilling Epistle of a Moose And a Boy who must Meet a Database Administrator in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 93.9350915066,
#   'replacement_cost': 9.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 916,
#   'title': 'TURN STAR',
#   'description': 'A Stunning Tale of a Man And a Monkey who must Chase a Student in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 109.0734572238,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 917,
#   'title': 'TUXEDO MILE',
#   'description': 'A Boring Drama of a Man And a Forensic Psychologist who must Face a Frisbee in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 123.3230754398,
#   'replacement_cost': 24.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 918,
#   'title': 'TWISTED PIRATES',
#   'description': 'A Touching Display of a Frisbee And a Boat who must Kill a Girl in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 80.0170948656,
#   'replacement_cost': 23.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 919,
#   'title': 'TYCOON GATHERING',
#   'description': 'A Emotional Display of a Husband And a A Shark who must Succumb a Madman in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 90.2389280404,
#   'replacement_cost': 17.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 920,
#   'title': 'UNBREAKABLE KARATE',
#   'description': 'A Amazing Character Study of a Robot And a Student who must Chase a Robot in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 85.097296129,
#   'replacement_cost': 16.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 921,
#   'title': 'UNCUT SUICIDES',
#   'description': 'A Intrepid Yarn of a Explorer And a Pastry Chef who must Pursue a Mad Cow in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 72.1543904536,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 922,
#   'title': 'UNDEFEATED DALMATIONS',
#   'description': 'A Unbelieveable Display of a Crocodile And a Feminist who must Overcome a Moose in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 77.9260414705,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 923,
#   'title': 'UNFAITHFUL KILL',
#   'description': 'A Taut Documentary of a Waitress And a Mad Scientist who must Battle a Technical Writer in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 109.7794695187,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 924,
#   'title': 'UNFORGIVEN ZOOLANDER',
#   'description': 'A Taut Epistle of a Monkey And a Sumo Wrestler who must Vanquish a A Shark in A Baloon Factory',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 123.1682742566,
#   'replacement_cost': 15.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 925,
#   'title': 'UNITED PILOT',
#   'description': 'A Fast-Paced Reflection of a Cat And a Mad Cow who must Fight a Car in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 124.942322934,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 926,
#   'title': 'UNTOUCHABLES SUNRISE',
#   'description': 'A Amazing Documentary of a Woman And a Astronaut who must Outrace a Teacher in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 105.4635301344,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 927,
#   'title': 'UPRISING UPTOWN',
#   'description': 'A Fanciful Reflection of a Boy And a Butler who must Pursue a Woman in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 80.0723022606,
#   'replacement_cost': 16.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 928,
#   'title': 'UPTOWN YOUNG',
#   'description': 'A Fateful Documentary of a Dog And a Hunter who must Pursue a Teacher in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 96.3904898416,
#   'replacement_cost': 16.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 929,
#   'title': 'USUAL UNTOUCHABLES',
#   'description': 'A Touching Display of a Explorer And a Lumberjack who must Fight a Forensic Psychologist in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.99,
#   'length': 92.3440846283,
#   'replacement_cost': 21.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 930,
#   'title': 'VACATION BOONDOCK',
#   'description': 'A Fanciful Character Study of a Secret Agent And a Mad Scientist who must Reach a Teacher in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 129.3934629566,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 931,
#   'title': 'VALENTINE VANISHING',
#   'description': 'A Thrilling Display of a Husband And a Butler who must Reach a Pastry Chef in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 104.3127579109,
#   'replacement_cost': 9.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 932,
#   'title': 'VALLEY PACKER',
#   'description': 'A Astounding Documentary of a Astronaut And a Boy who must Outrace a Sumo Wrestler in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 1.99,
#   'length': 68.3268977713,
#   'replacement_cost': 21.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 933,
#   'title': 'VAMPIRE WHALE',
#   'description': 'A Epic Story of a Lumberjack And a Monkey who must Confront a Pioneer in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 89.3028480863,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 934,
#   'title': 'VANILLA DAY',
#   'description': 'A Fast-Paced Saga of a Girl And a Forensic Psychologist who must Redeem a Girl in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 107.2471830151,
#   'replacement_cost': 20.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 935,
#   'title': 'VANISHED GARDEN',
#   'description': 'A Intrepid Character Study of a Squirrel And a A Shark who must Kill a Lumberjack in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 115.3044230784,
#   'replacement_cost': 17.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 936,
#   'title': 'VANISHING ROCKY',
#   'description': 'A Brilliant Reflection of a Man And a Woman who must Conquer a Pioneer in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 79.5785701003,
#   'replacement_cost': 21.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 937,
#   'title': 'VARSITY TRIP',
#   'description': 'A Action-Packed Character Study of a Astronaut And a Explorer who must Reach a Monkey in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 3.99,
#   'length': 104.7332431468,
#   'replacement_cost': 14.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 938,
#   'title': 'VELVET TERMINATOR',
#   'description': 'A Lacklusture Tale of a Pastry Chef And a Technical Writer who must Confront a Crocodile in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 102.0177256313,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 939,
#   'title': 'VERTIGO NORTHWEST',
#   'description': 'A Unbelieveable Display of a Mad Scientist And a Mad Scientist who must Outgun a Mad Cow in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.49,
#   'length': 140.1065815322,
#   'replacement_cost': 17.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 940,
#   'title': 'VICTORY ACADEMY',
#   'description': 'A Insightful Epistle of a Mad Scientist And a Explorer who must Challenge a Cat in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 139.7649813119,
#   'replacement_cost': 19.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 941,
#   'title': 'VIDEOTAPE ARSENIC',
#   'description': 'A Lacklusture Display of a Girl And a Astronaut who must Succumb a Student in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 116.8726828932,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 942,
#   'title': 'VIETNAM SMOOCHY',
#   'description': 'A Lacklusture Display of a Butler And a Man who must Sink a Explorer in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 108.6710214168,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 943,
#   'title': 'VILLAIN DESPERATE',
#   'description': 'A Boring Yarn of a Pioneer And a Feminist who must Redeem a Cat in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 95.206933148,
#   'replacement_cost': 27.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 944,
#   'title': 'VIRGIN DAISY',
#   'description': 'A Awe-Inspiring Documentary of a Robot And a Mad Scientist who must Reach a Database Administrator in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 104.9005071346,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 945,
#   'title': 'VIRGINIAN PLUTO',
#   'description': 'A Emotional Panorama of a Dentist And a Crocodile who must Meet a Boy in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 149.0011509659,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 946,
#   'title': 'VIRTUAL SPOILERS',
#   'description': 'A Fateful Tale of a Database Administrator And a Squirrel who must Discover a Student in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.99,
#   'length': 103.6457372872,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 947,
#   'title': 'VISION TORQUE',
#   'description': 'A Thoughtful Documentary of a Dog And a Man who must Sink a Man in A Shark Tank',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.99,
#   'length': 106.4366788538,
#   'replacement_cost': 16.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 948,
#   'title': 'VOICE PEACH',
#   'description': 'A Amazing Panorama of a Pioneer And a Student who must Overcome a Mad Scientist in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 103.3564896054,
#   'replacement_cost': 22.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 949,
#   'title': 'VOLCANO TEXAS',
#   'description': 'A Awe-Inspiring Yarn of a Hunter And a Feminist who must Challenge a Dentist in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 118.5736097447,
#   'replacement_cost': 27.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 950,
#   'title': 'VOLUME HOUSE',
#   'description': 'A Boring Tale of a Dog And a Woman who must Meet a Dentist in California',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 122.5395191359,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 951,
#   'title': 'VOYAGE LEGALLY',
#   'description': 'A Epic Tale of a Squirrel And a Hunter who must Conquer a Boy in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 108.833454897,
#   'replacement_cost': 28.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 952,
#   'title': 'WAGON JAWS',
#   'description': 'A Intrepid Drama of a Moose And a Boat who must Kill a Explorer in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 118.7205366079,
#   'replacement_cost': 17.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 953,
#   'title': 'WAIT CIDER',
#   'description': 'A Intrepid Epistle of a Woman And a Forensic Psychologist who must Succumb a Astronaut in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 122.0701092853,
#   'replacement_cost': 9.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 954,
#   'title': 'WAKE JAWS',
#   'description': 'A Beautiful Saga of a Feminist And a Composer who must Challenge a Moose in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 102.3808566001,
#   'replacement_cost': 18.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 955,
#   'title': 'WALLS ARTIST',
#   'description': 'A Insightful Panorama of a Teacher And a Teacher who must Overcome a Mad Cow in An Abandoned Fun House',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.99,
#   'length': 110.1471247872,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 956,
#   'title': 'WANDA CHAMBER',
#   'description': 'A Insightful Drama of a A Shark And a Pioneer who must Find a Womanizer in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.99,
#   'length': 83.5818622348,
#   'replacement_cost': 23.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 957,
#   'title': 'WAR NOTTING',
#   'description': 'A Boring Drama of a Teacher And a Sumo Wrestler who must Challenge a Secret Agent in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 5.99,
#   'length': 110.8744181858,
#   'replacement_cost': 26.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 958,
#   'title': 'WARDROBE PHANTOM',
#   'description': 'A Action-Packed Display of a Mad Cow And a Astronaut who must Kill a Car in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 130.9177427383,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 959,
#   'title': 'WARLOCK WEREWOLF',
#   'description': 'A Astounding Yarn of a Pioneer And a Crocodile who must Defeat a A Shark in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 3.99,
#   'length': 100.7003246327,
#   'replacement_cost': 10.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 960,
#   'title': 'WARS PLUTO',
#   'description': 'A Taut Reflection of a Teacher And a Database Administrator who must Chase a Madman in The Sahara Desert',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 3.99,
#   'length': 97.5160244685,
#   'replacement_cost': 15.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 961,
#   'title': 'WASH HEAVENLY',
#   'description': 'A Awe-Inspiring Reflection of a Cat And a Pioneer who must Escape a Hunter in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 6.49,
#   'length': 116.3439618527,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 962,
#   'title': 'WASTELAND DIVINE',
#   'description': 'A Fanciful Story of a Database Administrator And a Womanizer who must Fight a Database Administrator in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 116.4501034311,
#   'replacement_cost': 18.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 963,
#   'title': 'WATCH TRACY',
#   'description': 'A Fast-Paced Yarn of a Dog And a Frisbee who must Conquer a Hunter in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 0.99,
#   'length': 117.189876403,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 964,
#   'title': 'WATERFRONT DELIVERANCE',
#   'description': 'A Unbelieveable Documentary of a Dentist And a Technical Writer who must Build a Womanizer in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 5.99,
#   'length': 70.2759059182,
#   'replacement_cost': 17.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 965,
#   'title': 'WATERSHIP FRONTIER',
#   'description': 'A Emotional Yarn of a Boat And a Crocodile who must Meet a Moose in Soviet Georgia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 86.3582003766,
#   'replacement_cost': 28.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 966,
#   'title': 'WEDDING APOLLO',
#   'description': 'A Action-Packed Tale of a Student And a Waitress who must Conquer a Lumberjack in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 0.99,
#   'length': 122.4781160367,
#   'replacement_cost': 14.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 967,
#   'title': 'WEEKEND PERSONAL',
#   'description': 'A Fast-Paced Documentary of a Car And a Butler who must Find a Frisbee in A Jet Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 131.0799900074,
#   'replacement_cost': 26.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 968,
#   'title': 'WEREWOLF LOLA',
#   'description': 'A Fanciful Story of a Man And a Sumo Wrestler who must Outrace a Student in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 5.99,
#   'length': 122.9372112772,
#   'replacement_cost': 19.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 969,
#   'title': 'WEST LION',
#   'description': 'A Intrepid Drama of a Butler And a Lumberjack who must Challenge a Database Administrator in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 5.99,
#   'length': 97.9453609788,
#   'replacement_cost': 29.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 970,
#   'title': 'WESTWARD SEABISCUIT',
#   'description': 'A Lacklusture Tale of a Butler And a Husband who must Face a Boy in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 0.99,
#   'length': 77.451376182,
#   'replacement_cost': 11.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 971,
#   'title': 'WHALE BIKINI',
#   'description': 'A Intrepid Story of a Pastry Chef And a Database Administrator who must Kill a Feminist in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 113.3858076695,
#   'replacement_cost': 11.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 972,
#   'title': 'WHISPERER GIANT',
#   'description': 'A Intrepid Story of a Dentist And a Hunter who must Confront a Monkey in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.99,
#   'length': 126.5244063084,
#   'replacement_cost': 24.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 973,
#   'title': 'WIFE TURN',
#   'description': 'A Awe-Inspiring Epistle of a Teacher And a Feminist who must Confront a Pioneer in Ancient Japan',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 6.49,
#   'length': 119.9626059885,
#   'replacement_cost': 27.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 974,
#   'title': 'WILD APOLLO',
#   'description': 'A Beautiful Story of a Monkey And a Sumo Wrestler who must Conquer a A Shark in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 90.4672010371,
#   'replacement_cost': 24.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 975,
#   'title': 'WILLOW TRACY',
#   'description': 'A Brilliant Panorama of a Boat And a Astronaut who must Challenge a Teacher in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.49,
#   'length': 161.7070756329,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 976,
#   'title': 'WIND PHANTOM',
#   'description': 'A Touching Saga of a Madman And a Forensic Psychologist who must Build a Sumo Wrestler in An Abandoned Mine Shaft',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.49,
#   'length': 134.3429264143,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 977,
#   'title': 'WINDOW SIDE',
#   'description': 'A Astounding Character Study of a Womanizer And a Hunter who must Escape a Robot in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 4.49,
#   'length': 108.8912979832,
#   'replacement_cost': 25.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 978,
#   'title': 'WISDOM WORKER',
#   'description': 'A Unbelieveable Saga of a Forensic Psychologist And a Student who must Face a Squirrel in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.49,
#   'length': 149.0291139251,
#   'replacement_cost': 12.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 979,
#   'title': 'WITCHES PANIC',
#   'description': 'A Awe-Inspiring Drama of a Secret Agent And a Hunter who must Fight a Moose in Nigeria',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.49,
#   'length': 140.8524986906,
#   'replacement_cost': 10.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 980,
#   'title': 'WIZARD COLDBLOODED',
#   'description': 'A Lacklusture Display of a Robot And a Girl who must Defeat a Sumo Wrestler in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 110.1837966015,
#   'replacement_cost': 12.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 981,
#   'title': 'WOLVES DESIRE',
#   'description': 'A Fast-Paced Drama of a Squirrel And a Robot who must Succumb a Technical Writer in A Manhattan Penthouse',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 1.99,
#   'length': 87.930089599,
#   'replacement_cost': 13.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 982,
#   'title': 'WOMEN DORADO',
#   'description': 'A Insightful Documentary of a Waitress And a Butler who must Vanquish a Composer in Australia',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 151.2040821089,
#   'replacement_cost': 23.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 983,
#   'title': 'WON DARES',
#   'description': 'A Unbelieveable Documentary of a Teacher And a Monkey who must Defeat a Explorer in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 2.99,
#   'length': 106.174787287,
#   'replacement_cost': 18.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 984,
#   'title': 'WONDERFUL DROP',
#   'description': 'A Boring Panorama of a Woman And a Madman who must Overcome a Butler in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 3.99,
#   'length': 94.6425193174,
#   'replacement_cost': 20.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 985,
#   'title': 'WONDERLAND CHRISTMAS',
#   'description': 'A Awe-Inspiring Character Study of a Waitress And a Car who must Pursue a Mad Scientist in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 4.99,
#   'length': 107.3923950937,
#   'replacement_cost': 19.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 986,
#   'title': 'WONKA SEA',
#   'description': 'A Brilliant Saga of a Boat And a Mad Scientist who must Meet a Moose in Ancient India',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 2.99,
#   'length': 101.2626599007,
#   'replacement_cost': 24.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 987,
#   'title': 'WORDS HUNTER',
#   'description': 'A Action-Packed Reflection of a Composer And a Mad Scientist who must Face a Pioneer in A MySQL Convention',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 103.8927342658,
#   'replacement_cost': 13.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 988,
#   'title': 'WORKER TARZAN',
#   'description': 'A Action-Packed Yarn of a Secret Agent And a Technical Writer who must Battle a Sumo Wrestler in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 7,
#   'rental_rate': 4.49,
#   'length': 140.9891892104,
#   'replacement_cost': 26.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 989,
#   'title': 'WORKING MICROCOSMOS',
#   'description': 'A Stunning Epistle of a Dentist And a Dog who must Kill a Madman in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 6.49,
#   'length': 137.952138805,
#   'replacement_cost': 22.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 990,
#   'title': 'WORLD LEATHERNECKS',
#   'description': 'A Unbelieveable Tale of a Pioneer And a Astronaut who must Overcome a Robot in An Abandoned Amusement Park',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 2.99,
#   'length': 89.4662137013,
#   'replacement_cost': 13.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 991,
#   'title': 'WORST BANGER',
#   'description': 'A Thrilling Drama of a Madman And a Dentist who must Conquer a Boy in The Outback',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.99,
#   'length': 112.4155320599,
#   'replacement_cost': 26.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 992,
#   'title': 'WRATH MILE',
#   'description': 'A Intrepid Reflection of a Technical Writer And a Hunter who must Defeat a Sumo Wrestler in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 2.49,
#   'length': 151.5410368454,
#   'replacement_cost': 17.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 993,
#   'title': 'WRONG BEHAVIOR',
#   'description': 'A Emotional Saga of a Crocodile And a Sumo Wrestler who must Discover a Mad Cow in New Orleans',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 4.99,
#   'length': 107.1561357985,
#   'replacement_cost': 10.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 994,
#   'title': 'WYOMING STORM',
#   'description': 'A Awe-Inspiring Panorama of a Robot And a Boat who must Overcome a Feminist in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 6.99,
#   'length': 104.2583815565,
#   'replacement_cost': 29.99,
#   'rating': 'PG-13',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 995,
#   'title': 'YENTL IDAHO',
#   'description': 'A Amazing Display of a Robot And a Astronaut who must Fight a Womanizer in Berlin',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 6.49,
#   'length': 125.8780163868,
#   'replacement_cost': 11.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 996,
#   'title': 'YOUNG LANGUAGE',
#   'description': 'A Unbelieveable Yarn of a Boat And a Database Administrator who must Meet a Boy in The First Manned Space Station',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 1.99,
#   'length': 61.5645951977,
#   'replacement_cost': 9.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 997,
#   'title': 'YOUTH KICK',
#   'description': 'A Touching Drama of a Teacher And a Cat who must Challenge a Technical Writer in A U-Boat',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 4,
#   'rental_rate': 2.49,
#   'length': 133.5908745517,
#   'replacement_cost': 14.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 998,
#   'title': 'ZHIVAGO CORE',
#   'description': 'A Fateful Yarn of a Composer And a Man who must Face a Boy in The Canadian Rockies',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 6,
#   'rental_rate': 0.99,
#   'length': 107.9852188967,
#   'replacement_cost': 10.99,
#   'rating': 'PG',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 999,
#   'title': 'ZOOLANDER FICTION',
#   'description': 'A Fateful Reflection of a Waitress And a Boat who must Discover a Sumo Wrestler in Ancient China',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 5,
#   'rental_rate': 4.49,
#   'length': 113.7064872367,
#   'replacement_cost': 28.99,
#   'rating': 'R',
#   'last_update': '2007-09-10 17:46:03.905795'},
#  {'film_id': 1000,
#   'title': 'ZORRO ARK',
#   'description': 'A Intrepid Panorama of a Mad Scientist And a Boy who must Redeem a Boy in A Monastery',
#   'release_year': 2006,
#   'language_id': 1,
#   'rental_duration': 3,
#   'rental_rate': 5.99,
#   'length': 77.4859715847,
#   'replacement_cost': 18.99,
#   'rating': 'G',
#   'last_update': '2007-09-10 17:46:03.905795'}
# ]
# ```
# ### plots.js
# ```js
# let ratings = ['G', 'PG', 'PG-13', 'R'];
#
# // Metric variable for function inputs
# let metric = "length";
# // let metric = "rental_rate";
# // let metric = "replacement_cost";
#
# // Create a function to calculate the annual average of a metric
# function metricMean(films, rating, metric) {
#   // Initialize variables to increment
#   let count = 0;
#   let total = 0;
#
#   // Loop through the array of films
#   for (let i = 0; i < films.length; i++) {
#
#     // Store the film at index `i` for evaluation
#     row = films[i];
#
#     // Compare `rating` value to `rating` provided as argument
#     if (row.rating == rating){
#
#       // Increment by `metric` argument value
#       total += row[metric];
#       // Increment by one
#       count += 1;
#     }
#   }
#
#   // Calculate the average value
#   let meanValue = total / count;
#
#   // Return the calcuated average
#   return meanValue;
# }
#
# // Invoke the metric average function
# // Calculate the average for each rating individually
# let metricG = metricMean(films, "G", metric);
# let metricPG = metricMean(films, "PG", metric);
# let metricPG_13 = metricMean(films, "PG-13", metric);
# let metricR = metricMean(films, "R", metric);
#
# // Creat an array of rating averages
# let metricArray = [metricG, metricPG, metricPG_13, metricR];
#
# // Create a function to plot the rating average metric results
# function plotMetric(metricArray, ratings, metric){
#
#   let trace1 = {
#     x: ratings,
#     y: metricArray,
#     type: "bar"
#   }
#
#   let data = [trace1]
#
#   // Pass metric to chart title
#   let layout = {
#     title: `Pagila Rental Films Average ${metric}`
#   };
#
#   Plotly.newPlot("plot", data, layout);
# }
#
# // Invoke the plot creating function
# plotMetric(metricArray, ratings, metric);
# ```
# ### refactoeres.js
# ```js
# let ratings = ['G', 'PG', 'PG-13', 'R'];
#
# // Metric variable for function inputs
# let metric = "length";
# // let metric = "rental_rate";
# // let metric = "replacement_cost";
#
# // Function to calculate and plot the average of a metric by rating
# function plotMetric(films, ratings, metric) {
#   // Initialize an array to hold metric averages
#   let metricArray = [];
#
#   // Loop through the array of ratings
#   for (let i =0; i < ratings.length; i++) {
#     // Store the rating at index `i` for evaluation
#     rating = ratings[i];
#
#     // Initialize variables to increment
#     let count = 0;
#     let total = 0;
#
#     // Loop through the array of films
#     for (let j = 0; j < films.length; j++) {
#       // Store the film at index `j` for evaluation
#       row = films[j];
#
#       // Compare `rating` value to `rating` provided as argument
#       if (row.rating == rating){
#
#         // Increment by `metric` argument value
#         total += row[metric];
#         // Increment by one
#         count += 1;
#       }
#     }
#     // Calculate the average value
#     let meanValue = total / count;
#
#     // Append the average value to the  `metricArray`
#     metricArray.push(meanValue);
#   }
#
#   // Assign `ratings` array argument to `x`
#   // Assign the `metricArray` with averages for each rating to `y`
#   let trace1 = {
#     x: ratings,
#     y: metricArray,
#     type: "bar"
#   }
#
#   let data = [trace1];
#
#   // Pass metric to chart title
#   let layout = {
#     title: `Pagila Rental Films Average ${metric}`
#   };
#
#   Plotly.newPlot("plot", data, layout);
# }
#
# // Invoke the plotting function
# plotMetric(films, ratings, metric);
# ```

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### Rating Class Objectives
#
# * rate your understanding using 1-5 method in each objective

# %%
title = "14.1-Interactive-Visualizations-Introduction to JavaScript Visualizations"
objectives = [
    "Describe JavaScript variables, arrays, data types, and statements",
    "Implement basic JavaScript control flow (functions, loops, if/else statements)",
    "Create functions in JavaScript",
    "Create, update, and iterate JavaScript objects",
    "Create basic charts, including bar charts and line charts, by using Plotly",
    "Use Plotly's layout object to customize the appearance of charts",
    "Annotate charts with labels, text, and hover text",
]
rating = []
total = 0
for i in range(len(objectives)):
    rate = input(objectives[i]+"? ")
    total += int(rate)
    rating.append(objectives[i] + ". (" + rate + "/5)")
print("="*96)
print(f"Self Evaluation for: {title}")
print("-"*24)
for i in rating:
    print(i)
print("-"*64)
print("Average: " + str(total/len(objectives)))
